# %%
import csv
import datetime as datetime
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time 
import random
import os
from tqdm.notebook import trange, tqdm

# %%
def get_url(startPage):
    """Generate URL from position and Location
    :parameter: location -> Country"""
    template = 'https://empregos.org/jobfind.php?f={}&action=search&auth_sess=b32b5c79fb901f90536261a2e302a588&ref=558a97e97b671d3dca7fc7b67&bx_jtitle=&rdjt=2&jids[]=00&lids[]=000&bx_prv[]=&bx_plng[]=0&bx_kwd=&rdKeyw=2&bx_minsalary=&bx_maxsalary=&bx_lngids[]=-&rdLang=2&tids[]=0&posted=0&o=1&o_show=4&cmdSearch=++Pesquisar++'
    url = template.format(startPage)
    return url

# %%
url = get_url(5000)
url
# Out:
# 'https://empregos.org/jobfind.php?f=5000&action=search&auth_sess=b32b5c79fb901f90536261a2e302a588&ref=558a97e97b671d3dca7fc7b67&bx_jtitle=&rdjt=2&jids[]=00&lids[]=000&bx_prv[]=&bx_plng[]=0&bx_kwd=&rdKeyw=2&bx_minsalary=&bx_maxsalary=&bx_lngids[]=-&rdLang=2&tids[]=0&posted=0&o=1&o_show=4&cmdSearch=++Pesquisar++'

# %% [markdown]
# # Extract Raw Html

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'html.parser')
entries = soup.find_all('td')
len(entries)
# Out:
# 64

# %%
len(entries[12:-2])
# Out:
# 50

# %%
cards = entries[12:-2].copy()
cards
# Out:
# [<td>
#  <div class="rownumber"><strong>5001.</strong>
#  <span class="bkm"><input class="radio" name="job_id[]" type="checkbox" value="2775447"/> </span>
#  </div>
#  <div class="results phpjob_listbgcolor21">
#  <h2><a href="https://empregos.org/view.php?job_id=2775447&amp;type=search&amp;auth_sess=e261d448fae3a3354619fe256e5e7e88&amp;ref=1eb1266099101f7ad0ec7796e" title="Anúncio de emprego: Pizzaiolo M/F para Viseu em Pizzaria conceituada.">Anúncio de emprego: Pizzaiolo M/F para Viseu em Pizzaria conceituada.</a></h2>
#  <p class="desc"><a class="hilink" href="https://empregos.org/view.php?company_id=59997&amp;type=search&amp;auth_sess=e261d448fae3a3354619fe256e5e7e88&amp;ref=1eb1266099101f7ad0ec7796e" title="GWF">GWF</a> - Viseu - Viseu<br>
#  		Descrição: <h4>Pizzaiolo M/F para Viseu em Pizzaria conceituada.</h4>   <b>»</b>  GWF                                  <br> &amp;nbsp... <a class="hilink" href="https://empregos.org/view.php?job_id=2775447&amp;type=search&amp;auth_sess=e261d448fae3a3354619fe256e5e7e88&amp;ref=1eb1266099101f7ad0ec7796e" title="Anúncio de emprego: Pizzaiolo M/F para Viseu em Pizzaria conceituada. - More Details">Mais detalhes »</a></br></br></p>
#  <p class="posted">Enviado: Ontem - Visualizações: 328</p>
#  </div>
#  </td>,
#  <td>
#  <div class="rownumber"><strong>5002.</strong>
#  <span class="bkm"><input class="radio" name="job_id[]" type="checkbox" value="2775446"/> </span>
#  </div>
#  <div class="results phpjob_listbgcolor11">
#  <h2><a href="https://empregos.org/view.php?job_id=2775446&amp;type=search&amp;auth_sess=e261d448fae3a3354619fe256e5e7e88&amp;ref=1eb1266099101f7ad0ec7796e" title="Oferta: Angariador">Oferta: Angariador</a></h2>
#  <p class="desc"><a class="hilink" href="https://empregos.org/view.php?company_id=81164&amp;type=search&amp;auth_sess=e261d448fae3a3354619fe256e5e7e88&amp;ref=1eb1266099101f7ad0ec7796e" title="Simples E Singular, Lda">Simples E Singular, Lda</a> - Viseu - Viseu<br>
#  		Descrição: <h4>Angariador</h4>   <b>»</b>  Simples e Singular, Lda                                  <br>   <b>»&lt;... <a class="hilink" href="https://empregos.org/view.php?job_id=2775446&amp;type=search&amp;auth_sess=e261d448fae3a3354619fe256e5e7e88&amp;ref=1eb1266099101f7ad0ec7796e" title="Oferta: Angariador - More Details">Mais detalhes »</a></b></br></br></p>
#  <p class="posted">Enviado: Ontem - Visualizações: 325</p>
#  </div>
#  </td>,
#  <td>
#  <div class="rownumber"><strong>5003.</strong>
#  <span class="bkm"><input class="radio" name="job_id[]" type="checkbox" value="2775445"/> </span>
#  </div>
#  <div class="results phpjob_listbgcolor21">
#  <h2><a href="https://empregos.org/view.php?job_id=2775445&amp;type=search&amp;auth_sess=e261d448fae3a3354619fe256e5e7e88&amp;ref=1eb1266099101f7ad0ec7796e" title="Anúncio de emprego: Condutor de Empilhadores (MF)">Anúncio de emprego: Condutor de Empilhadores (MF)</a></h2>
#  <p class="desc"><a class="hilink" href="https://empregos.org/view.php?company_id=46970&amp;type=search&amp;auth_sess=e261d448fae3a3354619fe256e5e7e88&amp;ref=1eb1266099101f7ad0ec7796e" title="Lusofinsa">Lusofinsa</a> - Viseu - Viseu<br>
#  		Descrição: Oferta: <h4>Condutor de Empilhadores (MF)</h4>   <b>»</b>  Lusofinsa                                  <br>  &amp;nbsp... <a class="hilink" href="https://empregos.org/view.php?job_id=2775445&amp;type=search&amp;auth_sess=e261d448fae3a3354619fe256e5e7e88&amp;ref=1eb1266099101f7ad0ec7796e" title="Anúncio de emprego: Condutor de Empilhadores (MF) - More Details">Mais detalhes »</a></br></br></p>
#  <p class="posted">Enviado: Ontem - Visualizações: 361</p>
#  </div>
#  </td>,
#  <td>
#  <div class="rownumber"><strong>5004.</strong>
#  <span class="bkm"><input class="radio" name="job_id[]" type="checkbox" value="2775444"/> </span>
#  </div>
#  <div class="results phpjob_listbgcolor11">
#  <h2><a href="https://empregos.org/view.php?job_id=2775444&amp;type=search&amp;auth_sess=e261d448fae3a3354619fe256e5e7e88&amp;ref=1eb1266099101f7ad0ec7796e" title="Oferta: Vigilantes - Viseu">Oferta: Vigilantes - Viseu</a></h2>
#  <p class="desc"><a class="hilink" href="https://empregos.org/view.php?company_id=179956&amp;type=search&amp;auth_sess=e261d448fae3a3354619fe256e5e7e88&amp;ref=1eb1266099101f7ad0ec7796e" title="RH Forma - Formação e Consultoria, Lda.">RH Forma - Formação e Consultoria, Lda.</a> - Viseu - Viseu<br>
#  		Descrição: <h4>Vigilantes - Viseu</h4>   <b>»</b>  RH Forma - Formação e Consultoria, Lda.                                  <br/>&amp;nbsp... <a class="hilink" href="https://empregos.org/view.php?job_id=2775444&amp;type=search&amp;auth_sess=e261d448fae3a3354619fe256e5e7e88&amp;ref=1eb1266099101f7ad0ec7796e" title="Oferta: Vigilantes - Viseu - More Details">Mais detalhes »</a></br></p>
#  <p class="posted">Enviado: Ontem - Visualizações: 403</p>
#  </div>
#  </td>,
#  <td>
#  <div class="rownumber"><strong>5005.</strong>
#  <span class="bkm"><input class="radio" name="job_id[]" type="checkbox" value="2775443"/> </span>
#  </div>
#  <div class="results phpjob_listbgcolor21">
#  <h2><a href="https://empregos.org/view.php?job_id=2775443&amp;type=search&amp;auth_sess=e261d448fae3a3354619fe256e5e7e88&amp;ref=1eb1266099101f7ad0ec7796e" title="Oferta: Engenheiro(a) Eletrotécnico(a)  Produção (Catenária)">Oferta: Engenheiro(a) Eletrotécnico(a)  Produção (Catenária)</a></h2>
#  <p class="desc"><a class="hilink" href="https://empregos.org/view.php?company_id=92751&amp;type=search&amp;auth_sess=e261d448fae3a3354619fe256e5e7e88&amp;ref=1eb1266099101f7ad0ec7796e" title
amp;type=search&amp;auth_sess=e261d448fae3a3354619fe256e5e7e88&amp;ref=1eb1266099101f7ad0ec7796e" title="Oferta de emprego: Operários (Centro de Limpeza de Neve) - More Details">Mais detalhes »</a></p>
#  <p class="posted">Enviado: Ontem - Visualizações: 203</p>
#  </div>
#  </td>,
#  <td>
#  <div class="rownumber"><strong>5050.</strong>
#  <span class="bkm"><input class="radio" name="job_id[]" type="checkbox" value="2775398"/> </span>
#  </div>
#  <div class="results phpjob_listbgcolor11">
#  <h2><a href="https://empregos.org/view.php?job_id=2775398&amp;type=search&amp;auth_sess=e261d448fae3a3354619fe256e5e7e88&amp;ref=1eb1266099101f7ad0ec7796e" title="Anúncio de emprego: Vigilantes - Guarda">Anúncio de emprego: Vigilantes - Guarda</a></h2>
#  <p class="desc"><a class="hilink" href="https://empregos.org/view.php?company_id=179956&amp;type=search&amp;auth_sess=e261d448fae3a3354619fe256e5e7e88&amp;ref=1eb1266099101f7ad0ec7796e" title="RH Forma - Formação e Consultoria, Lda.">RH Forma - Formação e Consultoria, Lda.</a> - Guarda - Guarda<br/>
#  		Descrição: <h4>Vigilantes - Guarda</h4>   <b>»</b>  RH Forma - Formação e Consultoria, Lda.                                  <br/>&amp;nbsp... <a class="hilink" href="https://empregos.org/view.php?job_id=2775398&amp;type=search&amp;auth_sess=e261d448fae3a3354619fe256e5e7e88&amp;ref=1eb1266099101f7ad0ec7796e" title="Anúncio de emprego: Vigilantes - Guarda - More Details">Mais detalhes »</a></p>
#  <p class="posted">Enviado: Ontem - Visualizações: 218</p>
#  </div>
#  </td>]

# %% [markdown]
# # Prototype the model with a single record

# %%
card = cards[0]
card
# Out:
# <td>
# <div class="rownumber"><strong>5001.</strong>
# <span class="bkm"><input class="radio" name="job_id[]" type="checkbox" value="2775447"/> </span>
# </div>
# <div class="results phpjob_listbgcolor21">
# <h2><a href="https://empregos.org/view.php?job_id=2775447&amp;type=search&amp;auth_sess=e261d448fae3a3354619fe256e5e7e88&amp;ref=1eb1266099101f7ad0ec7796e" title="Anúncio de emprego: Pizzaiolo M/F para Viseu em Pizzaria conceituada.">Anúncio de emprego: Pizzaiolo M/F para Viseu em Pizzaria conceituada.</a></h2>
# <p class="desc"><a class="hilink" href="https://empregos.org/view.php?company_id=59997&amp;type=search&amp;auth_sess=e261d448fae3a3354619fe256e5e7e88&amp;ref=1eb1266099101f7ad0ec7796e" title="GWF">GWF</a> - Viseu - Viseu<br>
# 		Descrição: <h4>Pizzaiolo M/F para Viseu em Pizzaria conceituada.</h4>   <b>»</b>  GWF                                  <br> &amp;nbsp... <a class="hilink" href="https://empregos.org/view.php?job_id=2775447&amp;type=search&amp;auth_sess=e261d448fae3a3354619fe256e5e7e88&amp;ref=1eb1266099101f7ad0ec7796e" title="Anúncio de emprego: Pizzaiolo M/F para Viseu em Pizzaria conceituada. - More Details">Mais detalhes »</a></br></br></p>
# <p class="posted">Enviado: Ontem - Visualizações: 328</p>
# </div>
# </td>

# %%
jobUrl = card.a['href']
jobUrl
# Out:
# 'https://empregos.org/view.php?job_id=2775447&type=search&auth_sess=e261d448fae3a3354619fe256e5e7e88&ref=1eb1266099101f7ad0ec7796e'

# %%
jobTitle = card.a['title']
jobTitle
# Out:
# 'Anúncio de emprego: Pizzaiolo M/F para Viseu em Pizzaria conceituada.'

# %%
shortSummary = card.p.text.strip().replace('\n', ' ').replace('\t', ' ').replace('\xa0',' ')
shortSummary
# Out:
# 'GWF - Viseu - Viseu   Descrição: Pizzaiolo M/F para Viseu em Pizzaria conceituada.   »  GWF                                   &nbsp... Mais detalhes »'

# %% [markdown]
# # Get Full Job Description and Remaining Details

# %%
response = requests.get(jobUrl)
soup = BeautifulSoup(response.text, 'html.parser')
ref = soup.find('div', {'id':'idviewjob'})

# %%
jobTitle = ref.h3.string
jobTitle
# Out:
# 'Vem ser mais connosco! Muda a tua vida!'

# %%
jobDescription = ref.p.text.strip()
jobDescription
# Out:
# 'Pizzaiolo M/F para Viseu em Pizzaria conceituada.\xa0\xa0\xa0»  GWF                                  \xa0\xa0\xa0»  21-4-2021                          \xa0\xa0\xa0» Ref: 7369506                                                                  \xa0\xa0\xa0»   Viseu                                  \xa0\xa0\xa0»  Restauração / Bares / Pastelarias                                                        Detalhe da Oferta:                      \x95   Competências o   Experiência em funções similares; o   Domínio da língua Portuguesa; o   Conhecimentos de HACCP; o   Flexibilidade de horário; o   Espírito de equipa; o   Capacidade de aprendizagem. \x95   Responsabilidades o   Abertura de  massa, os recheios, o tempero e os aperitivos que acompanham uma pizza; o   Garantir a qualidade e o sabor do alimento, bem como o aspecto; o   Confecionar pizzas em forno a lenha; o   Limpar e higienizar toda a zona de trabalho. \x95   Benefícios Contrato de trabalho 9 meses; Formação inicial; Remuneração compatível com a função;  2 Folgas semanais;  Integração em equipa jovem e dinâmica. Referência da oferta: para *** Candidatura Online ***  com a ref: Pizzaiolo Viseu Mais Ofertas de Emprego Semelhantes:'

# %%
jobCategory = ref.table.find_all('td', 'col2')[0].text.replace('\xa0', ' ').split('[',1)[0][:-1]
languageReq = ref.table.find_all('td', 'col2')[1].text.strip()
jobType = ref.table.find_all('td', 'col2')[2].text.strip()
salary = ref.table.find_all('td', 'col2')[3].text.strip()
academicReq = ref.table.find_all('td', 'col2')[4].text.strip()
experienceYears = ref.table.find_all('td', 'col2')[5].text.strip()
jobLocation = ref.table.find_all('td', 'col2')[6].text.strip()
jobAdress = ref.find_all('td', 'view')[0].text.strip()
jobPostalCode = ref.find_all('td', 'view')[1].text.strip()
companyType = ref.find_all('tr')[9].contents[3].text.strip()
postDate = ref.table.find_all('td', 'col2')[7].text.strip()

if 'Empresa:' in [i.text.strip() for i in ref.find_all('strong')]:
    company = ref.find_all('a')[1]
else:
    company = ''
    
contactName = ref.table.find_all('td', 'col2')[8].text.strip()
contactEmail = ref.table.find_all('td', 'col2')[9].text.strip()

# %%
ref.find_all('strong')[0].parent.parent.find_all('td')[1].text.strip().replace('\xa0', '').split('[',1)[0]
# Out:
# 'Comercial'

# %%
for i in ref.find_all('strong'):
    id = i.text
    if id == 'Categoria de Emprego:':
        try:
            jobCategory = i.parent.parent.find_all('td')[1].text.strip()
        except AttributeError:
            jobCategory = ''
    elif id == 'Requisitos linguísticos:':
        try:
            languageReq = i.parent.parent.find_all('td')[1].text.strip()
        except AttributeError:
            languageReq = ''
    elif id == 'Tipo de emprego:':
        try:    
            jobType = i.parent.parent.find_all('td')[1].text.strip()
        except AttributeError:
            jobType = ''
    elif id == 'Remuneração:':
        try:
            salary = i.parent.parent.find_all('td')[1].text.strip()
        except AttributeError:
            salary = ''
    elif id == 'Grau académico:':
        try:    
            academicReq = i.parent.parent.find_all('td')[1].text.strip()
        except AttributeError:
            academicReq = ''
    elif id == 'Anos de experiência:':
        try:
            experienceYears = i.parent.parent.find_all('td')[1].text.strip()
        except AttributeError:
            experienceYears = ''
    elif id == 'Localização do emprego:':
        try:
            jobLocation = i.parent.parent.find_all('td')[1].text.strip()
        except AttributeError:
            jobLocation = ''
    elif id == 'Endereço:':
        try:
            jobAdress = i.parent.parent.find_all('td')[1].text.strip()
        except AttributeError:
            jobAdress = ''
    elif id == 'Código postal':
        try:
            jobPostalCode = i.parent.parent.find_all('td')[1].text.strip()
        except AttributeError:
            jobPostalCode = ''
    elif id == 'Benefícios e outras informações:':
        try:
            jobBenefits = i.parent.parent.find_all('td')[1].text.strip()
        except AttributeError:
            jobBenefits = ''
    elif id == 'Tipo de empresa':
        try:    
            companyType = i.parent.parent.find_all('td')[1].text.strip()
        except AttributeError:
            companyType = ''
    elif id == 'Data de publicação:':
        try:
            postDate = i.parent.parent.find_all('td')[1].text.strip()
        except AttributeError:
            postDate = ''
    elif id == 'Empresa:':
        try:
            company = i.parent.parent.find_all('td')[1].text.strip()
        except AttributeError:
            company = ''
    elif id == 'Nome do contacto:':
        try:
            contactName = i.parent.parent.find_all('td')[1].text.strip()
        except AttributeError:
            contactName = ''
    elif id == 'Email de contacto:':
        try:
            contactEmail = i.parent.parent.find_all('td')[1].text.strip()
        except AttributeError:
            contactEmail = ''
    elif id == 'Endereço:':
        try:
            jobAdress = i.parent.parent.find_all('td')[1].text.strip()
        except AttributeError:
            jobAdress = ''
    elif id == 'Telefone:':
        try:
            contactPhone = i.parent.parent.find_all('td')[1].text.strip()
        except AttributeError:
            contactPhone = ''

# %%
jobCategory = ref.table.find_all('td', 'col2')[0].text.replace('\xa0', ' ').split('[',1)[0][:-1]
jobCategory
# Out:
# 'Comercial'

# %%
languageReq = ref.table.find_all('td', 'col2')[1].text.strip()
languageReq
# Out:
# ''

# %%
jobType = ref.table.find_all('td', 'col2')[2].text.strip()
jobType
# Out:
# 'Full Time, Part Time, Estudante, Temporário'

# %%
salary = ref.table.find_all('td', 'col2')[3].text.strip()
salary
# Out:
# '1250 EUR'

# %%
academicReq = ref.table.find_all('td', 'col2')[4].text.strip()
academicReq
# Out:
# 'não especificado'

# %%
experienceYears = ref.table.find_all('td', 'col2')[5].text.strip()
experienceYears
# Out:
# 'Não especificado'

# %%
jobLocation = ref.table.find_all('td', 'col2')[6].text.strip()
jobLocation
# Out:
# 'Setúbal'

# %%
postDate = ref.table.find_all('td', 'col2')[7].text.strip()
postDate
# Out:
# '2021-09-17 / Viewed 13 times'

# %%
contactName = ref.table.find_all('td', 'col2')[8].text.strip()
contactName
# Out:
# 'Daniel Simões'

# %%
contactEmail = ref.table.find_all('td', 'col2')[9].text.strip()
contactEmail
# Out:
# 'daniel.simoes@maisconsultores.pt'

# %%
jobAdress = ref.find_all('td', 'view')[0].text.strip()
jobAdress
# Out:
# 'Rua Casal do Marco n.º 65A'

# %%
jobPostalCode = ref.find_all('td', 'view')[1].text.strip()
jobPostalCode
# Out:
# '2840-731'

# %%
companyType = ref.find_all('tr')[9].contents[3].text.strip()
companyType
# Out:
# 'Recrutador'

# %%
if 'Empresa:' in [i.text.strip() for i in ref.find_all('strong')]:
    company = ref.find_all('a')[1]
else:
    company = ''

company
# Out:
# ''

# %%
def get_jobDescription(jobUrl):
    response = requests.get(jobUrl)
    soup = BeautifulSoup(response.text, 'html.parser')
    ref = soup.find('div', {'id':'idviewjob'})

    # Full job description
    jobDescription = ref.p.text.strip()

    for i in ref.find_all('strong'):
        id = i.text
        if id == 'Categoria de Emprego:':
            try:
                jobCategory = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                jobCategory = ''
        elif id == 'Requisitos linguísticos:':
            try:
                languageReq = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                languageReq = ''
        elif id == 'Tipo de emprego:':
            try:    
                jobType = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                jobType = ''
        elif id == 'Remuneração:':
            try:
                salary = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                salary = ''
        elif id == 'Grau académico:':
            try:    
                academicReq = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                academicReq = ''
        elif id == 'Anos de experiência:':
            try:
                experienceYears = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                experienceYears = ''
        elif id == 'Localização do emprego:':
            try:
                jobLocation = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                jobLocation = ''
        elif id == 'Endereço:':
            try:
                jobAdress = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                jobAdress = ''
        elif id == 'Código postal':
            try:
                jobPostalCode = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                jobPostalCode = ''
        elif id == 'Benefícios e outras informações:':
            try:
                jobBenefits = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                jobBenefits = ''
        elif id == 'Tipo de empresa':
            try:    
                companyType = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                companyType = ''
        elif id == 'Data de publicação:':
            try:
                postDate = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                postDate = ''
        elif id == 'Empresa:':
            try:
                company = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                company = ''
        elif id == 'Nome do contacto:':
            try:
                contactName = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                contactName = ''
        elif id == 'Email de contacto:':
            try:
                contactEmail = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                contactEmail = ''
        elif id == 'Endereço:':
            try:
                jobAdress = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                jobAdress = ''
        elif id == 'Telefone:':
            try:
                contactPhone = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                contactPhone = ''
        else:
            try:
                other = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                other = ''


    dataToAdd = (company, companyType, jobCategory, jobType, salary, jobDescription,   
                 jobLocation, jobAdress, jobPostalCode, languageReq, academicReq, 
                 experienceYears, jobBenefits, postDate, contactName, contactEmail, contactPhone, other)
    return dataToAdd

# %% [markdown]
# # Generalize the Model with a function

# %%
def get_record(card):
    """Extract Job dat from a single record"""
    # Job Url
    jobUrl = card.a['href']

    # Job Title
    jobTitle = card.a['title']
    
    # Short Summary
    shortSummary = card.p.text.strip().replace('\n', ' ').replace('\t', ' ').replace('\xa0',' ')

    # Extract Date
    today = datetime.date.today().strftime('%Y-%m-%d')

    record = (jobUrl, jobTitle, shortSummary, today)
    return record

# %% [markdown]
# # Iterating By Page

# %%
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup.find('div', 'pgright').find_all('a')[-1].get('href')
# Out:
# 'https://empregos.org/jobfind.php?f=50&action=search&auth_sess=783c86b44850879600652e80fb445abf&ref=3d9dcc1e0d8c8a56602367094&bx_jtitle=&rdjt=2&jids[]=00&lids[]=000&bx_prv[]=&bx_plng[]=0&bx_kwd=&rdKeyw=2&bx_minsalary=&bx_maxsalary=&bx_lngids[]=-&rdLang=2&tids[]=0&posted=0&o=1&o_show=4&cmdSearch=++Pesquisar++'

# %%
while True:
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    for card in cards:
        record = get_record()
        records.append(record)

    try:
        url = soup.find('div', 'pgright').find_all('a')[-1].get('href')
    except AttributeError:
        break

# %% [markdown]
# # Putting it all together

# %%
import csv
import datetime as datetime
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time 
import random
import os


def get_url(startPage):
    """Generate URL from position and Location
    :parameter: location -> Country"""
    template = 'https://empregos.org/jobfind.php?f={}&action=search&auth_sess=b32b5c79fb901f90536261a2e302a588&ref=558a97e97b671d3dca7fc7b67&bx_jtitle=&rdjt=2&jids[]=00&lids[]=000&bx_prv[]=&bx_plng[]=0&bx_kwd=&rdKeyw=2&bx_minsalary=&bx_maxsalary=&bx_lngids[]=-&rdLang=2&tids[]=0&posted=0&o=1&o_show=4&cmdSearch=++Pesquisar++'
    url = template.format(startPage)
    return url

def get_jobDescription(jobUrl):

    response = requests.get(jobUrl)
    soup = BeautifulSoup(response.text, 'html.parser')
    try:
        ref = soup.find('div', {'id':'idviewjob'})
    except AttributeError:
        ref = ''

    # If there is no active job description return all blanks - to be dropped in Data Cleaning
    if ref == None or '':
        company, companyType, jobCategory, jobType, salary, jobDescription = '', '', '', '', '', ''
        jobLocation, jobAdress, jobPostalCode, languageReq, academicReq = '', '', '', '', ''
        experienceYears, jobBenefits, postDate, contactName, contactEmail, contactPhone, other = '', '', '', '', '', '', ''

        dataToAdd = (company, companyType, jobCategory, jobType, salary, jobDescription,   
                jobLocation, jobAdress, jobPostalCode, languageReq, academicReq, 
                experienceYears, jobBenefits, postDate, contactName, contactEmail, contactPhone, other)

        return dataToAdd

    # Full job description
    try:
        jobDescription = ref.p.text.strip()
    except AttributeError:
        jobDescription = ''
        
    # initiate all vars
    company, companyType, jobCategory, jobType, salary = '', '', '', '', ''
    jobLocation, jobAdress, jobPostalCode, languageReq, academicReq = '', '', '', '', ''
    experienceYears, jobBenefits, postDate, contactName, contactEmail, contactPhone, other = '', '', '', '', '', '', ''
    

    for i in ref.find_all('strong'):
        id = i.text
        if id == 'Categoria de emprego:':
            try:
                jobCategory = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                jobCategory = ''
        elif id == 'Requisitos linguísticos:':
            try:
                languageReq = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                languageReq = ''
        elif id == 'Tipo de emprego:':
            try:    
                jobType = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                jobType = ''
        elif id == 'Remuneração:':
            try:
                salary = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                salary = ''
        elif id == 'Grau académico:':
            try:    
                academicReq = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                academicReq = ''
        elif id == 'Anos de experiência:':
            try:
                experienceYears = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                experienceYears = ''
        elif id == 'Localização do emprego:':
            try:
                jobLocation = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                jobLocation = ''
        elif id == 'Endereço:':
            try:
                jobAdress = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                jobAdress = ''
        elif id == 'Código postal':
            try:
                jobPostalCode = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                jobPostalCode = ''
        elif id == 'Benefícios e outras informações:':
            try:
                jobBenefits = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                jobBenefits = ''
        elif id == 'Tipo de empresa':
            try:    
                companyType = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                companyType = ''
        elif id == 'Data de publicação:':
            try:
                postDate = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                postDate = ''
        elif id == 'Empresa:':
            try:
                company = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                company = ''
        elif id == 'Nome do contacto:':
            try:
                contactName = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                contactName = ''
        elif id == 'Email de contacto:':
            try:
                contactEmail = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                contactEmail = ''
        elif id == 'Endereço:':
            try:
                jobAdress = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                jobAdress = ''
        elif id == 'Telefone:':
            try:
                contactPhone = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                contactPhone = ''
        else:
            try:
                other = i.parent.parent.find_all('td')[1].text.strip()
            except AttributeError:
                other = ''

    dataToAdd = (company, companyType, jobCategory, jobType, salary, jobDescription,   
                jobLocation, jobAdress, jobPostalCode, languageReq, academicReq, 
                experienceYears, jobBenefits, postDate, contactName, contactEmail, contactPhone, other)

    return dataToAdd
    


def get_record(card):
    """Extract Job dat from a single record"""
    # Job Url
    jobUrl = card.a['href']

    # Job Title
    jobTitle = card.a['title']
    
    # Short Summary
    shortSummary = card.p.text.strip().replace('\n', ' ').replace('\t', ' ').replace('\xa0',' ')

    # Extract Date
    extractDate = datetime.date.today().strftime('%Y-%m-%d')

    dataToAdd = get_jobDescription(jobUrl)

    record = (jobTitle, shortSummary, jobUrl, extractDate) + dataToAdd

    return record

def main(startPage):
    """Run the main program routine"""
    records = []
    url = get_url(startPage)

    # Extract Job Data   
    iter = 0 
    # Break out of loop if waiting time > 3 min
    timeout = time.time() + 60*4
    while True:
        # Random Sleep Time 0 to 1 seconds
        time.sleep(random.random())
        iter += 1

        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        entries = soup.find_all('td')
        cards = entries[12:-2].copy()

        for card in cards:
            record = get_record(card)
            records.append(record)

        try:
            url = soup.find('div', 'pgright').find_all('a')[-1].get('href')
            print(f'Iteration number {iter}')
            if iter == 50 or time.time() > timeout:
                print(url)
                break
        except AttributeError:
            print(url)
            print(f'Number of Iterations was {iter}')
            break

    # Save Job Data
    if os.path.exists('empregoOrg_jobs.csv') == False:
        with open('empregoOrg_jobs.csv', 'w', newline='', encoding='utf-8') as f:
            writer = csv.writer(f)
            writer.writerow(['jobTitle', 'shortSummary', 'jobUrl', 'extractDate', 
                'company', 'companyType', 'jobCategory', 'jobType', 'salary', 'jobDescription',   
                'jobLocation', 'jobAdress', 'jobPostalCode', 'languageReq', 'academicReq', 
                'experienceYears', 'jobBenefits', 'postDate', 'contactName', 'contactEmail', 'contactPhone', 'other'])
            writer.writerows(records)
        f.close()
    else:
        with open('empregoOrg_jobs.csv', 'a+', newline='', encoding='utf-8') as f:
            writer = csv.writer(f)
            writer.writerows(records)
        f.close()
    
    print(f'Scrapped {len(records)} job posting')

# %%
main(startPage=0)
# Out:
# Iteration number 1
# Iteration number 2
# Iteration number 3
# Iteration number 4
# Iteration number 5
# Iteration number 6
# Iteration number 7
# Iteration number 8
# Iteration number 9
# Iteration number 10
# Iteration number 11
# Iteration number 12
# Iteration number 13
# Iteration number 14
# Iteration number 15
# Iteration number 16
# Iteration number 17
# Iteration number 18
# Iteration number 19
# Iteration number 20
# https://empregos.org/jobfind.php?f=1000&action=search&auth_sess=68113a7c8081c425b16034a718557407&ref=ea2fd45810ecf508717f2411b&bx_jtitle=&rdjt=2&jids[]=00&lids[]=000&bx_prv[]=&bx_plng[]=0&bx_kwd=&rdKeyw=2&bx_minsalary=&bx_maxsalary=&bx_lngids[]=-&rdLang=2&tids[]=0&posted=0&o=1&o_show=4&cmdSearch=++Pesquisar++
# Scrapped 1000 job posting

# %%
for i in tqdm(range(5)):
    try:
        start = len(pd.read_csv('empregoOrg_jobs.csv'))
        print(f'Start Page -> {start}')
        main(startPage=start)
        print(f'Total Jobs scraped {start}')
    except:
        break
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# C:\Users\gilnr\Anaconda3\envs\mlcourse\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (7,12,13,16,18,19,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# Start Page -> 65800
# Iteration number 1
# Iteration number 2
# Iteration number 3
# Iteration number 4
# Iteration number 5
# Iteration number 6
# Iteration number 7
# Iteration number 8
# Iteration number 9
# Iteration number 10
# Iteration number 11
# https://empregos.org/jobfind.php?f=66350&action=search&auth_sess=ae35bcf63d88774e5c3e59c110dac496&ref=b87a78fd501513b6a798f790a&bx_jtitle=&rdjt=2&jids[]=00&lids[]=000&bx_prv[]=&bx_plng[]=0&bx_kwd=&rdKeyw=2&bx_minsalary=&bx_maxsalary=&bx_lngids[]=-&rdLang=2&tids[]=0&posted=0&o=1&o_show=4&cmdSearch=++Pesquisar++

# %%
print(f'Number of scraped Job Ads -> {len(pd.read_csv("empregoOrg_jobs.csv"))}')
pd.read_csv('empregoOrg_jobs.csv')
# Out:
# Number of scraped Job Ads -> 65800
#                                                 jobTitle  \
# 0                                       Gestor Comercial
# 1                             Consultor Negócios - Porto
# 2                  Gestor de Cliente Imobiliário ( m/f )
# 3      Part-Time - Possibilidade de teletrabalho - Mí...
# 4      Comercial C/ ou S/ Experiência Imobiliário 50%...
# ...                                                  ...
# 65795  Oferta: Precisa-se Empregado de Mesa (part tim...
# 65796  Oferta de emprego: Precisa-se Copeiro(a) para ...
# 65797  Oferta: Precisa-se Ajudante de Cozinha para Re...
# 65798  Oferta: Operadores de valores (M/F) AÇORES Ful...
# 65799  Oferta de emprego: Precisa-se Casal para Empre...
#
#                                             shortSummary  \
# 0      century21 - Lisboa - Lisboa - Lisboa   Descriç...
# 1      Maxgroup - Porto   Descrição: Está à procura d...
# 2      Pole Position Lda - Lisboa - Lisboa   Descriçã...
# 3      - Setúbal   Descrição: Gostava de poder mudar ...
# 4      - Setúbal   Descrição: Gostava de poder mudar ...
# ...                                                  ...
# 65795  Forneria São Dinis - Restauração, Lda - Outro ...
# 65796  Forneria São Dinis - Restauração, Lda - Outro ...
# 65797  Forneria São Dinis - Restauração, Lda - Outro ...
# 65798  ESEGUR - Outro - Outro   Descrição: Operadores...
# 65799  Confidencial - Outro - Outro   Descrição: Prec...
#
#                                                   jobUrl extractDate  \
# 0      https://empregos.org/view.php?job_id=2796393&t...  2021-09-18
# 1      https://empregos.org/view.php?job_id=2796392&t...  2021-09-18
# 2      https://empregos.org/view.php?job_id=2796391&t...  2021-09-18
# 3      https://empregos.org/view.php?job_id=2796390&t...  2021-09-18
# 4      https://empregos.org/view.php?job_id=2796389&t...  2021-09-18
# ...                                                  ...         ...
# 65795  https://empregos.org/view.php?job_id=2790489&t...  2021-09-20
# 65796  https://empregos.org/view.php?job_id=2790488&t...  2021-09-20
# 65797  https://empregos.org/view.php?job_id=2790487&t...  2021-09-20
# 65798  https://empregos.org/view.php?job_id=2790486&t...  2021-09-20
# 65799  https://empregos.org/view.php?job_id=2790485&t...  2021-09-20
#
#                                      company companyType  \
# 0                                  century21  Empregador
# 1                                   Maxgroup  Empregador
# 2                          Pole Position Lda  Empregador
# 3                                        NaN  Recrutador
# 4                                        NaN  Recrutador
# ...                                      ...         ...
# 65795  Forneria São Dinis - Restauração, Lda  Empregador
# 65796  Forneria São Dinis - Restauração, Lda  Empregador
# 65797  Forneria São Dinis - Restauração, Lda  Empregador
# 65798                                 ESEGUR  Empregador
# 65799                           Confidencial  Empregador
#
#                                              jobCategory  \
# 0       Comercial [ Ver todos os empregos de Comercial ]
# 1      Imobiliário [ Ver todos os empregos de Imobili...
# 2       Comercial [ Ver todos os empregos de Comercial ]
# 3       Comercial [ Ver todos os empregos de Comercial ]
# 4       Comercial [ Ver todos os empregos de Comercial ]
# ...                                                  ...
# 65795         Outras [ Ver todos os empregos de Outras ]
# 65796         Outras [ Ver todos os empregos de Outras ]
# 65797         Outras [ Ver todos os empregos de Outras ]
# 65798         Outras [ Ver todos os empregos de Outras ]
# 65799         Outras [ Ver todos os empregos de Outras ]
#
#                                            jobType               salary  \
# 0                                        Full Time  15.000 a 25.000 EUR
# 1                            Full Time, Permanente       25.000 Ano EUR
# 2                                        Full Time     Não especificado
# 3      Full Time, Part Time, Estudante, Temporário             1250 EUR
# 4      Full Time, Part Time, Estudante, Temporário             1250 EUR
# ...                                            ...                  ...
# 65795                                          NaN     Não especificado
# 65796                                          NaN     Não especificado
# 65797                                          NaN     Não especificado
# 65798                                          NaN     Não especificado
# 65799                                          NaN     Não especificado
#
#                                           jobDescription  ...   jobPostalCode  \
# 0                View century21 profile and job listings  ...        1500-506
# 1      Está à procura de um Novo Desafio?\r\nValoriza...  ...  4000-238 Porto
# 2      S E J A C E N T U R Y 2 1. S E J A P O L E P O...  ...        2720-306
# 3      Gostava de poder mudar a sua vida? De poder te...  ...        2840-731
# 4      Gostava de poder mudar a sua vida? De poder te...  ...        2840-731
# ...                                                  ...  ...             ...
# 65795  Precisa-se Empregado de Mesa (part time) para ...  ...             NaN
# 65796  Precisa-se Copeiro(a) para Restaurante de Reno...  ...             NaN
# 65797  Precisa-se Ajudante de Cozinha para Restaurant...  ...             NaN
# 65798  Operadores de valores (M/F) AÇORES Full-Time  ...  ...             NaN
# 65799  Precisa-se Casal para Empregado de Mesa/Bar e ...  ...             NaN
#
#       languageReq       academicReq   experienceYears  \
# 0             NaN  não especificado  Não especificado
# 1             NaN  não especificado  Não especificado
# 2             NaN  não especificado  Não especificado
# 3             NaN  não especificado  Não especificado
# 4             NaN  não especificado  Não especificado
# ...           ...               ...               ...
# 65795         NaN  não especificado  Não especificado
# 65796         NaN  não especificado  Não especificado
# 65797         NaN  não especificado  Não especificado
# 65798         NaN  não especificado  Não especificado
# 65799         NaN  não especificado  Não especificado
#
#                                              jobBenefits  \
# 0      Formação de iniciação gratuita \r\nPlano de ...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 65795                                                NaN
# 65796                                                NaN
# 65797                                                NaN
# 65798                                                NaN
# 65799                                                NaN
#
#                             postDate         contactName  \
# 0      2021-09-18 / Viewed 390 times  CENTURY 21 Colombo
# 1      2021-09-18 / Viewed 216 times       Daniel Renato
# 2      2021-09-18 / Viewed 469 times           Ana Simal
# 3      2021-09-18 / Viewed 485 times       Daniel Simões
# 4      2021-09-18 / Viewed 222 times       Daniel Simões
# ...                              ...                 ...
# 65795  2021-09-03 / Viewed 165 times                 NaN
# 65796  2021-09-03 / Viewed 139 times                 NaN
# 65797  2021-09-03 / Viewed 137 times                 NaN
# 65798  2021-09-03 / Viewed 142 times                 NaN
# 65799  2021-09-03 / Viewed 146 times                 NaN
#
#                            contactEmail          contactPhone  \
# 0               rh.colombo@century21.pt             217106180
# 1                      drenato@remax.pt             963014877
# 2          anaisabel.simal@century21.pt           215 806 787
# 3      daniel.simoes@maisconsultores.pt                   NaN
# 4      daniel.simoes@maisconsultores.pt                   NaN
# ...                                 ...                   ...
# 65795                               NaN                   NaN
# 65796                               NaN                   NaN
# 65797                               NaN                   NaN
# 65798                               NaN  219491151||219491180
# 65799                               NaN                   NaN
#
#                                                    other
# 0      Envie-nos o seu CV atualizado para rh.colombo@...
# 1                                      talent_27_08_2021
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 65795                                                NaN
# 65796                                                NaN
# 65797                                                NaN
# 65798                                                NaN
# 65799                                                NaN
#
# [65800 rows x 22 columns]
