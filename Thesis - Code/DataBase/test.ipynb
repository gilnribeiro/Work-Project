# %%
import pandas as pd
from mongoDb_functions import Database
from pymongo import MongoClient
from config import USERNAME, PASSWORD, DEFAULT_DB, DEFAULT_CLUSTER

# %%
D = Database(USERNAME, PASSWORD, DEFAULT_DB, DEFAULT_CLUSTER)

# %%
items = D.pull_data('jobsdb', 'Job Vacancies')

# %%
D.client
# Out:
# MongoClient(host=['cluster0-shard-00-02.ohzpo.mongodb.net:27017', 'cluster0-shard-00-01.ohzpo.mongodb.net:27017', 'cluster0-shard-00-00.ohzpo.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-xlbrkp-shard-0', ssl=True, ssl_cert_reqs=<VerifyMode.CERT_NONE: 0>)

# %%
df = pd.DataFrame(items)

# %%
df
# Out:
#                            _id  \
# 0     61621d47a32af59d8d38a6e1
# 1     61621d47a32af59d8d38a6e2
# 2     61621d47a32af59d8d38a6e3
# 3     61621d47a32af59d8d38a6e4
# 4     61621d47a32af59d8d38a6e5
# ...                        ...
# 3885  61621d47a32af59d8d38b60e
# 3886  61621d47a32af59d8d38b60f
# 3887  61621d47a32af59d8d38b610
# 3888  61621d47a32af59d8d38b611
# 3889  61621d47a32af59d8d38b612
#
#                                               job_title  \
# 0                                   TIBCO EAI Developer
# 1     Software Engineer - Fullstack Javascript Devel...
# 2                            Software Automation Tester
# 3                           Analista de Privacidade  IT
# 4                               .NET Software Developer
# ...                                                 ...
# 3885                                       BI w/ Python
# 3886                             Analyst Developer JAVA
# 3887                            Senior Product Designer
# ...
