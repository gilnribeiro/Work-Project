# %%
import requests
from w3lib.html import remove_tags

# %%
session = requests.Session()
session.get(f'https://landing.jobs/api/v1/jobs?limit=50&offset=0').json()
# Out:
# [{'id': 2586,
#   'city': 'Lisbon',
#   'company_id': 256,
#   'country_code': 'PT',
#   'country_name': 'Portugal',
#   'currency_code': 'EUR',
#   'expires_at': '2021-10-15',
#   'main_requirements': '<ul><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="1" data-aria-level="1">MSc / BSc in Information Systems and Computer Engineering&nbsp;and/or Computer Science&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="2" data-aria-level="1"><strong>Advanced knowledge on Linux</strong>&nbsp;operating systems&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="3" data-aria-level="1"><strong>Large&nbsp;Experience (3+ years)</strong>&nbsp;as Java based technology full stack developer/Engineer.&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="4" data-aria-level="1">Strong Experience&nbsp;while developing with&nbsp;<strong>JavaScript</strong>&nbsp;and its superset,&nbsp;<strong>Typescript</strong>&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="5" data-aria-level="1">Deep understanding of web markup, including&nbsp;<strong>HTML</strong><strong>&nbsp;</strong><strong>and CSS</strong>&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="5" data-aria-level="1">Experience with&nbsp;JavaScript libraries and frameworks such as&nbsp;and&nbsp;/or&nbsp;Angular&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="5" data-aria-level="1">Experience with&nbsp;<strong>Java based technologies</strong>&nbsp;(JBoss, Tomcat, Glassfish Spring Boot, Spring MVC, Hibernate)&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="5" data-aria-level="1">Experience of&nbsp;<strong>design patterns</strong>&nbsp;while&nbsp;implementing&nbsp;advanced&nbsp;and complex&nbsp;software solutions.&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="5" data-aria-level="1">Experience with&nbsp;<strong>relational databases</strong>&nbsp;(MS&nbsp;SQL&nbsp;Server, MySQL,&nbsp;PostgreSQL&nbsp;etc.)&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="5" data-aria-level="1">Experience in design patterns while implementing&nbsp;large scale&nbsp;and complex software solutions.&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="5" data-aria-level="1">Strong experience in using&nbsp;<strong>Eclipse, Maven, Jenkins, GIT, JIRA</strong>&nbsp;or equivalent tools&nbsp;</li><li><strong>Strong communication skills</strong>&nbsp;(written and spoken).&nbsp;</li></ul>',
#   'nice_to_have': '<ul><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="2" data-aria-level="1">Knowledge or experience with&nbsp;<strong>Docker/Kubernetes</strong>&nbsp;ecosystem</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="3" data-aria-level="1">Knowledge or experience with&nbsp;microservices based architectures</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="5" data-aria-level="1">Team player&nbsp;and problem solving skills<br></li></ul>',
#   'perks': '<p>Besides a competitive salary and a variable bonus program according to the performance, we have a number of other benefits:</p><ul><li>Flexible work hours and partial remote work</li><li>Relaxed work environment</li><li>Fruit and coffee available</li><li>Health insurance</li><li>Training plan, adjusted to individual needs</li><li>Social and team building events</li><li>Areas for leisure within the facilities</li></ul>',
#   'referral_value': '275.0',
#   'relocation_paid': False,
#   'role_description': '<p><strong>ABOUT US</strong></p><p>&nbsp;<br></p><p>Everything we do is to&nbsp;<strong>inspire others</strong>&nbsp;to achieve outstanding results. We do this by investing in IT mastery to generate market value. As a global company specializing in&nbsp;<strong>Big Data</strong>,&nbsp;<strong>Business Intelligence &amp; Analytics</strong>,&nbsp;<strong>Data Science</strong>,&nbsp;<strong>Middleware</strong>,&nbsp;<strong>Digital&nbsp;</strong><strong>Xperiences</strong>, and&nbsp;<strong>Collaboration and Development tools</strong>, we have top products and services used by Fortune 500 companies.&nbsp;With a posture of honesty and cooperation with more than 180 clients in the service area&nbsp;and more than 3000 that use our products in 76 different countries, Xpand IT is recognized for its technological knowledge and&nbsp;<strong>“Passion for Excellence”</strong>.</p><p>At Xpand IT,&nbsp;<strong>everyone has a special talent</strong>. We value everyone’s talent in all fields. Excellent technical experts, visionary designers,&nbsp;dynamic and communicative Human Resources team, innovative researchers, magical marketers, entrepreneurial managers. These are the people that are part of&nbsp;<strong>Xpand IT.<br></strong>&nbsp;<br></p><p><strong>ABOUT THE JOB<br><br></strong></p><p>As a Java Full-stack developer you will build the end-to-end interactions within web and software applications. As part of your mission, you’ll design plans for the user interface, define controls’&nbsp;look &amp; feel and&nbsp;activity. You’ll&nbsp;also structure the backbone&nbsp;part of an application, which manages program middleware&nbsp;logic&nbsp;and database server(s)&nbsp;interactions. Full-stack developers understand what&nbsp;happens&nbsp;between these two (or more) layers and have the set of software skills needed to work on both.&nbsp;</p><p>At Xpand IT, full-stack developers are&nbsp;also&nbsp;problem-solvers who work in a fast-paced, collaborative environment alongside other experts such as UI/UX and cluster/database gurus.&nbsp;</p><p><strong><br><br></strong><strong>JOB DESCRIPTION/ACTIVITIES</strong></p><ul><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="37" data-aria-posinset="1" data-aria-level="1">Use /&nbsp;suggest a variety of<strong>&nbsp;state-of-the-art programming languages in order to create user-friendly web interfaces</strong><strong>&nbsp;</strong></li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="37" data-aria-posinset="2" data-aria-level="1">Design and build&nbsp;<strong>high-quality mockup</strong>s and design different prototypes.&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="37" data-aria-posinset="3" data-aria-level="1"><strong>Optimize web applications</strong>&nbsp;for maximum speed, cross-browser and cross-device&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="37" data-aria-posinset="3" data-aria-level="1">Build reusable code and libraries for future use&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="37" data-aria-posinset="3" data-aria-level="1">Work in a multidisciplinary\u202fteam with other teammates such as backend developers and web designers&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="37" data-aria-posinset="3" data-aria-level="1">Being Responsible for&nbsp;<strong>requirements definition</strong>&nbsp;and translate them into technical services.&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="37" data-aria-posinset="3" data-aria-level="1">Design and development&nbsp;of applicational backend services using the best design practices and&nbsp;patterns&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="37" data-aria-posinset="3" data-aria-level="1"><strong>Recommend system solutions</strong>&nbsp;by comparing advantages and disadvantages of&nbsp;alternative&nbsp;development strategies.&nbsp;</li><li data-leveltext="\uf0b7" data-f ...
#   'title': 'Java Full-stack Developer',
#   'created_at': '2016-11-29T15:30:52.191Z',
#   'updated_at': '2021-10-08T00:00:21.091Z',
#   'published_at': '2020-05-13T09:01:28.506Z',
#   'type': 'Full-time',
#   'remote': True,
#   'tags': ['TypeScript', 'JavaScript', 'Linux', 'Git', 'JIRA', 'Java'],
#   'url': 'https://landing.jobs/at/xpand-it/java-full-stack-developer-in-lisbon-2020'},
#  {'id': 3333,
#   'city': 'Lisbon',
#   'company_id': 256,
#   'country_code': 'PT',
#   'country_name': 'Portugal',
#   'currency_code': 'EUR',
#   'expires_at': '2021-10-13',
#   'main_requirements': '<ul><li>MSc / BSc in Information Systems and Computer Engineering&nbsp;and/or Computer Science</li><li><strong>Professional experience (+ 3 years)</strong>&nbsp;as a<strong>&nbsp;Developer in JavaScript-based technologies, HTML5 and CSS3</strong></li><li>Experience with JavaScript libraries and frameworks such as&nbsp;<strong>React and /or Angular</strong></li><li>Experience with backend JavaScript frameworks such as&nbsp;<strong>Node.js</strong></li><li>Experience in&nbsp;design patterns while implementing advanced<strong>&nbsp;and complex software solutions</strong>, namely in API Rest services implementation</li><li>Experience in data base management tools like&nbsp;<strong>MS SQL Server, MySQL or PostgreSQL</strong></li><li>Experience in using&nbsp;Eclipse, Maven, Jenkins, GIT, JIRA&nbsp;or equivalent tools</li><li><strong>Team player</strong>&nbsp;and technical problem solving skills</li><li>Strong communication skills&nbsp;(written and spoken)</li><li>English proficiency<br></li></ul>',
#   'nice_to_have': '<p><br data-mce-bogus="1"></p>',
#   'perks': '<p>Besides a competitive salary and a variable bonus program according to the performance, we have a number of other benefits:</p><ul><li>Flexible work hours and partial remote work</li><li>Relaxed work environment</li><li>Fruit and coffee available</li><li>Health insurance</li><li>Training plan, adjusted to individual needs</li><li>Opportunity to work on challenging projects in different locations</li><li>Social and team building events</li><li>Areas for leisure within the facilities</li><li>Protocols and other local benefits</li></ul>',
#   'referral_value': '300.0',
#   'relocation_paid': False,
#   'role_description': '<p><strong>ABOUT US…</strong></p><p>Everything we do is to&nbsp;inspire others to&nbsp;<strong>achieve outstanding results.</strong>&nbsp;We do this by investing in IT mastery to generate market value. As a global company specializing in&nbsp;<strong>Big Data,&nbsp;Business Intelligence &amp; Analytics,&nbsp;Data Science,&nbsp;Middleware,&nbsp;Digital Xperiences, and&nbsp;Collaboration and Development tools</strong>, we have top products and services used by Fortune 500 companies.&nbsp;With a posture of honesty and cooperation with more than 180 clients in the service area&nbsp;and more than 3000 that use our products in 76 different countries, Xpand IT is recognized for its technological knowledge and “<strong>Passion for Excellence</strong>”.</p><p>At Xpand IT,&nbsp;<strong>everyone has a special talent</strong>. We value everyone’s talent in all fields. Excellent technical experts, visionary designers,&nbsp;dynamic and communicative Human Resources team, innovative researchers, magical marketers, entrepreneurial managers. These are the people that are part of&nbsp;<strong>Xpand IT.<br></strong></p><p><strong>ABOUT THE JOB</strong></p><p>As a JavaScript Full-stack Developer you will&nbsp;<strong>build the end-to-end applications requirements</strong>. You will participate in the central structure of an application as well as<strong>&nbsp;create design plans for the user interface, define controls’ look, feel and activity.</strong>&nbsp;At Xpand IT you will work with JavaScript technologies in a collaborative environment alongside other experts such as UI/UX and cluster/database gurus.<br></p><p><strong>JOB DESCRIPTION / ACTIVITIES</strong></p><ul><li><strong>Being responsible for requirements definition</strong>&nbsp;and translate them into technical services</li><li>Use / suggest a variety of state-of-the-art programming languages in order to&nbsp;<strong>create user-friendly web interfaces</strong></li><li>Design and build&nbsp;<strong>high-quality mockups</strong>&nbsp;and design different prototypes</li><li>Optimize web applications for&nbsp;maximum speed, cross-browser and cross-device</li><li><strong>Build reusable API libraries</strong>&nbsp;for future use</li><li>Work in multidisciplinary&nbsp;teams&nbsp;with other teammates such as&nbsp;backend developers&nbsp;and&nbsp;web designers</li><li>Design and development of<strong>&nbsp;applicational backend services</strong>&nbsp;using the best design practices and patterns</li><li>Recommends system solutions by&nbsp;comparing advantages and disadvantages&nbsp;of alternative development strategies</li><li>Integrates applications through the&nbsp;<strong>development of APIs / Services</strong>&nbsp;with third-party modules</li><li>Guarantee the correct&nbsp;<strong>performance, security and scalability of backend services</strong></li><li>Guarantee that&nbsp;<strong>Unit Test / Test Sets</strong>&nbsp;are correctly updated so that Continuous Integration engine remains flawless.<br><br></li></ul><p><span contenteditable="false" data-mce-object="iframe" class="mce-preview-object mce-object-iframe" data-mce-p-allowfullscreen="allowfullscreen" data-mce-p-src="//www.youtube.com/embed/EvUbt7fpU5A"><iframe src="//www.youtube.com/embed/EvUbt7fpU5A" allowfullscreen="allowfullscreen" width="560" height="314" frameborder="0"></iframe><span class="mce-shim"></span></span></p><p>&nbsp;<br></p>',
#   'title': 'JavaScript Full-stack Developer',
#   'created_at': '2017-04-07T12:03:21.341Z',
#   'updated_at': '2021-10-08T00:00:31.662Z',
#   'published_at': '2020-12-28T14:38:00.024Z',
#   'type': 'Full-time',
#   'remote': True,
#   'tags': ['React',
#    'AngularJS',
#    'SQL Server',
#    'Scrum',
#    'Node.js',
#    'JavaScript'],
#   'url': 'https://landing.jobs/at/xpand-it/javascript-full-stack-developer-in-lisbon-2020'},
#  {'id': 5524,
#   'city': 'Berlin',
#   'company_id': 2502,
#   'country_code': 'DE',
#   'country_name': 'Germany',
#   'currency_code': 'EUR',
#   'expires_at': '2021-10-19',
#   'main_requirements': '* Experience in C++ (we use C++11 features like lambdas and rvalue references throughout our codebase and switch to C++14 where our compilers support it)\r\n* Bachelor´s Degree or higher\r\n* Advanced English level',
#   'nice_to_have': '',
#   'perks': "* healthy work-life balance - we do not work at night or on weekends\r\n* support of our staff's families with a full-time company nanny - she is available for free when children are sick, or when you just feel like spending an evening out\r\n* competitive salaries + EUR 120,000 annually following one year of employment\r\n* help with Relocation and work permit\r\n* International and diverse Team\r\n* German language courses\r\n* Food, drinks, snack around the office",
#   'referral_value': '300.0',
#   'relocation_paid': True,
#   'role_description': '**About us**\r\n\r\nthink-cell is the leading developer of graphics software to improve professional slide production in Microsoft PowerPoint. Our software automates the creation of charts and layouts to make working with PowerPoint easier, faster, and more enjoyable.\r\n\r\nWe have published scientific articles in the areas of Artificial Intelligence and Computer Graphics and we will encourage you to do the same. We sponsor visits to conferences and have close relationships with universities and research institutes in the U.S. and Germany.\r\n\r\n**Your role**\r\n\r\nWe are looking for smart, creative developers with a solid theoretical background.\r\n\r\n* You will work largely independently and will be responsible for the whole range of activities when implementing a new feature\r\n* You will be in control of your own work. Instead of splitting different activities between several people, you will involved in all: architecture, design, implementation, customer feedback and bug fixing\r\n* You should be able to look at a problem from the user\'s perspective and discuss abstract concepts with fellow developers\r\n\r\n<span contenteditable="false" data-mce-object="iframe" class="mce-preview-object mce-object-iframe" data-mce-p-allowfullscreen="allowfullscreen" data-mce-p-src="//www.youtube.com/embed/SX6vGFLghJo"><iframe src="//www.youtube.com/embed/SX6vGFLghJo" allowfullscreen="allowfullscreen" width="560" height="314" frameborder="0"></iframe> <span class="mce-shim"></span></span>\r\n\r\n* * *',
#   'title': 'C++ Developer',
#   'created_at': '2018-05-25T15:11:24.712Z',
#   'updated_at': '2021-10-08T00:00:21.440Z',
#   'published_at': '2020-03-05T11:21:27.975Z',
#   'type': 'Full-time',
#   'remote': False,
#   'gross_salary_low': 75000,
#   'gross_salary_high': 120000,
#   'tags': ['Software Development', 'C++'],
#   'url': 'https://landing.jobs/at/think-cell/c-developer-in-berlin'},
#  {'id': 5694,
#   'city': 'Berlin',
#   'company_id': 2593,
#   'country_code': 'DE',
#   'country_name': 'Germany',
#   'currency_code': 'EUR',
#   'expires_at': '2021-10-24',
#   'main_requirements': '<ul><li>At least 5 years of software development experience in agile teams</li><li>3+ years of experience building modular frontends utilising&nbsp;react (or other modern frameworks)</li><li>2+ years of experience leading software development teams</li><li>2+ years of experience designing microservice applications utilising nodeJS / express<br></li><li>Excellent knowledge of MongoDB and one other common SQL or NoSQL database technology such as Cassandra or MySQL/MariaDB</li><li>Infrastructure knowledge including REST APIs, Search Technologies like Solr/Lucene</li><li>Good programming skills in at least 1 more modern programming language/ framework</li><li>Working knowledge of tools like Gulp, npm, Jenkins</li><li>Working knowledge of DevOps, Docker, NGINX</li><li>Experience with at least one unit testing framework, such as JUnit</li></ul>',
#   'nice_to_have': '* German language skills are a plus',
#   'perks': '<ul><li>Beautiful, spaceous office</li><li>Flat hierarchies, quick decisionmaking process</li><li>A stable and secure environment at a market-leading company</li><li>PTO, employee pension schemes, discounts for various activities</li><li>free, voluntary german language courses</li><li>regular teamevents and hackathons</li><li>relocation support</li></ul>',
#   'referral_value': '300.0',
#   'relocation_paid': True,
#   'role_description': '*Disclaimer: All company details and specific procedures will be revealed when you start your application process!*\r\n\r\n**What we do:**\r\n\r\nWe are the second largest furniture retailer in Europe. With us you will operate highly complex ecommerce platforms across multiple european markets to drive our online presence further.\r\n\r\nYou will join 100 IT colleagues hailing from more than 20 nations in our newly opened, spaceous Berlin office, which oversees our entire IT operations for all of europe.\r\n\r\n**What you will do:**\r\n\r\no Contribute across the full technology stack, from database, infrastructure that supports deployments to Front-end development. As a Software Developer you will work in an agile cross-functional team with the Product Owners, Designers and Software Testers to drive our Online Shops and other digital products forward.\r\n\r\no Development of Front-end features based on MVC Design Pattern\r\n\r\no Creating views/templates and styles in our Atomic Design Methodology\r\n\r\no Implementing client side JavaScript\r\n\r\no Developing Application side controller logic\r\n\r\no Collaborating with backend developers to design REST APIs and Data Models\r\n\r\no Further Development of our Content Management Systems including Data Models, GUIs and integration of new features and tools in our ecosystem\r\n\r\no Creating Unit Tests and supporting the Testing & QA Team with UI Tests\r\n\r\no Consulting the Product Owners in architectural and technological decisions to ensure that we stay on the leading edge of technology',
#   'title': 'Teamlead JavaScript',
#   'created_at': '2018-06-19T13:42:48.324Z',
#   'updated_at': '2021-10-08T00:00:28.358Z',
#   'published_at': '2020-11-18T11:24:50.023Z',
#   'type': 'Full-time',
#   'remote': False,
#   'gross_salary_low': 60000,
#   'gross_salary_high': 75000,
#   'tags': ['Team Management',
#    'Team Leadership',
#    'JavaScript',
#    'DevOps',
#    'REST APIs',
#    'Databases',
#    'Node.js',
#    'React'],
#   'url': 'https://landing.jobs/at/landing-partner-de-99d6b69b-02bd-4e6c-8863-9d0475e065ca/teamlead-javascript'},
#  {'id': 7376,
#   'city': 'Berlin',
#   'company_id': 2965,
#   'country_code': 'DE',
#   'country_name': 'Germany',
#   'currency_code': 'EUR',
#   'expires_at': '2021-11-02',
#   'main_requirements': '<ul><li>Practical experience with "Infrastructure as Code" and CI/CD tools as well as development of deployment pipelines</li><li>Passion and interest in new technologies and subjects revolving around Linux and Cloud</li><li>Good experience with container technologies like Kubernetes, Docker, AWS, and Puppet.</li><li>You are comfortable with configuration management systems like Ansible, Chef, Puppet</li><li>Expertise with Java based applications</li><li>Programming skills in Java or Python and Bash</li><li>Flexibility, trustworthiness, team collaboration, and&nbsp;self-sufficiency</li></ul>',
#   'nice_to_have': '<ul><li>Speak German at least at a beginner level<br></li></ul>',
#   'perks': '<ul><li>the possibility to include your own ideas in order to reach the goal in your team</li><li>Work-Life-Balance with flexible working hours and a family-friendly nature</li><li>Flat hierarchies with open and quick&nbsp;</li><li>Great possibilities for education and training</li><li>Fresh fruit, breakfast, drinks, team events, and more.<br></li><li>30 days vacation</li></ul>',
#   'referral_value': '300.0',
#   'relocation_paid': True,
#   'role_description': '<ul><li>Establish and maintain automated processess which improve development and operations - Cloud applications as well as on premise infrastructures</li><li>As member of the Platform-team you are responsible to establish and ensure the availability and scalability of the infrastructure</li><li>You optimise and automated deployment processes</li></ul>',
#   'title': 'Senior DevOps Engineer',
#   'created_at': '2018-12-18T17:05:21.381Z',
#   'updated_at': '2021-10-08T00:00:35.393Z',
#   'published_at': '2020-11-24T11:15:38.312Z',
#   'type': 'Full-time',
#   'remote': False,
#   'gross_salary_low': 55000,
#   'gross_salary_high': 65000,
#   'tags': ['Chef',
#    'Puppet',
#    'Ansible',
#    'Python',
#    'Java',
#    'Docker',
#    'Amazon Web Services',
#    'Kubernetes'],
#   'url': 'https://landing.jobs/at/2965/senior-devops-engineer-in-berlin-2020'},
#  {'id': 7426,
#   'city': 'Berlin',
#   'company_id': 147,
#   'country_code': 'DE',
#   'country_name': 'Germany',
#   'currency_code': 'EUR',
#   'expires_at': '2021-11-26',
#   'main_requirements': '<ul><li style="font-weight: 400;" data-mce-style="font-weight: 400;">University degree in Computer Science, Engineering, Information Systems or related fields or equivalent practical experience</li><li style="font-weight: 400;" data-mce-style="font-weight: 400;">Familiar working with Microservices in the AWS-Cloud</li><li style="font-weight: 400;" data-mce-style="font-weight: 400;">Professional&nbsp; Java experience</li><li style="font-weight: 400;" data-mce-style="font-weight: 400;">Understanding, dissecting and influencing business requirements in order to find a suitable technological solution is one of your core competencies</li><li style="font-weight: 400;" data-mce-style="font-weight: 400;">Good understanding and practical experience in working in an agile environment using test-driven development and continuous integration and delivery</li><li style="font-weight: 400;" data-mce-style="font-weight: 400;">Writing clean, testable, maintainable and well documented code comes naturally - we strongly believe in Uncle Bob</li><li style="font-weight: 400;" data-mce-style="font-weight: 400;">You are comfortable participating in technical and architectural discussions</li><li style="font-weight: 400;" data-mce-style="font-weight: 400;">You are an open-minded and creative team player willing to continue creating our culture</li><li style="font-weight: 400;" data-mce-style="font-weight: 400;">Great English communication skills</li></ul>',
#   'nice_to_have': '',
#   'perks': '<p>At Raisin, we care about each other and it is one of our top priorities to foster an open and caring environment in which everyone feels welcome and comfortable. Our culture is strongly driven by our ambitious team, which, connects more than 40 different nationalities. As part of our team in Berlin, you will benefit from<br></p><ul><li>Relocation and visa support as well as a relocation reimbursement</li><li>Personal training budget of 1,700 € and four full training days</li><li>Free choice of hardware<br></li><li>Stay up to date at regular townhall sessions with our founders and feel free to ask any kinds of questions</li><li>Flexible working hours, home office and 28 vacation days&nbsp;</li><li>Enjoy more than 50+ different sports with Urban Sports Club: We subsidize your membership with more than 20 € per month&nbsp;</li><li>We offer you a company pension scheme (Betriebliche Altersvorsorge), which we support with 20%<br></li></ul>',
#   'referral_value': '300.0',
#   'relocation_paid': False,
#   'role_description': '<p>We are Raisin, a dynamic and fast-growing fintech company with its headquarters in Berlin. Together, we built a marketplace offering our customers simple, transparent access to deposits across Europe. In addition, in Germany, we also provide ETF portfolios as well as pension products. In the US, we are also offering a Savings as a Service model for bank partners.</p><p><br>We raised more than € 195 million in funding from investors including Goldman Sachs, PayPal Ventures, Index Ventures, btov Ventures, Ribbit Capital, Orange Digital Ventures and Thrive Capital.<br></p><p><br data-mce-bogus="1"></p><p>For further development and expansion of our successful business, Raisin is looking for highly motivated, smart and driven engineers to complement our team in Berlin. As a Java developer here, you will be working on our online banking system together with an international team of top developers.</p><ul><li style="font-weight: 400;" data-mce-style="font-weight: 400;">Providing core services and high quality solutions for a large scale online platform and everything related to the online banking system</li><li style="font-weight: 400;" data-mce-style="font-weight: 400;">Integrating externally developed components into existing application environments</li><li style="font-weight: 400;" data-mce-style="font-weight: 400;">Together with the rest of the team, setting standards, establishing guidelines and sharing best practices in order to ensure continuous learning and development as well as stable solutions for our customers.</li></ul>',
#   'title': 'Software Engineer (Back-end) (m/f/d)',
#   'created_at': '2019-01-07T18:08:20.275Z',
#   'updated_at': '2021-10-08T00:00:26.378Z',
#   'published_at': '2020-09-02T10:42:12.712Z',
#   'type': 'Full-time',
#   'remote': False,
#   'tags': ['Microservices',
#    'Amazon Web Services',
#    'MySQL',
#    'Java',
#    'Continuous Integration',
#    'Test Driven Development'],
#   'url': 'https://landing.jobs/at/raisin/software-engineer-back-end-m-f-d'},
#  {'id': 7642,
#   'city': 'Hamburg',
#   'company_id': 3095,
#   'country_code': 'DE',
#   'country_name': 'Germany',
#   'currency_code': 'EUR',
#   'expires_at': '2021-12-01',
#   'main_requirements': '<!--block--><p><strong>Who you are<br></strong><br></p><ul><li><!--block-->Very good &amp; MVP-focused coding skills in PHP7 of minimum 3 years (Medior-Level) //&nbsp; 5 years (Senior-Level)</li><li><!--block-->Practical &amp; recent experience with MVC Frameworks like Laravel, Symfony, Zend or Yii2</li><li><!--block-->Deep technical understanding of RESTful API’s</li><li><!--block-->Solid background in building scalable distributed products and practical experience with Caching</li><li><!--block-->Previous experience with handling &amp; querying relational databases (e.g. MySQL, MariaDB or PostgreSQL)</li><li><!--block-->Passionate about writing well-structured, efficient and maintainable code, actively keeping the quality of the code base in check</li><li><!--block-->Comfortable working in an English-speaking&nbsp; &amp; agile environment</li></ul><!--block--><p><br></p>',
#   'nice_to_have': '',
#   'perks': '<ul><li><!--block-->Grow together with one of the fastest growing eCommerce companies in Europe</li><li><!--block-->Flexible working times<br></li><li><!--block-->Fresh fruits + drinks everywhere</li><li><!--block-->Language courses (German &amp; English)</li><li><!--block-->Free sports courses &amp; reduced price for gym membership</li><li><!--block-->Subsidized public transportation ticket</li><li><!--block-->Free choice of hardware and operating system (Mac, Windows, Linux) also for private usage</li><li><!--block-->State-of-the-art tech stack running on AWS<br></li><li><!--block-->Company flats (subject to availability)</li><li><!--block-->Agile work environment (MOVE) and cross-functional teams</li><li><!--block-->Free access to Germany’s greatest developer conference code.talks</li><li><!--block-->German health insurance included</li><li><!--block-->Company pension scheme</li><li><!--block-->Help in relocation and VISA process</li></ul>',
#   'referral_value': '300.0',
#   'relocation_paid': True,
#   'role_description': '<div><!--block-->We are looking for <strong>(Senior) Backend PHP Developers</strong> to join one of our Tech Teams at ABOUT YOU. Our Tech Department is the heart of ABOUT YOU, driven by the passion to develop the best infrastructure &amp; applications. You will work on high-scalable products on a cloud-based infrastructure and collaborate with developers who constantly challenge themselves to raise the bar of what is “state of the art” technology.<br><br></div><div><!--block--><br>Leap to the next level in your career and shape the online shopping experience of millions of customers by building the best shop infrastructure.<br><br><strong>What you will do<br></strong><br></div><ul><li><!--block-->Work on high-scalable products with PHP7 hosted on a cloud-based infrastructure</li><li><!--block-->Build and provide internal &amp; external RESTful APIs that ensure a fast &amp; frictionless updating of our backend products</li><li><!--block-->Develop multiple backend platforms ranging from high throughput to maximum faultlessness</li><li><!--block-->Constantly challenge and expand your knowledge of reliable software architecture, programming and new technologies</li><li><!--block-->Work with agile processes that are adapted to the team’s and project’s needs</li><li><!--block-->Exchange your knowledge with other developers and be part of our ABOUT YOU TECH community</li></ul>',
#   'title': '(Senior) Back-end PHP Developer',
#   'created_at': '2019-02-15T14:34:29.140Z',
#   'updated_at': '2021-10-08T00:00:27.276Z',
#   'published_at': '2020-03-22T20:41:01.501Z',
#   'type': 'Full-time',
#   'remote': False,
#   'tags': ['Symfony', 'Laravel', 'Databases', 'MVC', 'REST APIs', 'PHP'],
#   'url': 'https://landing.jobs/at/about-you-gmbh/senior-back-end-php-developer-in-hamburg'},
#  {'id': 7710,
#   'city': 'Lisbon',
#   'company_id': 322,
#   'country_code': 'PT',
#   'country_name': 'Portugal',
#   'currency_code': 'EUR',
#   'expires_at': '2021-11-11',
#   'main_requirements': '<ul><li>Development in languages such as&nbsp;<strong>Java or Kotlin</strong></li><li><strong>Solid Android</strong>&nbsp;development experience</li><li>Understanding of Design Patterns and Object Oriented Design</li><li>Knowledge of Android App Architecture</li><li>Experience working with&nbsp;<strong>Restful APIs</strong></li><li>Practical knowledge of network protocols and challenges with latency and reliability</li><li>Demonstrable knowledge of coding involving&nbsp;<strong>multithreading</strong>, request queueing and caching</li><li>Continuous Integration/Deployment tools and processes</li><li>Ability to work well in a team, self-driven and eager to learn</li><li>Creative thinking, analytical skills, with attention to detail</li><li>Fluent in English</li><li>Lisbon based</li></ul>',
#   'nice_to_have': '',
#   'perks': '<p><br data-mce-bogus="1"></p>',
#   'referral_value': '300.0',
#   'relocation_paid': False,
#   'role_description': "<p><!--block--></p><p>In the UK &amp; Ireland, <strong>Sky</strong> has been making entertainment better for over 27 years. We’re part of Europe’s leading entertainment company with over 21 million customers across five countries and are now starting our operations in Portugal. Delivering Sky’s mix of TV that people love, pioneering technology, award-winning service and super-fast broadband is a genuine team effort. Across our business, whether in front of the camera or behind the scenes, we’re always looking for new ways to make things better for our customers.<br></p><p><!--block--></p><p>We’re always looking to improve by developing pioneering products and services which give every one of our customers experiences they’ll love. Join us as a&nbsp;<strong>Senior&nbsp;</strong><strong>Mobile Developer (Android)&nbsp;</strong>and you'll be part of a dynamic team that makes sure our technology delivers the best experience for our customers.</p><p><strong>Your Key Responsibilities</strong>:</p><ul><li>Develop excellent quality software using agile techniques</li><li>Design clean and reliable code</li><li>Deliver highly scalable and highly reliable products (yes, our customers expect 99.999% availability)</li><li>Collaborate with other developers, sharing and receiving knowledge</li><li>Promote best technology and software development practices into the team with passion and enthusiasm</li><li>Contribute to the whole development cycle, analysis, implementation, testing and operation \u202f&nbsp;</li><li>Operation excellence and support are part of the development teams’ responsibility</li></ul>",
#   'title': 'Mobile Developer (Android)',
#   'created_at': '2019-03-04T11:07:38.200Z',
#   'updated_at': '2021-10-08T00:00:19.642Z',
#   'published_at': '2020-10-29T17:21:43.920Z',
#   'type': 'Full-time',
#   'remote': False,
#   'tags': ['Kotlin', 'Android', 'Java', 'Mobile Applications', 'REST APIs'],
#   'url': 'https://landing.jobs/at/sky-technology-centre-portugal/mobile-developer-android-in-lisbon'},
#  {'id': 7879,
#   'city': 'Hamburg',
#   'company_id': 3095,
#   'country_code': 'DE',
#   'country_name': 'Germany',
#   'currency_code': 'EUR',
#   'expires_at': '2021-10-22',
#   'main_requirements': '<div><!--block--><strong>Who you are<br></strong><br></div><ul><li><!--block-->Very good &amp; MVP-focused coding skills in JavaScript of minimum 3 years (Medior-Level) //&nbsp; 5 years (Senior-Level)</li><li><!--block-->Practical &amp; recent experience with JS Frameworks like React, React Native or Vue.js</li><li><!--block-->Comfortable working with TypeScript or ES6</li><li><!--block-->Solid background in building complex customer-facing products coming along with excellent analytical and problem-solving skills</li><li><!--block-->Passionate about writing well-structured, efficient and maintainable code, actively keeping the quality of the code base in check</li><li><!--block-->Used to work in an English speaking environment</li></ul><div><!--block--><br></div>',
#   'nice_to_have': '',
#   'perks': '<p>&nbsp;</p><ul><li>Flexible working times</li><li><!--block-->40% discount on our online shop</li><li><!--block-->Fresh fruits + drinks everywhere</li><li><!--block-->Language courses (German &amp; English)</li><li><!--block-->Free sports courses &amp; reduced price for gym membership</li><li><!--block-->Subsidized public transportation ticket</li><li><!--block-->Free choice of hardware and operating system (Mac, Windows, Linux) also for private usage</li><li><!--block-->State-of-the-art tech stack running on AWS</li><li><!--block-->Modern office in the city center of Hamburg</li><li><!--block-->International working environment and English as company language</li><li><!--block-->Company flats (subject to availability)</li><li><!--block-->Agile work environment (MOVE) and cross-functional teams</li><li><!--block-->Free access to Germany’s greatest developer conference code.talks</li><li><!--block-->German health insurance included</li><li><!--block-->Company pension scheme</li></ul>',
#   'referral_value': '300.0',
#   'relocation_paid': True,
#   'role_description': '<div><!--block-->We are currently looking for a skilled &amp; passionate <strong>(Senior) Frontend Developer</strong> to become part of one of our Tech Teams at ABOUT YOU!<br><br>All Tech Teams are driven by the dedication to deliver high-scalable applications shaped by a lean and intuitive user interface that ensures the best possible user experience. Your work will impact the future of how eCommerce is experienced by millions of customers.</div><div><!--block--><br>Jump to the next career step and unlock the future potential of frontend development by constantly challenging your tech know-how with us!<br><br></div><div><!--block--><br><br><strong>What you will do<br></strong><br></div><ul><li><!--block-->Build high traffic user interfaces with JavaScript and React/React Native or Vue.js</li><li><!--block-->Work on the implementation of high-leverage features to optimize UX and conversion rates</li><li><!--block-->Cooperate with skilled developers, product managers, QA’s, and designers to ship new components and features</li><li><!--block-->Draft architectural decisions together with the Tech Lead and explore new technologies</li><li><!--block-->Have a direct impact on team processes by regular agile retrospectives</li><li><!--block-->Exchange your knowledge with other developers and be part of our ABOUT YOU TECH community</li></ul>',
#   'title': '(Senior) Front-end Developer',
#   'created_at': '2019-03-27T12:18:43.932Z',
#   'updated_at': '2021-10-08T00:00:27.335Z',
#   'published_at': '2020-03-22T20:41:11.131Z',
#   'type': 'Full-time',
#   'remote': False,
#   'tags': ['Vue.js', 'React', 'TypeScript', 'React Native', 'JavaScript'],
#   'url': 'https://landing.jobs/at/about-you-gmbh/senior-front-end-developer-in-hamburg-2019'},
#  {'id': 8346,
#   'city': 'Lisbon',
#   'company_id': 2651,
#   'country_code': 'PT',
#   'country_name': 'Portugal',
#   'currency_code': 'EUR',
#   'expires_at': '2022-01-26',
#   'main_requirements': '<p><strong>You are a great candidate if you have:<br></strong></p><ul><li>Passion for what you do;</li><li>You are a flexible person when it comes to technologies – You choose the best tool for the job;</li><li>By now, you already know how to adapt to new situations;</li><li>You are aware of your feelings and other people’s emotions and how you can work together;</li><li>You know how to communicate verbally and in writing and you always have a positive intent.</li></ul><p><strong>Nice to Have:</strong></p><ul><li>Experience working in a&nbsp;<strong>Product team</strong>&nbsp;(previous experience deploying software into production);</li><li>Experience with&nbsp;<strong>JVM</strong>&nbsp;technologies (namely: Java, Scala, or Kotlin);</li><li>Experience with&nbsp;<strong>Streaming</strong>&nbsp;technologies, like Kafka, RabbitMQ, or Flink;</li><li>Experience in&nbsp;<strong>RESTful API</strong>&nbsp;development;</li><li>Experience with&nbsp;<strong>NoSQL</strong>;</li><li>Deep understanding of Application and&nbsp;<strong>Infrastructure</strong>&nbsp;Design in a&nbsp;<strong>Cloud</strong>&nbsp;Environment;</li><li>Previous experience with&nbsp;<strong>Containers</strong>&nbsp;(Docker, Kubernetes);</li><li>Fluent with unit&nbsp;<strong>testing</strong>, automated integration, and load tests, CI/CD pipelines;</li><li>Experience in&nbsp;<strong>Mentoring</strong>&nbsp;/ Coaching others</li></ul>',
#   'nice_to_have': '<p class="p1"><br></p>',
#   'perks': '<p><u>You’ll enjoy the perks of a balanced work-life</u></p><ul><li>You’ll receive a fair salary that reflects the job market, your experience, and your impact;</li><li>You and your family will receive health insurance;</li><li>You’ll have work-life flexibility: we are a remote-first company. This means we trust you with&nbsp;<em>when</em>&nbsp;and&nbsp;<em>where</em>&nbsp;you work from: from our office in the city center, from Alentejo or from your home country. We want to give you the flexibility you need&nbsp;<em>and&nbsp;</em>keep our great office culture, so we do in-person team events in the office every once in a while;</li><li>Oh, and of course, you’ll get some discounts on Mercedes rentals and acquisition.</li></ul><p><br data-mce-bogus="1"></p><p>&lt;center&gt;<strong>So… do you have what it takes to become a tb.lxer?</strong><strong>&nbsp;Apply now!</strong></p><p><br data-mce-bogus="1"></p><p>To know more about us visit our&nbsp;<a href="https://medium.com/tblx-insider" target="_blank" rel="noopener noreferrer" data-mce-href="https://medium.com/tblx-insider">Medium</a>,&nbsp;<a href="https://www.linkedin.com/company/tblx/" data-mce-href="https://www.linkedin.com/company/tblx/">LinkedIn</a>&nbsp;and&nbsp;<a href="https://www.instagram.com/wearetblx/?hl=en" data-mce-href="https://www.instagram.com/wearetblx/?hl=en">Instagram</a>&lt;/center&gt;</p>',
#   'referral_value': '300.0',
#   'relocation_paid': True,
#   'role_description': '<p>Hey there,</p><p><br></p><p>The world is changing right before our eyes, and we are changing with it. It hasn’t been rainbows and sunshine all the time. We have been challenged, and we have persevered. We stuck together and we kept growing. We reinvented how we work best in collaboration in a remote setup, coming to a healthy remote-first working mode.</p><p><br></p><p><strong>What do we do?</strong></p><p>We are trusted to build the best software products in e-mobility, and pave the way for sustainable transportation. Curious to know more? Keep reading!</p><p>As a corporate startup, we are spearheading innovation within our mother company Daimler Trucks &amp; Buses. Our mission is to develop data-driven solutions for the transportation of&nbsp;<s>tomorrow</s>&nbsp;today: connected, electric and sustainable. Here, your code is more than code. You have an impact on the way goods and people move, on the environment, and on the world we’re creating for future generations.</p><p><br></p><p><strong>&lt;center&gt;Are you in?&lt;/center&gt;</strong></p><p><br></p><p>We’re looking for a bold and driven&nbsp;<strong>Backend Engineer</strong><strong>&nbsp;to&nbsp;</strong>help us create a sustainable future of transportation. Keep scrolling to read all the important must-haves and key responsibilities.</p><p><br></p><p><strong>What your day-to-day work will be like:</strong></p><ul><li>Develop exciting projects with the latest technologies (Java, Scala, Kotlin, Python is our tech stack);</li><li>Implement RESTful APIs to serve data and integrate them with API management tools;</li><li>Align with Data Engineers to define data schemas on the serving layer databases;</li><li>Align with Frontend developers and data consumers in general for API requirements;</li><li>Implement CI/CD pipelines;</li><li>Eventually, you will have to fix some bugs, right? This is not Disneyland 😁</li></ul><p><br data-mce-bogus="1"></p><p><strong>Now that you</strong><strong>&nbsp;know what we are looking for,&nbsp;</strong><strong>here’s what’s in it for you:</strong></p><p><u>You’ll learn and grow technically</u></p><ul><li>You’ll work in an experienced engineering team, mainly composed of seniors who are humble and ready to help you learn;</li><li>You’ll be backed up by leadership that walks the talk:</li><li>You’ll have access to trainings according to your learning and growth needs.</li></ul>',
#   'title': 'Software Engineer - Backend Focus',
#   'created_at': '2019-06-27T15:10:56.603Z',
#   'updated_at': '2021-10-08T00:00:29.334Z',
#   'published_at': '2021-06-07T10:39:10.739Z',
#   'type': 'Full-time',
#   'remote': False,
#   'tags': ['REST APIs',
#    'Python',
#    'Test Driven Development',
#    'Cloud Computing',
#    'SQL',
#    'Docker',
#    'MongoDB',
#    'Java',
#    'Kotlin',
#    'Scala'],
#   'url': 'https://landing.jobs/at/tb-lx-by-daimler-trucks-buses/software-engineer-backend-focus-in-lisbon'},
#  {'id': 8954,
#   'city': 'Frankfurt',
#   'company_id': 147,
#   'country_code': 'DE',
#   'country_name': 'Germany',
#   'currency_code': 'EUR',
#   'expires_at': '2021-10-17',
#   'main_requirements': '<p><strong>Dein Profil:</strong></p><ul><li>Du hast dein Studium in Informatik, Wirtschaftsinformatik oder einem ähnlichen Feld erfolgreich abgeschlossen</li><li>Du verfügst über mindestens zwei Jahre Berufserfahrung im Software Engineering und kennst Dich bestens mit serverless Cloud Services aus</li><li>Du hast Erfahrung in agiler Softwareentwicklung und siehst in Software Engineering und FinTech deinen nächsten, langfristigen Karriereschritt</li><li>Dich reizt es hands on als Entwickler unserer Banking as a Service Produkte zu arbeiten</li><li>Du sprichst Deutsch verhandlungssicher und Englisch fließend</li><li>Du verfügst über solide Erfahrungen mit Javascript sowie RESTful API Design, Testautomatisierung, AWS API Gateway, AWS Lambda, OpenAPI/Swagger, Jira, Confluence, Git, Gitflow</li><li>Du bist motiviert, behältst immer einen kühlen Kopf und bist ein echter Teamplayer</li><li>Erfahrungen im IT Bereich von Banking oder FinTech sind von Vorteil<br></li></ul>',
#   'nice_to_have': '<div><!--block-->Banking, Financial Services</div>',
#   'perks': '<div><!--block-->Als Teil der Raisin-Familie vereint die Raisin Bank das Beste aus beiden Welten:<br>die Erfahrung und Sicherheit einer Bank mit der Flexibilität und Innovationskraft eines Start-ups.<br>Wenn du ein dynamisches Umfeld suchst, in dem du deine Stärken ausspielen und dich weiterentwickeln kannst, dann bist du bei uns richtig!&nbsp;</div><div><!--block-->Mit dem Ansatz “We build it, we own it” sorgst du gemeinsam mit unserem IT und Produkt Team dafür, dass wir langfristig der optimale Partner für Europas Fintechs und Banken sind.&nbsp;<br>Unsere Benefits:<br>&nbsp;</div><ul><li><!--block-->Wir übernehmen die Beiträge der hauseigenen Altersvorsorge</li><li><!--block-->Gleitzeitmodell und 30 Tage Urlaub</li><li><!--block-->Verpflegungszuschuss für das tägliche Mittagessen</li><li><!--block-->Wir übernehmen die Kosten für deine RMV-Jahreskarte am Stadtgebiet Frankfurt&nbsp;</li></ul>',
#   'referral_value': '300.0',
#   'relocation_paid': False,
# ...
#   'expires_at': '2021-10-15',
#   'main_requirements': '<div><!--block-->&nbsp;<strong>Qualifications and what you should bring:<br></strong><br></div><ul><li><!--block-->Experienced Project Leader for modern architectures in complex multi-channel SPAs&nbsp;</li><li><!--block-->Integration of graphical user interfaces with backend service landscapes</li><li><!--block-->Love your work and move things forward to deliver the best product. #TechFirst!&nbsp;</li><li><!--block-->Mentoring / Coaching / Hiring experience</li><li><!--block-->English communication skills, German is not necessary!</li></ul>',
#   'nice_to_have': '',
#   'perks': '<ul><li><!--block-->100% REMOTE WORK POSSIBLE // optional Berlin office</li><li><!--block-->flexible work hours // 30 days paid vacation&nbsp;</li><li><!--block-->Paid relocation package</li><li><!--block-->Individual development budget for training, conferences, etc.</li><li><!--block-->Team events &amp; company benefits</li><li><!--block-->Sports &amp; Fitness cooperation, drinks, snacks &amp; fresh fruits</li></ul><div><!--block--><br></div>',
#   'referral_value': '300.0',
#   'relocation_paid': True,
#   'role_description': '<div><!--block-->Think <strong>UNICORN </strong>and develop <strong>THE</strong> new <strong>Cloud Streaming Platform </strong>for Music, TV, Movies, Podcasts, ebooks, radio etc. - <strong>All in ONE!</strong> --&gt; <strong>Competing with Netflix and Amazon is ambitious?</strong> <strong>Hell yeah! ...</strong>but trust us, we got the<strong> network, </strong>the <strong>power</strong> and the <strong>money</strong> of the <strong>biggest content players!</strong>&nbsp;<br><br></div><ul><li><!--block-->We just started from scratch - now we need the passion, the ownership and the skills from the best Techies in the world!</li></ul><div><!--block--><strong>Our goal:</strong> Building a platform that matters and growing to 150 people in tech within 1 year&nbsp;<br><br></div><div><!--block--><strong>Techs:</strong></div><ul><li><!--block-->React. js, Vue.js, GraphQL</li><li><!--block-->TypeScript</li><li><!--block-->Node.js, TDD</li><li><!--block-->Backend: Kotlin, Python cloud-native microservices</li></ul><div><!--block--><br></div><div><!--block--><strong>Our Dev Culture: <br>#RemoteFirst</strong>&nbsp;</div><ul><li><!--block-->International, cross-functional remote teams with a "you build it, you run it" attitude &nbsp;</li><li><!--block-->Work autonomously and agile in a creative environment - you are the driving engine!</li><li><!--block-->Personalized development strategy for individual and professional growth</li><li><!--block-->Flexible working hours, optional office in central Berlin</li><li><!--block-->English communication and discussion culture&nbsp;</li></ul>',
#   'title': 'Senior / Lead JavaScript Engineer (m/f/x)',
#   'created_at': '2020-08-20T12:38:01.585Z',
#   'updated_at': '2021-10-08T00:00:18.152Z',
#   'published_at': '2020-08-21T14:29:59.805Z',
#   'type': 'Full-time',
#   'remote': True,
#   'gross_salary_low': 75000,
#   'gross_salary_high': 95000,
#   'tags': ['Python',
#    'Kotlin',
#    'HTML',
#    'GraphQL',
#    'Node.js',
#    'JavaScript',
#    'TypeScript',
#    'React',
#    'CSS'],
#   'url': 'https://landing.jobs/at/avantgarde-creating-fans/senior-lead-javascript-engineer-m-f-x'},
#  {'id': 10740,
#   'city': 'Berlin',
#   'company_id': 1465,
#   'country_code': 'DE',
#   'country_name': 'Germany',
#   'currency_code': 'EUR',
#   'expires_at': '2021-10-15',
#   'main_requirements': '<div><!--block-->&nbsp;<strong>Qualifications and what you should bring:</strong></div><ul><li><!--block-->JVM, Backend, Architecture Expert +5 years</li><li><!--block-->Expert in hiring and leading teams in cloud native &amp; complex microservice environments <strong>(hands-on if you like)</strong></li><li><!--block-->Love your work and move things forward to deliver the best product. #TechFirst!</li><li><!--block-->Creativity: Take over responsibility and shape the future of our platform with your ideas</li><li><!--block-->English Communication skills are key!&nbsp;</li><li><!--block-->Mentoring / Coaching / Hiring experience&nbsp;</li></ul>',
#   'nice_to_have': '',
#   'perks': '<ul><li><!--block-->100% REMOTE WORK POSSIBLE // optional Berlin office</li><li><!--block-->flexible work hours // 30 days paid vacation&nbsp;</li><li><!--block-->Paid relocation package</li><li><!--block-->Individual development budget for training, conferences, etc.</li><li><!--block-->Team events &amp; company benefits</li><li><!--block-->Sports &amp; Fitness cooperation, drinks, snacks &amp; fresh fruits</li></ul><div><!--block--><br></div><div><!--block--><br></div><div><!--block--><br></div><div><!--block--><br></div>',
#   'referral_value': '300.0',
#   'relocation_paid': True,
#   'role_description': '<div><!--block-->Think <strong>UNICORN </strong>and develop <strong>THE</strong> new <strong>Cloud Streaming Platform </strong>for Music, TV, Movies, Podcasts, ebooks, radio etc. - <strong>All in ONE!</strong> --&gt; <strong>Competing with Netflix and Amazon is ambitious?</strong> <strong>Hell yeah! ...</strong>but trust us, we got the<strong> network, </strong>the <strong>power</strong> and the <strong>money</strong> of the <strong>biggest content players!</strong>&nbsp;<br><br></div><ul><li><!--block-->We just started from scratch - now we need the passion, the ownership and the skills from the best Techies in the world!</li></ul><div><!--block--><strong>Our goal:</strong> Building a platform that matters and growing to 150 people in tech within 1 year!<br><br></div><div><!--block--><strong>Techs:</strong></div><ul><li><!--block-->Kotlin SpringBoot Microservices in the cloud&nbsp;</li><li><!--block-->Python (for some "Data Magic")</li><li><!--block-->Kubernetes, Terraform, TDD, CI/CD</li><li><!--block-->Frontend: TypeScript, React, Vue, GraphQL&nbsp;</li></ul><div><!--block--><br></div><div><!--block--><strong>Our Dev Culture: <br>#RemoteFirst</strong>&nbsp;</div><ul><li><!--block-->International, cross-functional remote teams with a "you build it, you run it" attitude &nbsp;</li><li><!--block-->Work autonomously and agile in a creative environment - you are the driving engine!</li><li><!--block-->Personalized development strategy for individual and professional growth</li><li><!--block-->Flexible working hours, optional office in central Berlin</li><li><!--block-->English communication and discussion culture&nbsp;</li></ul>',
#   'title': 'Teamlead / Tech Manager (m/f/x) Cloud Streaming Platform',
#   'created_at': '2020-08-20T13:02:24.050Z',
#   'updated_at': '2021-10-08T00:00:23.435Z',
#   'published_at': '2020-08-21T14:29:46.874Z',
#   'type': 'Full-time',
#   'remote': True,
#   'gross_salary_low': 85000,
#   'gross_salary_high': 110000,
#   'tags': ['Docker',
#    'Kubernetes',
#    'Amazon Web Services',
#    'JavaScript',
#    'Java',
#    'Kotlin',
#    'Python'],
#   'url': 'https://landing.jobs/at/avantgarde-creating-fans/teamlead-tech-manager-m-f-x-cloud-streaming-platform'},
#  {'id': 10743,
#   'city': 'Lisbon',
#   'company_id': 389,
#   'country_code': 'PT',
#   'country_name': 'Portugal',
#   'currency_code': 'EUR',
#   'expires_at': '2022-02-13',
#   'main_requirements': "<ul><li><!--block-->Advanced knowledge of HTML5, knowledge about HTTP, Rest and JSON, alongside CSS3/SASS and Javascript (ES6) to develop new features and modules.</li><li><!--block-->Having extended knowledge of building JS apps using React and Redux.&nbsp;</li><li><!--block-->You're passionate for beautiful, test-driven code and an eye for simplicity and pragmatism</li><li><!--block-->Implementing a CI\\CD environment while working to also create and maintaining pipelines guidelines.</li><li><!--block-->Experience working with monitoring tools;</li><li><!--block-->Experience in SEO&nbsp;</li></ul>",
#   'nice_to_have': '<ul><li><!--block-->Experience with monitoring tools;</li><li><!--block-->Experience working with legacy code and monolith while handling migrations;</li><li><!--block-->Experience with Performance and Scalability</li></ul>',
#   'perks': '<ul><li><!--block-->Unique opportunity to become a part of an international team of top engineers learning from one another and contributing to the global Naspers Classifieds success, based in Lisbon but chipping in on all Classifieds websites in Europe and around the world</li><li><!--block-->Great place to learn and develop within fast-growing, global classifieds leader which opens further career opportunities in a diverse world of OLX and Naspers</li><li><!--block-->Fun and informal environment where getting stuff done and enjoying the ride is far more important than rules and hierarchies</li><li><!--block-->We offer a fixed salary plus other benefits like health insurance, company self-service, food supply, bonus system for good performance, and others</li></ul><div><!--block--><br></div><div><!--block--><br></div><div><!--block--><br></div>',
#   'referral_value': '300.0',
#   'relocation_paid': False,
#   'role_description': "<ul><li><!--block-->Research, suggest and implement new solutions to our problem domain</li><li><!--block-->Contribute to scaling our platform to the next level of modularity &amp; share-ability while working on architecture, tools, standards, and practices for the European engineering organisation</li><li><!--block-->Developing and maintaining a service with billions of page views per month</li><li><!--block-->You'll become an evangelist in assuring the quality practices that bring longevity and success of the product</li><li><!--block-->Along with the teams, you'll lead in building scalable products in a fast release environment</li></ul>",
#   'title': 'Front-end Engineer',
#   'created_at': '2020-08-21T11:14:46.636Z',
#   'updated_at': '2021-10-08T00:00:14.134Z',
#   'published_at': '2021-03-08T10:34:53.353Z',
#   'type': 'Full-time',
#   'remote': True,
#   'tags': ['Redux',
#    'SASS',
#    'JSON',
#    'SEO',
#    'Performance Testing',
#    'React',
#    'JavaScript'],
#   'url': 'https://landing.jobs/at/olx-group/front-end-engineer-in-lisbon-2020-8-21'},
#  {'id': 10744,
#   'city': 'Lisbon',
#   'company_id': 389,
#   'country_code': 'PT',
#   'country_name': 'Portugal',
#   'currency_code': 'EUR',
#   'expires_at': '2022-02-13',
#   'main_requirements': '<ul><li><!--block-->Experience building and scaling High-Traffic Web Applications</li><li><!--block-->Good knowledge of containers and containers orchestration, such as Kubernetes</li><li><!--block-->Proven background on Linux/Unix Systems</li><li><!--block-->Good Knowledge on Amazon Web Services ecosystem</li><li><!--block-->Proficiency on Configuration Management Frameworks such as Ansible, Puppet, Chef or Salt</li><li><!--block-->Expertise with one or more programming languages: Python, Go</li></ul>',
#   'nice_to_have': '',
#   'perks': "<ul><li><!--block-->Unique opportunity to become a part of international teams, learning from one another, and contributing to the global OLX Group success.</li><li><!--block-->An excellent place to learn and develop within fast-growing, global classifieds' leader which opens further career opportunities in a diverse world of OLX and Prosus.</li><li><!--block-->Competitive salary and awesome benefits</li><li><!--block-->Company Mobile phone and any tool you might need a MacBook Pro/ Notebook/ PC</li></ul><div><!--block--><br></div>",
#   'referral_value': '300.0',
#   'relocation_paid': False,
#   'role_description': '<ul><li><!--block-->Support a Global Distributed Classifieds Platform Evolution (scalability, HA, deployment, performance)</li><li><!--block-->Architect, build and implement infrastructure services to enable our distributed platform growth</li><li><!--block-->Advocate sensible, scalable, systems design and share responsibility within the organization in diagnosing, resolving, and preventing production issues through mechanisms like automation</li><li><!--block-->Automate as much as humanly possible and always configure as code</li><li><!--block-->Take operational responsibility for the services that we own, including taking part in an on-call rotation, practice balanced incident response and blameless postmortems</li></ul><div><!--block--><br></div>',
#   'title': 'Site Reliability Engineer',
#   'created_at': '2020-08-21T11:57:59.535Z',
#   'updated_at': '2021-10-08T00:00:32.846Z',
#   'published_at': '2020-08-24T09:05:26.885Z',
#   'type': 'Full-time',
#   'remote': True,
#   'tags': ['Agile',
#    'Ansible',
#    'Amazon Web Services',
#    'Linux',
#    'Go',
#    'Kubernetes',
#    'Python',
#    'CI/CD'],
#   'url': 'https://landing.jobs/at/olx-group/site-reliability-engineer-in-lisbon-2020-8'},
#  {'id': 10759,
#   'city': 'Porto',
#   'company_id': 1885,
#   'country_code': 'PT',
#   'country_name': 'Portugal',
#   'currency_code': 'EUR',
#   'expires_at': '2021-12-19',
#   'main_requirements': '<ul><li><!--block-->Engineer mentality: passion about solving highly complex challenges;&nbsp;</li><li><!--block-->Architecture-oriented engineer;</li><li><!--block-->Unafraid of stepping out of your comfort zone;</li><li><!--block-->Solid experience in the development of native Android applications;</li><li><!--block-->Comfortable with all stages of software development: from Software Architecture design to testing and deployment;</li><li><!--block-->Ability to write clean and optimized code;</li><li><!--block-->Good verbal and written English skills.</li></ul>',
#   'nice_to_have': '<ul><li><!--block-->Experience in C++ is a big plus;</li><li><!--block-->Experience with card present transaction protocols (E.g. EMV/Nexo/ISO8583);</li><li><!--block-->Experience with Python/Django/Javascript;</li><li><!--block-->Experience with Microservices and Docker.</li></ul>',
#   'perks': '<ul><li><!--block-->Work with people passionate about solving high complex tech challenges;&nbsp;</li><li><!--block-->Impact on the product and culture;</li><li><!--block-->Modern technologies and low tech debt;</li><li><!--block-->Progress fast! We promote ownership, doesn’t matter years of experience nor age;&nbsp;</li><li><!--block-->Flexible environment and work life balance - as well as good team environment;&nbsp;</li><li><!--block-->The Switch Kit: Macbook Pro and others;</li><li><!--block-->Health insurance with dental plan;&nbsp;</li><li><!--block-->Spotify and Netflix;</li><li><!--block-->Daily transportation Braga &lt;&gt; Porto Office for someone who lives in Braga.&nbsp;</li></ul>',
#   'referral_value': '300.0',
#   'relocation_paid': False,
#   'role_description': '<p>If you are a talented and passionate Android Software Engineer, not afraid of stepping out of your comfort zone, yearning to learn with the best, and have a giant impact... We have a challenge for you.&nbsp;<br><br>At Switch we have the challenge to build a product that it’s huge and must be scalable to match the most use cases possible. Furthermore, it also needs to be reliable to process millions of transactions for some of the largest merchants/retailers in the world, complying with extremely critical security rules.<br><strong></strong></p><p><br data-mce-bogus="1"></p><p><strong>Your role:&nbsp;</strong></p><ul><li>Develop new features and apps across our Android POS payment platform;</li><li>Manage integrations with different payment stakeholders / terminal manufacturers;</li><li>Improve the quality of our current Android POS payment products while staying true to both Android and Switch’s design principles;</li><li>Ensure the scalability of all current and new features;</li><li>Guarantee as much compatibility as possible with other non-Android POS payment ecosystems.</li></ul>',
#   'title': 'Android Software Engineer',
#   'created_at': '2020-08-25T08:01:20.421Z',
#   'updated_at': '2021-10-08T00:00:31.626Z',
#   'published_at': '2020-08-26T16:29:08.108Z',
#   'type': 'Full-time',
#   'remote': True,
#   'gross_salary_low': 28000,
#   'gross_salary_high': 42000,
#   'tags': ['Web Development',
#    'C++',
#    'C',
#    'Docker',
#    'Django',
#    'Python',
#    'Android'],
#   'url': 'https://landing.jobs/at/switch/android-software-engineer-in-porto-2020'}]

# %%
id = 1
response = session.get(f'https://landing.jobs/api/v1/companies/{id}').json()
response['name']
# Out:
# 'Talkdesk'

# %%
results = response.json()
results[0]
remove_tags(results[0]['main_requirements'])
#     print(key + ':' + remove_tags(value))
len(results)
results
# Out:
# [{'id': 2586,
#   'city': 'Lisbon',
#   'company_id': 256,
#   'country_code': 'PT',
#   'country_name': 'Portugal',
#   'currency_code': 'EUR',
#   'expires_at': '2021-10-15',
#   'main_requirements': '<ul><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="1" data-aria-level="1">MSc / BSc in Information Systems and Computer Engineering&nbsp;and/or Computer Science&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="2" data-aria-level="1"><strong>Advanced knowledge on Linux</strong>&nbsp;operating systems&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="3" data-aria-level="1"><strong>Large&nbsp;Experience (3+ years)</strong>&nbsp;as Java based technology full stack developer/Engineer.&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="4" data-aria-level="1">Strong Experience&nbsp;while developing with&nbsp;<strong>JavaScript</strong>&nbsp;and its superset,&nbsp;<strong>Typescript</strong>&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="5" data-aria-level="1">Deep understanding of web markup, including&nbsp;<strong>HTML</strong><strong>&nbsp;</strong><strong>and CSS</strong>&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="5" data-aria-level="1">Experience with&nbsp;JavaScript libraries and frameworks such as&nbsp;and&nbsp;/or&nbsp;Angular&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="5" data-aria-level="1">Experience with&nbsp;<strong>Java based technologies</strong>&nbsp;(JBoss, Tomcat, Glassfish Spring Boot, Spring MVC, Hibernate)&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="5" data-aria-level="1">Experience of&nbsp;<strong>design patterns</strong>&nbsp;while&nbsp;implementing&nbsp;advanced&nbsp;and complex&nbsp;software solutions.&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="5" data-aria-level="1">Experience with&nbsp;<strong>relational databases</strong>&nbsp;(MS&nbsp;SQL&nbsp;Server, MySQL,&nbsp;PostgreSQL&nbsp;etc.)&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="5" data-aria-level="1">Experience in design patterns while implementing&nbsp;large scale&nbsp;and complex software solutions.&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="5" data-aria-level="1">Strong experience in using&nbsp;<strong>Eclipse, Maven, Jenkins, GIT, JIRA</strong>&nbsp;or equivalent tools&nbsp;</li><li><strong>Strong communication skills</strong>&nbsp;(written and spoken).&nbsp;</li></ul>',
#   'nice_to_have': '<ul><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="2" data-aria-level="1">Knowledge or experience with&nbsp;<strong>Docker/Kubernetes</strong>&nbsp;ecosystem</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="3" data-aria-level="1">Knowledge or experience with&nbsp;microservices based architectures</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="27" data-aria-posinset="5" data-aria-level="1">Team player&nbsp;and problem solving skills<br></li></ul>',
#   'perks': '<p>Besides a competitive salary and a variable bonus program according to the performance, we have a number of other benefits:</p><ul><li>Flexible work hours and partial remote work</li><li>Relaxed work environment</li><li>Fruit and coffee available</li><li>Health insurance</li><li>Training plan, adjusted to individual needs</li><li>Social and team building events</li><li>Areas for leisure within the facilities</li></ul>',
#   'referral_value': '275.0',
#   'relocation_paid': False,
#   'role_description': '<p><strong>ABOUT US</strong></p><p>&nbsp;<br></p><p>Everything we do is to&nbsp;<strong>inspire others</strong>&nbsp;to achieve outstanding results. We do this by investing in IT mastery to generate market value. As a global company specializing in&nbsp;<strong>Big Data</strong>,&nbsp;<strong>Business Intelligence &amp; Analytics</strong>,&nbsp;<strong>Data Science</strong>,&nbsp;<strong>Middleware</strong>,&nbsp;<strong>Digital&nbsp;</strong><strong>Xperiences</strong>, and&nbsp;<strong>Collaboration and Development tools</strong>, we have top products and services used by Fortune 500 companies.&nbsp;With a posture of honesty and cooperation with more than 180 clients in the service area&nbsp;and more than 3000 that use our products in 76 different countries, Xpand IT is recognized for its technological knowledge and&nbsp;<strong>“Passion for Excellence”</strong>.</p><p>At Xpand IT,&nbsp;<strong>everyone has a special talent</strong>. We value everyone’s talent in all fields. Excellent technical experts, visionary designers,&nbsp;dynamic and communicative Human Resources team, innovative researchers, magical marketers, entrepreneurial managers. These are the people that are part of&nbsp;<strong>Xpand IT.<br></strong>&nbsp;<br></p><p><strong>ABOUT THE JOB<br><br></strong></p><p>As a Java Full-stack developer you will build the end-to-end interactions within web and software applications. As part of your mission, you’ll design plans for the user interface, define controls’&nbsp;look &amp; feel and&nbsp;activity. You’ll&nbsp;also structure the backbone&nbsp;part of an application, which manages program middleware&nbsp;logic&nbsp;and database server(s)&nbsp;interactions. Full-stack developers understand what&nbsp;happens&nbsp;between these two (or more) layers and have the set of software skills needed to work on both.&nbsp;</p><p>At Xpand IT, full-stack developers are&nbsp;also&nbsp;problem-solvers who work in a fast-paced, collaborative environment alongside other experts such as UI/UX and cluster/database gurus.&nbsp;</p><p><strong><br><br></strong><strong>JOB DESCRIPTION/ACTIVITIES</strong></p><ul><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="37" data-aria-posinset="1" data-aria-level="1">Use /&nbsp;suggest a variety of<strong>&nbsp;state-of-the-art programming languages in order to create user-friendly web interfaces</strong><strong>&nbsp;</strong></li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="37" data-aria-posinset="2" data-aria-level="1">Design and build&nbsp;<strong>high-quality mockup</strong>s and design different prototypes.&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="37" data-aria-posinset="3" data-aria-level="1"><strong>Optimize web applications</strong>&nbsp;for maximum speed, cross-browser and cross-device&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="37" data-aria-posinset="3" data-aria-level="1">Build reusable code and libraries for future use&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="37" data-aria-posinset="3" data-aria-level="1">Work in a multidisciplinary\u202fteam with other teammates such as backend developers and web designers&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="37" data-aria-posinset="3" data-aria-level="1">Being Responsible for&nbsp;<strong>requirements definition</strong>&nbsp;and translate them into technical services.&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="37" data-aria-posinset="3" data-aria-level="1">Design and development&nbsp;of applicational backend services using the best design practices and&nbsp;patterns&nbsp;</li><li data-leveltext="\uf0b7" data-font="Symbol" data-listid="37" data-aria-posinset="3" data-aria-level="1"><strong>Recommend system solutions</strong>&nbsp;by comparing advantages and disadvantages of&nbsp;alternative&nbsp;development strategies.&nbsp;</li><li data-leveltext="\uf0b7" data-f ...
#   'title': 'Java Full-stack Developer',
#   'created_at': '2016-11-29T15:30:52.191Z',
#   'updated_at': '2021-10-08T00:00:21.091Z',
#   'published_at': '2020-05-13T09:01:28.506Z',
#   'type': 'Full-time',
#   'remote': True,
#   'tags': ['TypeScript', 'JavaScript', 'Linux', 'Git', 'JIRA', 'Java'],
#   'url': 'https://landing.jobs/at/xpand-it/java-full-stack-developer-in-lisbon-2020'},
#  {'id': 3333,
#   'city': 'Lisbon',
#   'company_id': 256,
#   'country_code': 'PT',
#   'country_name': 'Portugal',
#   'currency_code': 'EUR',
#   'expires_at': '2021-10-13',
#   'main_requirements': '<ul><li>MSc / BSc in Information Systems and Computer Engineering&nbsp;and/or Computer Science</li><li><strong>Professional experience (+ 3 years)</strong>&nbsp;as a<strong>&nbsp;Developer in JavaScript-based technologies, HTML5 and CSS3</strong></li><li>Experience with JavaScript libraries and frameworks such as&nbsp;<strong>React and /or Angular</strong></li><li>Experience with backend JavaScript frameworks such as&nbsp;<strong>Node.js</strong></li><li>Experience in&nbsp;design patterns while implementing advanced<strong>&nbsp;and complex software solutions</strong>, namely in API Rest services implementation</li><li>Experience in data base management tools like&nbsp;<strong>MS SQL Server, MySQL or PostgreSQL</strong></li><li>Experience in using&nbsp;Eclipse, Maven, Jenkins, GIT, JIRA&nbsp;or equivalent tools</li><li><strong>Team player</strong>&nbsp;and technical problem solving skills</li><li>Strong communication skills&nbsp;(written and spoken)</li><li>English proficiency<br></li></ul>',
#   'nice_to_have': '<p><br data-mce-bogus="1"></p>',
#   'perks': '<p>Besides a competitive salary and a variable bonus program according to the performance, we have a number of other benefits:</p><ul><li>Flexible work hours and partial remote work</li><li>Relaxed work environment</li><li>Fruit and coffee available</li><li>Health insurance</li><li>Training plan, adjusted to individual needs</li><li>Opportunity to work on challenging projects in different locations</li><li>Social and team building events</li><li>Areas for leisure within the facilities</li><li>Protocols and other local benefits</li></ul>',
#   'referral_value': '300.0',
#   'relocation_paid': False,
#   'role_description': '<p><strong>ABOUT US…</strong></p><p>Everything we do is to&nbsp;inspire others to&nbsp;<strong>achieve outstanding results.</strong>&nbsp;We do this by investing in IT mastery to generate market value. As a global company specializing in&nbsp;<strong>Big Data,&nbsp;Business Intelligence &amp; Analytics,&nbsp;Data Science,&nbsp;Middleware,&nbsp;Digital Xperiences, and&nbsp;Collaboration and Development tools</strong>, we have top products and services used by Fortune 500 companies.&nbsp;With a posture of honesty and cooperation with more than 180 clients in the service area&nbsp;and more than 3000 that use our products in 76 different countries, Xpand IT is recognized for its technological knowledge and “<strong>Passion for Excellence</strong>”.</p><p>At Xpand IT,&nbsp;<strong>everyone has a special talent</strong>. We value everyone’s talent in all fields. Excellent technical experts, visionary designers,&nbsp;dynamic and communicative Human Resources team, innovative researchers, magical marketers, entrepreneurial managers. These are the people that are part of&nbsp;<strong>Xpand IT.<br></strong></p><p><strong>ABOUT THE JOB</strong></p><p>As a JavaScript Full-stack Developer you will&nbsp;<strong>build the end-to-end applications requirements</strong>. You will participate in the central structure of an application as well as<strong>&nbsp;create design plans for the user interface, define controls’ look, feel and activity.</strong>&nbsp;At Xpand IT you will work with JavaScript technologies in a collaborative environment alongside other experts such as UI/UX and cluster/database gurus.<br></p><p><strong>JOB DESCRIPTION / ACTIVITIES</strong></p><ul><li><strong>Being responsible for requirements definition</strong>&nbsp;and translate them into technical services</li><li>Use / suggest a variety of state-of-the-art programming languages in order to&nbsp;<strong>create user-friendly web interfaces</strong></li><li>Design and build&nbsp;<strong>high-quality mockups</strong>&nbsp;and design different prototypes</li><li>Optimize web applications for&nbsp;maximum speed, cross-browser and cross-device</li><li><strong>Build reusable API libraries</strong>&nbsp;for future use</li><li>Work in multidisciplinary&nbsp;teams&nbsp;with other teammates such as&nbsp;backend developers&nbsp;and&nbsp;web designers</li><li>Design and development of<strong>&nbsp;applicational backend services</strong>&nbsp;using the best design practices and patterns</li><li>Recommends system solutions by&nbsp;comparing advantages and disadvantages&nbsp;of alternative development strategies</li><li>Integrates applications through the&nbsp;<strong>development of APIs / Services</strong>&nbsp;with third-party modules</li><li>Guarantee the correct&nbsp;<strong>performance, security and scalability of backend services</strong></li><li>Guarantee that&nbsp;<strong>Unit Test / Test Sets</strong>&nbsp;are correctly updated so that Continuous Integration engine remains flawless.<br><br></li></ul><p><span contenteditable="false" data-mce-object="iframe" class="mce-preview-object mce-object-iframe" data-mce-p-allowfullscreen="allowfullscreen" data-mce-p-src="//www.youtube.com/embed/EvUbt7fpU5A"><iframe src="//www.youtube.com/embed/EvUbt7fpU5A" allowfullscreen="allowfullscreen" width="560" height="314" frameborder="0"></iframe><span class="mce-shim"></span></span></p><p>&nbsp;<br></p>',
#   'title': 'JavaScript Full-stack Developer',
#   'created_at': '2017-04-07T12:03:21.341Z',
#   'updated_at': '2021-10-08T00:00:31.662Z',
#   'published_at': '2020-12-28T14:38:00.024Z',
#   'type': 'Full-time',
#   'remote': True,
#   'tags': ['React',
#    'AngularJS',
#    'SQL Server',
#    'Scrum',
#    'Node.js',
#    'JavaScript'],
#   'url': 'https://landing.jobs/at/xpand-it/javascript-full-stack-developer-in-lisbon-2020'},
#  {'id': 5524,
#   'city': 'Berlin',
#   'company_id': 2502,
#   'country_code': 'DE',
#   'country_name': 'Germany',
#   'currency_code': 'EUR',
#   'expires_at': '2021-10-19',
#   'main_requirements': '* Experience in C++ (we use C++11 features like lambdas and rvalue references throughout our codebase and switch to C++14 where our compilers support it)\r\n* Bachelor´s Degree or higher\r\n* Advanced English level',
#   'nice_to_have': '',
#   'perks': "* healthy work-life balance - we do not work at night or on weekends\r\n* support of our staff's families with a full-time company nanny - she is available for free when children are sick, or when you just feel like spending an evening out\r\n* competitive salaries + EUR 120,000 annually following one year of employment\r\n* help with Relocation and work permit\r\n* International and diverse Team\r\n* German language courses\r\n* Food, drinks, snack around the office",
#   'referral_value': '300.0',
#   'relocation_paid': True,
#   'role_description': '**About us**\r\n\r\nthink-cell is the leading developer of graphics software to improve professional slide production in Microsoft PowerPoint. Our software automates the creation of charts and layouts to make working with PowerPoint easier, faster, and more enjoyable.\r\n\r\nWe have published scientific articles in the areas of Artificial Intelligence and Computer Graphics and we will encourage you to do the same. We sponsor visits to conferences and have close relationships with universities and research institutes in the U.S. and Germany.\r\n\r\n**Your role**\r\n\r\nWe are looking for smart, creative developers with a solid theoretical background.\r\n\r\n* You will work largely independently and will be responsible for the whole range of activities when implementing a new feature\r\n* You will be in control of your own work. Instead of splitting different activities between several people, you will involved in all: architecture, design, implementation, customer feedback and bug fixing\r\n* You should be able to look at a problem from the user\'s perspective and discuss abstract concepts with fellow developers\r\n\r\n<span contenteditable="false" data-mce-object="iframe" class="mce-preview-object mce-object-iframe" data-mce-p-allowfullscreen="allowfullscreen" data-mce-p-src="//www.youtube.com/embed/SX6vGFLghJo"><iframe src="//www.youtube.com/embed/SX6vGFLghJo" allowfullscreen="allowfullscreen" width="560" height="314" frameborder="0"></iframe> <span class="mce-shim"></span></span>\r\n\r\n* * *',
#   'title': 'C++ Developer',
#   'created_at': '2018-05-25T15:11:24.712Z',
#   'updated_at': '2021-10-08T00:00:21.440Z',
#   'published_at': '2020-03-05T11:21:27.975Z',
#   'type': 'Full-time',
#   'remote': False,
#   'gross_salary_low': 75000,
#   'gross_salary_high': 120000,
#   'tags': ['Software Development', 'C++'],
#   'url': 'https://landing.jobs/at/think-cell/c-developer-in-berlin'},
#  {'id': 5694,
#   'city': 'Berlin',
#   'company_id': 2593,
#   'country_code': 'DE',
#   'country_name': 'Germany',
#   'currency_code': 'EUR',
#   'expires_at': '2021-10-24',
#   'main_requirements': '<ul><li>At least 5 years of software development experience in agile teams</li><li>3+ years of experience building modular frontends utilising&nbsp;react (or other modern frameworks)</li><li>2+ years of experience leading software development teams</li><li>2+ years of experience designing microservice applications utilising nodeJS / express<br></li><li>Excellent knowledge of MongoDB and one other common SQL or NoSQL database technology such as Cassandra or MySQL/MariaDB</li><li>Infrastructure knowledge including REST APIs, Search Technologies like Solr/Lucene</li><li>Good programming skills in at least 1 more modern programming language/ framework</li><li>Working knowledge of tools like Gulp, npm, Jenkins</li><li>Working knowledge of DevOps, Docker, NGINX</li><li>Experience with at least one unit testing framework, such as JUnit</li></ul>',
#   'nice_to_have': '* German language skills are a plus',
#   'perks': '<ul><li>Beautiful, spaceous office</li><li>Flat hierarchies, quick decisionmaking process</li><li>A stable and secure environment at a market-leading company</li><li>PTO, employee pension schemes, discounts for various activities</li><li>free, voluntary german language courses</li><li>regular teamevents and hackathons</li><li>relocation support</li></ul>',
#   'referral_value': '300.0',
#   'relocation_paid': True,
#   'role_description': '*Disclaimer: All company details and specific procedures will be revealed when you start your application process!*\r\n\r\n**What we do:**\r\n\r\nWe are the second largest furniture retailer in Europe. With us you will operate highly complex ecommerce platforms across multiple european markets to drive our online presence further.\r\n\r\nYou will join 100 IT colleagues hailing from more than 20 nations in our newly opened, spaceous Berlin office, which oversees our entire IT operations for all of europe.\r\n\r\n**What you will do:**\r\n\r\no Contribute across the full technology stack, from database, infrastructure that supports deployments to Front-end development. As a Software Developer you will work in an agile cross-functional team with the Product Owners, Designers and Software Testers to drive our Online Shops and other digital products forward.\r\n\r\no Development of Front-end features based on MVC Design Pattern\r\n\r\no Creating views/templates and styles in our Atomic Design Methodology\r\n\r\no Implementing client side JavaScript\r\n\r\no Developing Application side controller logic\r\n\r\no Collaborating with backend developers to design REST APIs and Data Models\r\n\r\no Further Development of our Content Management Systems including Data Models, GUIs and integration of new features and tools in our ecosystem\r\n\r\no Creating Unit Tests and supporting the Testing & QA Team with UI Tests\r\n\r\no Consulting the Product Owners in architectural and technological decisions to ensure that we stay on the leading edge of technology',
#   'title': 'Teamlead JavaScript',
#   'created_at': '2018-06-19T13:42:48.324Z',
#   'updated_at': '2021-10-08T00:00:28.358Z',
#   'published_at': '2020-11-18T11:24:50.023Z',
#   'type': 'Full-time',
#   'remote': False,
#   'gross_salary_low': 60000,
#   'gross_salary_high': 75000,
#   'tags': ['Team Management',
#    'Team Leadership',
#    'JavaScript',
#    'DevOps',
#    'REST APIs',
#    'Databases',
#    'Node.js',
#    'React'],
#   'url': 'https://landing.jobs/at/landing-partner-de-99d6b69b-02bd-4e6c-8863-9d0475e065ca/teamlead-javascript'},
#  {'id': 7376,
#   'city': 'Berlin',
#   'company_id': 2965,
#   'country_code': 'DE',
#   'country_name': 'Germany',
#   'currency_code': 'EUR',
#   'expires_at': '2021-11-02',
#   'main_requirements': '<ul><li>Practical experience with "Infrastructure as Code" and CI/CD tools as well as development of deployment pipelines</li><li>Passion and interest in new technologies and subjects revolving around Linux and Cloud</li><li>Good experience with container technologies like Kubernetes, Docker, AWS, and Puppet.</li><li>You are comfortable with configuration management systems like Ansible, Chef, Puppet</li><li>Expertise with Java based applications</li><li>Programming skills in Java or Python and Bash</li><li>Flexibility, trustworthiness, team collaboration, and&nbsp;self-sufficiency</li></ul>',
#   'nice_to_have': '<ul><li>Speak German at least at a beginner level<br></li></ul>',
#   'perks': '<ul><li>the possibility to include your own ideas in order to reach the goal in your team</li><li>Work-Life-Balance with flexible working hours and a family-friendly nature</li><li>Flat hierarchies with open and quick&nbsp;</li><li>Great possibilities for education and training</li><li>Fresh fruit, breakfast, drinks, team events, and more.<br></li><li>30 days vacation</li></ul>',
#   'referral_value': '300.0',
#   'relocation_paid': True,
#   'role_description': '<ul><li>Establish and maintain automated processess which improve development and operations - Cloud applications as well as on premise infrastructures</li><li>As member of the Platform-team you are responsible to establish and ensure the availability and scalability of the infrastructure</li><li>You optimise and automated deployment processes</li></ul>',
#   'title': 'Senior DevOps Engineer',
#   'created_at': '2018-12-18T17:05:21.381Z',
#   'updated_at': '2021-10-08T00:00:35.393Z',
#   'published_at': '2020-11-24T11:15:38.312Z',
#   'type': 'Full-time',
#   'remote': False,
#   'gross_salary_low': 55000,
#   'gross_salary_high': 65000,
#   'tags': ['Chef',
#    'Puppet',
#    'Ansible',
#    'Python',
#    'Java',
#    'Docker',
#    'Amazon Web Services',
#    'Kubernetes'],
#   'url': 'https://landing.jobs/at/2965/senior-devops-engineer-in-berlin-2020'},
#  {'id': 7426,
#   'city': 'Berlin',
#   'company_id': 147,
#   'country_code': 'DE',
#   'country_name': 'Germany',
#   'currency_code': 'EUR',
#   'expires_at': '2021-11-26',
#   'main_requirements': '<ul><li style="font-weight: 400;" data-mce-style="font-weight: 400;">University degree in Computer Science, Engineering, Information Systems or related fields or equivalent practical experience</li><li style="font-weight: 400;" data-mce-style="font-weight: 400;">Familiar working with Microservices in the AWS-Cloud</li><li style="font-weight: 400;" data-mce-style="font-weight: 400;">Professional&nbsp; Java experience</li><li style="font-weight: 400;" data-mce-style="font-weight: 400;">Understanding, dissecting and influencing business requirements in order to find a suitable technological solution is one of your core competencies</li><li style="font-weight: 400;" data-mce-style="font-weight: 400;">Good understanding and practical experience in working in an agile environment using test-driven development and continuous integration and delivery</li><li style="font-weight: 400;" data-mce-style="font-weight: 400;">Writing clean, testable, maintainable and well documented code comes naturally - we strongly believe in Uncle Bob</li><li style="font-weight: 400;" data-mce-style="font-weight: 400;">You are comfortable participating in technical and architectural discussions</li><li style="font-weight: 400;" data-mce-style="font-weight: 400;">You are an open-minded and creative team player willing to continue creating our culture</li><li style="font-weight: 400;" data-mce-style="font-weight: 400;">Great English communication skills</li></ul>',
#   'nice_to_have': '',
#   'perks': '<p>At Raisin, we care about each other and it is one of our top priorities to foster an open and caring environment in which everyone feels welcome and comfortable. Our culture is strongly driven by our ambitious team, which, connects more than 40 different nationalities. As part of our team in Berlin, you will benefit from<br></p><ul><li>Relocation and visa support as well as a relocation reimbursement</li><li>Personal training budget of 1,700 € and four full training days</li><li>Free choice of hardware<br></li><li>Stay up to date at regular townhall sessions with our founders and feel free to ask any kinds of questions</li><li>Flexible working hours, home office and 28 vacation days&nbsp;</li><li>Enjoy more than 50+ different sports with Urban Sports Club: We subsidize your membership with more than 20 € per month&nbsp;</li><li>We offer you a company pension scheme (Betriebliche Altersvorsorge), which we support with 20%<br></li></ul>',
#   'referral_value': '300.0',
#   'relocation_paid': False,
#   'role_description': '<p>We are Raisin, a dynamic and fast-growing fintech company with its headquarters in Berlin. Together, we built a marketplace offering our customers simple, transparent access to deposits across Europe. In addition, in Germany, we also provide ETF portfolios as well as pension products. In the US, we are also offering a Savings as a Service model for bank partners.</p><p><br>We raised more than € 195 million in funding from investors including Goldman Sachs, PayPal Ventures, Index Ventures, btov Ventures, Ribbit Capital, Orange Digital Ventures and Thrive Capital.<br></p><p><br data-mce-bogus="1"></p><p>For further development and expansion of our successful business, Raisin is looking for highly motivated, smart and driven engineers to complement our team in Berlin. As a Java developer here, you will be working on our online banking system together with an international team of top developers.</p><ul><li style="font-weight: 400;" data-mce-style="font-weight: 400;">Providing core services and high quality solutions for a large scale online platform and everything related to the online banking system</li><li style="font-weight: 400;" data-mce-style="font-weight: 400;">Integrating externally developed components into existing application environments</li><li style="font-weight: 400;" data-mce-style="font-weight: 400;">Together with the rest of the team, setting standards, establishing guidelines and sharing best practices in order to ensure continuous learning and development as well as stable solutions for our customers.</li></ul>',
#   'title': 'Software Engineer (Back-end) (m/f/d)',
#   'created_at': '2019-01-07T18:08:20.275Z',
#   'updated_at': '2021-10-08T00:00:26.378Z',
#   'published_at': '2020-09-02T10:42:12.712Z',
#   'type': 'Full-time',
#   'remote': False,
#   'tags': ['Microservices',
#    'Amazon Web Services',
#    'MySQL',
#    'Java',
#    'Continuous Integration',
#    'Test Driven Development'],
#   'url': 'https://landing.jobs/at/raisin/software-engineer-back-end-m-f-d'},
#  {'id': 7642,
#   'city': 'Hamburg',
#   'company_id': 3095,
#   'country_code': 'DE',
#   'country_name': 'Germany',
#   'currency_code': 'EUR',
#   'expires_at': '2021-12-01',
#   'main_requirements': '<!--block--><p><strong>Who you are<br></strong><br></p><ul><li><!--block-->Very good &amp; MVP-focused coding skills in PHP7 of minimum 3 years (Medior-Level) //&nbsp; 5 years (Senior-Level)</li><li><!--block-->Practical &amp; recent experience with MVC Frameworks like Laravel, Symfony, Zend or Yii2</li><li><!--block-->Deep technical understanding of RESTful API’s</li><li><!--block-->Solid background in building scalable distributed products and practical experience with Caching</li><li><!--block-->Previous experience with handling &amp; querying relational databases (e.g. MySQL, MariaDB or PostgreSQL)</li><li><!--block-->Passionate about writing well-structured, efficient and maintainable code, actively keeping the quality of the code base in check</li><li><!--block-->Comfortable working in an English-speaking&nbsp; &amp; agile environment</li></ul><!--block--><p><br></p>',
#   'nice_to_have': '',
#   'perks': '<ul><li><!--block-->Grow together with one of the fastest growing eCommerce companies in Europe</li><li><!--block-->Flexible working times<br></li><li><!--block-->Fresh fruits + drinks everywhere</li><li><!--block-->Language courses (German &amp; English)</li><li><!--block-->Free sports courses &amp; reduced price for gym membership</li><li><!--block-->Subsidized public transportation ticket</li><li><!--block-->Free choice of hardware and operating system (Mac, Windows, Linux) also for private usage</li><li><!--block-->State-of-the-art tech stack running on AWS<br></li><li><!--block-->Company flats (subject to availability)</li><li><!--block-->Agile work environment (MOVE) and cross-functional teams</li><li><!--block-->Free access to Germany’s greatest developer conference code.talks</li><li><!--block-->German health insurance included</li><li><!--block-->Company pension scheme</li><li><!--block-->Help in relocation and VISA process</li></ul>',
#   'referral_value': '300.0',
#   'relocation_paid': True,
#   'role_description': '<div><!--block-->We are looking for <strong>(Senior) Backend PHP Developers</strong> to join one of our Tech Teams at ABOUT YOU. Our Tech Department is the heart of ABOUT YOU, driven by the passion to develop the best infrastructure &amp; applications. You will work on high-scalable products on a cloud-based infrastructure and collaborate with developers who constantly challenge themselves to raise the bar of what is “state of the art” technology.<br><br></div><div><!--block--><br>Leap to the next level in your career and shape the online shopping experience of millions of customers by building the best shop infrastructure.<br><br><strong>What you will do<br></strong><br></div><ul><li><!--block-->Work on high-scalable products with PHP7 hosted on a cloud-based infrastructure</li><li><!--block-->Build and provide internal &amp; external RESTful APIs that ensure a fast &amp; frictionless updating of our backend products</li><li><!--block-->Develop multiple backend platforms ranging from high throughput to maximum faultlessness</li><li><!--block-->Constantly challenge and expand your knowledge of reliable software architecture, programming and new technologies</li><li><!--block-->Work with agile processes that are adapted to the team’s and project’s needs</li><li><!--block-->Exchange your knowledge with other developers and be part of our ABOUT YOU TECH community</li></ul>',
#   'title': '(Senior) Back-end PHP Developer',
#   'created_at': '2019-02-15T14:34:29.140Z',
#   'updated_at': '2021-10-08T00:00:27.276Z',
#   'published_at': '2020-03-22T20:41:01.501Z',
#   'type': 'Full-time',
#   'remote': False,
#   'tags': ['Symfony', 'Laravel', 'Databases', 'MVC', 'REST APIs', 'PHP'],
#   'url': 'https://landing.jobs/at/about-you-gmbh/senior-back-end-php-developer-in-hamburg'},
#  {'id': 7710,
#   'city': 'Lisbon',
#   'company_id': 322,
#   'country_code': 'PT',
#   'country_name': 'Portugal',
#   'currency_code': 'EUR',
#   'expires_at': '2021-11-11',
#   'main_requirements': '<ul><li>Development in languages such as&nbsp;<strong>Java or Kotlin</strong></li><li><strong>Solid Android</strong>&nbsp;development experience</li><li>Understanding of Design Patterns and Object Oriented Design</li><li>Knowledge of Android App Architecture</li><li>Experience working with&nbsp;<strong>Restful APIs</strong></li><li>Practical knowledge of network protocols and challenges with latency and reliability</li><li>Demonstrable knowledge of coding involving&nbsp;<strong>multithreading</strong>, request queueing and caching</li><li>Continuous Integration/Deployment tools and processes</li><li>Ability to work well in a team, self-driven and eager to learn</li><li>Creative thinking, analytical skills, with attention to detail</li><li>Fluent in English</li><li>Lisbon based</li></ul>',
#   'nice_to_have': '',
#   'perks': '<p><br data-mce-bogus="1"></p>',
#   'referral_value': '300.0',
#   'relocation_paid': False,
#   'role_description': "<p><!--block--></p><p>In the UK &amp; Ireland, <strong>Sky</strong> has been making entertainment better for over 27 years. We’re part of Europe’s leading entertainment company with over 21 million customers across five countries and are now starting our operations in Portugal. Delivering Sky’s mix of TV that people love, pioneering technology, award-winning service and super-fast broadband is a genuine team effort. Across our business, whether in front of the camera or behind the scenes, we’re always looking for new ways to make things better for our customers.<br></p><p><!--block--></p><p>We’re always looking to improve by developing pioneering products and services which give every one of our customers experiences they’ll love. Join us as a&nbsp;<strong>Senior&nbsp;</strong><strong>Mobile Developer (Android)&nbsp;</strong>and you'll be part of a dynamic team that makes sure our technology delivers the best experience for our customers.</p><p><strong>Your Key Responsibilities</strong>:</p><ul><li>Develop excellent quality software using agile techniques</li><li>Design clean and reliable code</li><li>Deliver highly scalable and highly reliable products (yes, our customers expect 99.999% availability)</li><li>Collaborate with other developers, sharing and receiving knowledge</li><li>Promote best technology and software development practices into the team with passion and enthusiasm</li><li>Contribute to the whole development cycle, analysis, implementation, testing and operation \u202f&nbsp;</li><li>Operation excellence and support are part of the development teams’ responsibility</li></ul>",
#   'title': 'Mobile Developer (Android)',
#   'created_at': '2019-03-04T11:07:38.200Z',
#   'updated_at': '2021-10-08T00:00:19.642Z',
#   'published_at': '2020-10-29T17:21:43.920Z',
#   'type': 'Full-time',
#   'remote': False,
#   'tags': ['Kotlin', 'Android', 'Java', 'Mobile Applications', 'REST APIs'],
#   'url': 'https://landing.jobs/at/sky-technology-centre-portugal/mobile-developer-android-in-lisbon'},
#  {'id': 7879,
#   'city': 'Hamburg',
#   'company_id': 3095,
#   'country_code': 'DE',
#   'country_name': 'Germany',
#   'currency_code': 'EUR',
#   'expires_at': '2021-10-22',
#   'main_requirements': '<div><!--block--><strong>Who you are<br></strong><br></div><ul><li><!--block-->Very good &amp; MVP-focused coding skills in JavaScript of minimum 3 years (Medior-Level) //&nbsp; 5 years (Senior-Level)</li><li><!--block-->Practical &amp; recent experience with JS Frameworks like React, React Native or Vue.js</li><li><!--block-->Comfortable working with TypeScript or ES6</li><li><!--block-->Solid background in building complex customer-facing products coming along with excellent analytical and problem-solving skills</li><li><!--block-->Passionate about writing well-structured, efficient and maintainable code, actively keeping the quality of the code base in check</li><li><!--block-->Used to work in an English speaking environment</li></ul><div><!--block--><br></div>',
#   'nice_to_have': '',
#   'perks': '<p>&nbsp;</p><ul><li>Flexible working times</li><li><!--block-->40% discount on our online shop</li><li><!--block-->Fresh fruits + drinks everywhere</li><li><!--block-->Language courses (German &amp; English)</li><li><!--block-->Free sports courses &amp; reduced price for gym membership</li><li><!--block-->Subsidized public transportation ticket</li><li><!--block-->Free choice of hardware and operating system (Mac, Windows, Linux) also for private usage</li><li><!--block-->State-of-the-art tech stack running on AWS</li><li><!--block-->Modern office in the city center of Hamburg</li><li><!--block-->International working environment and English as company language</li><li><!--block-->Company flats (subject to availability)</li><li><!--block-->Agile work environment (MOVE) and cross-functional teams</li><li><!--block-->Free access to Germany’s greatest developer conference code.talks</li><li><!--block-->German health insurance included</li><li><!--block-->Company pension scheme</li></ul>',
#   'referral_value': '300.0',
#   'relocation_paid': True,
#   'role_description': '<div><!--block-->We are currently looking for a skilled &amp; passionate <strong>(Senior) Frontend Developer</strong> to become part of one of our Tech Teams at ABOUT YOU!<br><br>All Tech Teams are driven by the dedication to deliver high-scalable applications shaped by a lean and intuitive user interface that ensures the best possible user experience. Your work will impact the future of how eCommerce is experienced by millions of customers.</div><div><!--block--><br>Jump to the next career step and unlock the future potential of frontend development by constantly challenging your tech know-how with us!<br><br></div><div><!--block--><br><br><strong>What you will do<br></strong><br></div><ul><li><!--block-->Build high traffic user interfaces with JavaScript and React/React Native or Vue.js</li><li><!--block-->Work on the implementation of high-leverage features to optimize UX and conversion rates</li><li><!--block-->Cooperate with skilled developers, product managers, QA’s, and designers to ship new components and features</li><li><!--block-->Draft architectural decisions together with the Tech Lead and explore new technologies</li><li><!--block-->Have a direct impact on team processes by regular agile retrospectives</li><li><!--block-->Exchange your knowledge with other developers and be part of our ABOUT YOU TECH community</li></ul>',
#   'title': '(Senior) Front-end Developer',
#   'created_at': '2019-03-27T12:18:43.932Z',
#   'updated_at': '2021-10-08T00:00:27.335Z',
#   'published_at': '2020-03-22T20:41:11.131Z',
#   'type': 'Full-time',
#   'remote': False,
#   'tags': ['Vue.js', 'React', 'TypeScript', 'React Native', 'JavaScript'],
#   'url': 'https://landing.jobs/at/about-you-gmbh/senior-front-end-developer-in-hamburg-2019'},
#  {'id': 8346,
#   'city': 'Lisbon',
#   'company_id': 2651,
#   'country_code': 'PT',
#   'country_name': 'Portugal',
#   'currency_code': 'EUR',
#   'expires_at': '2022-01-26',
#   'main_requirements': '<p><strong>You are a great candidate if you have:<br></strong></p><ul><li>Passion for what you do;</li><li>You are a flexible person when it comes to technologies – You choose the best tool for the job;</li><li>By now, you already know how to adapt to new situations;</li><li>You are aware of your feelings and other people’s emotions and how you can work together;</li><li>You know how to communicate verbally and in writing and you always have a positive intent.</li></ul><p><strong>Nice to Have:</strong></p><ul><li>Experience working in a&nbsp;<strong>Product team</strong>&nbsp;(previous experience deploying software into production);</li><li>Experience with&nbsp;<strong>JVM</strong>&nbsp;technologies (namely: Java, Scala, or Kotlin);</li><li>Experience with&nbsp;<strong>Streaming</strong>&nbsp;technologies, like Kafka, RabbitMQ, or Flink;</li><li>Experience in&nbsp;<strong>RESTful API</strong>&nbsp;development;</li><li>Experience with&nbsp;<strong>NoSQL</strong>;</li><li>Deep understanding of Application and&nbsp;<strong>Infrastructure</strong>&nbsp;Design in a&nbsp;<strong>Cloud</strong>&nbsp;Environment;</li><li>Previous experience with&nbsp;<strong>Containers</strong>&nbsp;(Docker, Kubernetes);</li><li>Fluent with unit&nbsp;<strong>testing</strong>, automated integration, and load tests, CI/CD pipelines;</li><li>Experience in&nbsp;<strong>Mentoring</strong>&nbsp;/ Coaching others</li></ul>',
#   'nice_to_have': '<p class="p1"><br></p>',
#   'perks': '<p><u>You’ll enjoy the perks of a balanced work-life</u></p><ul><li>You’ll receive a fair salary that reflects the job market, your experience, and your impact;</li><li>You and your family will receive health insurance;</li><li>You’ll have work-life flexibility: we are a remote-first company. This means we trust you with&nbsp;<em>when</em>&nbsp;and&nbsp;<em>where</em>&nbsp;you work from: from our office in the city center, from Alentejo or from your home country. We want to give you the flexibility you need&nbsp;<em>and&nbsp;</em>keep our great office culture, so we do in-person team events in the office every once in a while;</li><li>Oh, and of course, you’ll get some discounts on Mercedes rentals and acquisition.</li></ul><p><br data-mce-bogus="1"></p><p>&lt;center&gt;<strong>So… do you have what it takes to become a tb.lxer?</strong><strong>&nbsp;Apply now!</strong></p><p><br data-mce-bogus="1"></p><p>To know more about us visit our&nbsp;<a href="https://medium.com/tblx-insider" target="_blank" rel="noopener noreferrer" data-mce-href="https://medium.com/tblx-insider">Medium</a>,&nbsp;<a href="https://www.linkedin.com/company/tblx/" data-mce-href="https://www.linkedin.com/company/tblx/">LinkedIn</a>&nbsp;and&nbsp;<a href="https://www.instagram.com/wearetblx/?hl=en" data-mce-href="https://www.instagram.com/wearetblx/?hl=en">Instagram</a>&lt;/center&gt;</p>',
#   'referral_value': '300.0',
#   'relocation_paid': True,
#   'role_description': '<p>Hey there,</p><p><br></p><p>The world is changing right before our eyes, and we are changing with it. It hasn’t been rainbows and sunshine all the time. We have been challenged, and we have persevered. We stuck together and we kept growing. We reinvented how we work best in collaboration in a remote setup, coming to a healthy remote-first working mode.</p><p><br></p><p><strong>What do we do?</strong></p><p>We are trusted to build the best software products in e-mobility, and pave the way for sustainable transportation. Curious to know more? Keep reading!</p><p>As a corporate startup, we are spearheading innovation within our mother company Daimler Trucks &amp; Buses. Our mission is to develop data-driven solutions for the transportation of&nbsp;<s>tomorrow</s>&nbsp;today: connected, electric and sustainable. Here, your code is more than code. You have an impact on the way goods and people move, on the environment, and on the world we’re creating for future generations.</p><p><br></p><p><strong>&lt;center&gt;Are you in?&lt;/center&gt;</strong></p><p><br></p><p>We’re looking for a bold and driven&nbsp;<strong>Backend Engineer</strong><strong>&nbsp;to&nbsp;</strong>help us create a sustainable future of transportation. Keep scrolling to read all the important must-haves and key responsibilities.</p><p><br></p><p><strong>What your day-to-day work will be like:</strong></p><ul><li>Develop exciting projects with the latest technologies (Java, Scala, Kotlin, Python is our tech stack);</li><li>Implement RESTful APIs to serve data and integrate them with API management tools;</li><li>Align with Data Engineers to define data schemas on the serving layer databases;</li><li>Align with Frontend developers and data consumers in general for API requirements;</li><li>Implement CI/CD pipelines;</li><li>Eventually, you will have to fix some bugs, right? This is not Disneyland 😁</li></ul><p><br data-mce-bogus="1"></p><p><strong>Now that you</strong><strong>&nbsp;know what we are looking for,&nbsp;</strong><strong>here’s what’s in it for you:</strong></p><p><u>You’ll learn and grow technically</u></p><ul><li>You’ll work in an experienced engineering team, mainly composed of seniors who are humble and ready to help you learn;</li><li>You’ll be backed up by leadership that walks the talk:</li><li>You’ll have access to trainings according to your learning and growth needs.</li></ul>',
#   'title': 'Software Engineer - Backend Focus',
#   'created_at': '2019-06-27T15:10:56.603Z',
#   'updated_at': '2021-10-08T00:00:29.334Z',
#   'published_at': '2021-06-07T10:39:10.739Z',
#   'type': 'Full-time',
#   'remote': False,
#   'tags': ['REST APIs',
#    'Python',
#    'Test Driven Development',
#    'Cloud Computing',
#    'SQL',
#    'Docker',
#    'MongoDB',
#    'Java',
#    'Kotlin',
#    'Scala'],
#   'url': 'https://landing.jobs/at/tb-lx-by-daimler-trucks-buses/software-engineer-backend-focus-in-lisbon'},
#  {'id': 8954,
#   'city': 'Frankfurt',
#   'company_id': 147,
#   'country_code': 'DE',
#   'country_name': 'Germany',
#   'currency_code': 'EUR',
#   'expires_at': '2021-10-17',
#   'main_requirements': '<p><strong>Dein Profil:</strong></p><ul><li>Du hast dein Studium in Informatik, Wirtschaftsinformatik oder einem ähnlichen Feld erfolgreich abgeschlossen</li><li>Du verfügst über mindestens zwei Jahre Berufserfahrung im Software Engineering und kennst Dich bestens mit serverless Cloud Services aus</li><li>Du hast Erfahrung in agiler Softwareentwicklung und siehst in Software Engineering und FinTech deinen nächsten, langfristigen Karriereschritt</li><li>Dich reizt es hands on als Entwickler unserer Banking as a Service Produkte zu arbeiten</li><li>Du sprichst Deutsch verhandlungssicher und Englisch fließend</li><li>Du verfügst über solide Erfahrungen mit Javascript sowie RESTful API Design, Testautomatisierung, AWS API Gateway, AWS Lambda, OpenAPI/Swagger, Jira, Confluence, Git, Gitflow</li><li>Du bist motiviert, behältst immer einen kühlen Kopf und bist ein echter Teamplayer</li><li>Erfahrungen im IT Bereich von Banking oder FinTech sind von Vorteil<br></li></ul>',
#   'nice_to_have': '<div><!--block-->Banking, Financial Services</div>',
#   'perks': '<div><!--block-->Als Teil der Raisin-Familie vereint die Raisin Bank das Beste aus beiden Welten:<br>die Erfahrung und Sicherheit einer Bank mit der Flexibilität und Innovationskraft eines Start-ups.<br>Wenn du ein dynamisches Umfeld suchst, in dem du deine Stärken ausspielen und dich weiterentwickeln kannst, dann bist du bei uns richtig!&nbsp;</div><div><!--block-->Mit dem Ansatz “We build it, we own it” sorgst du gemeinsam mit unserem IT und Produkt Team dafür, dass wir langfristig der optimale Partner für Europas Fintechs und Banken sind.&nbsp;<br>Unsere Benefits:<br>&nbsp;</div><ul><li><!--block-->Wir übernehmen die Beiträge der hauseigenen Altersvorsorge</li><li><!--block-->Gleitzeitmodell und 30 Tage Urlaub</li><li><!--block-->Verpflegungszuschuss für das tägliche Mittagessen</li><li><!--block-->Wir übernehmen die Kosten für deine RMV-Jahreskarte am Stadtgebiet Frankfurt&nbsp;</li></ul>',
#   'referral_value': '300.0',
#   'relocation_paid': False,
# ...
#   'expires_at': '2021-10-15',
#   'main_requirements': '<div><!--block-->&nbsp;<strong>Qualifications and what you should bring:<br></strong><br></div><ul><li><!--block-->Experienced Project Leader for modern architectures in complex multi-channel SPAs&nbsp;</li><li><!--block-->Integration of graphical user interfaces with backend service landscapes</li><li><!--block-->Love your work and move things forward to deliver the best product. #TechFirst!&nbsp;</li><li><!--block-->Mentoring / Coaching / Hiring experience</li><li><!--block-->English communication skills, German is not necessary!</li></ul>',
#   'nice_to_have': '',
#   'perks': '<ul><li><!--block-->100% REMOTE WORK POSSIBLE // optional Berlin office</li><li><!--block-->flexible work hours // 30 days paid vacation&nbsp;</li><li><!--block-->Paid relocation package</li><li><!--block-->Individual development budget for training, conferences, etc.</li><li><!--block-->Team events &amp; company benefits</li><li><!--block-->Sports &amp; Fitness cooperation, drinks, snacks &amp; fresh fruits</li></ul><div><!--block--><br></div>',
#   'referral_value': '300.0',
#   'relocation_paid': True,
#   'role_description': '<div><!--block-->Think <strong>UNICORN </strong>and develop <strong>THE</strong> new <strong>Cloud Streaming Platform </strong>for Music, TV, Movies, Podcasts, ebooks, radio etc. - <strong>All in ONE!</strong> --&gt; <strong>Competing with Netflix and Amazon is ambitious?</strong> <strong>Hell yeah! ...</strong>but trust us, we got the<strong> network, </strong>the <strong>power</strong> and the <strong>money</strong> of the <strong>biggest content players!</strong>&nbsp;<br><br></div><ul><li><!--block-->We just started from scratch - now we need the passion, the ownership and the skills from the best Techies in the world!</li></ul><div><!--block--><strong>Our goal:</strong> Building a platform that matters and growing to 150 people in tech within 1 year&nbsp;<br><br></div><div><!--block--><strong>Techs:</strong></div><ul><li><!--block-->React. js, Vue.js, GraphQL</li><li><!--block-->TypeScript</li><li><!--block-->Node.js, TDD</li><li><!--block-->Backend: Kotlin, Python cloud-native microservices</li></ul><div><!--block--><br></div><div><!--block--><strong>Our Dev Culture: <br>#RemoteFirst</strong>&nbsp;</div><ul><li><!--block-->International, cross-functional remote teams with a "you build it, you run it" attitude &nbsp;</li><li><!--block-->Work autonomously and agile in a creative environment - you are the driving engine!</li><li><!--block-->Personalized development strategy for individual and professional growth</li><li><!--block-->Flexible working hours, optional office in central Berlin</li><li><!--block-->English communication and discussion culture&nbsp;</li></ul>',
#   'title': 'Senior / Lead JavaScript Engineer (m/f/x)',
#   'created_at': '2020-08-20T12:38:01.585Z',
#   'updated_at': '2021-10-08T00:00:18.152Z',
#   'published_at': '2020-08-21T14:29:59.805Z',
#   'type': 'Full-time',
#   'remote': True,
#   'gross_salary_low': 75000,
#   'gross_salary_high': 95000,
#   'tags': ['Python',
#    'Kotlin',
#    'HTML',
#    'GraphQL',
#    'Node.js',
#    'JavaScript',
#    'TypeScript',
#    'React',
#    'CSS'],
#   'url': 'https://landing.jobs/at/avantgarde-creating-fans/senior-lead-javascript-engineer-m-f-x'},
#  {'id': 10740,
#   'city': 'Berlin',
#   'company_id': 1465,
#   'country_code': 'DE',
#   'country_name': 'Germany',
#   'currency_code': 'EUR',
#   'expires_at': '2021-10-15',
#   'main_requirements': '<div><!--block-->&nbsp;<strong>Qualifications and what you should bring:</strong></div><ul><li><!--block-->JVM, Backend, Architecture Expert +5 years</li><li><!--block-->Expert in hiring and leading teams in cloud native &amp; complex microservice environments <strong>(hands-on if you like)</strong></li><li><!--block-->Love your work and move things forward to deliver the best product. #TechFirst!</li><li><!--block-->Creativity: Take over responsibility and shape the future of our platform with your ideas</li><li><!--block-->English Communication skills are key!&nbsp;</li><li><!--block-->Mentoring / Coaching / Hiring experience&nbsp;</li></ul>',
#   'nice_to_have': '',
#   'perks': '<ul><li><!--block-->100% REMOTE WORK POSSIBLE // optional Berlin office</li><li><!--block-->flexible work hours // 30 days paid vacation&nbsp;</li><li><!--block-->Paid relocation package</li><li><!--block-->Individual development budget for training, conferences, etc.</li><li><!--block-->Team events &amp; company benefits</li><li><!--block-->Sports &amp; Fitness cooperation, drinks, snacks &amp; fresh fruits</li></ul><div><!--block--><br></div><div><!--block--><br></div><div><!--block--><br></div><div><!--block--><br></div>',
#   'referral_value': '300.0',
#   'relocation_paid': True,
#   'role_description': '<div><!--block-->Think <strong>UNICORN </strong>and develop <strong>THE</strong> new <strong>Cloud Streaming Platform </strong>for Music, TV, Movies, Podcasts, ebooks, radio etc. - <strong>All in ONE!</strong> --&gt; <strong>Competing with Netflix and Amazon is ambitious?</strong> <strong>Hell yeah! ...</strong>but trust us, we got the<strong> network, </strong>the <strong>power</strong> and the <strong>money</strong> of the <strong>biggest content players!</strong>&nbsp;<br><br></div><ul><li><!--block-->We just started from scratch - now we need the passion, the ownership and the skills from the best Techies in the world!</li></ul><div><!--block--><strong>Our goal:</strong> Building a platform that matters and growing to 150 people in tech within 1 year!<br><br></div><div><!--block--><strong>Techs:</strong></div><ul><li><!--block-->Kotlin SpringBoot Microservices in the cloud&nbsp;</li><li><!--block-->Python (for some "Data Magic")</li><li><!--block-->Kubernetes, Terraform, TDD, CI/CD</li><li><!--block-->Frontend: TypeScript, React, Vue, GraphQL&nbsp;</li></ul><div><!--block--><br></div><div><!--block--><strong>Our Dev Culture: <br>#RemoteFirst</strong>&nbsp;</div><ul><li><!--block-->International, cross-functional remote teams with a "you build it, you run it" attitude &nbsp;</li><li><!--block-->Work autonomously and agile in a creative environment - you are the driving engine!</li><li><!--block-->Personalized development strategy for individual and professional growth</li><li><!--block-->Flexible working hours, optional office in central Berlin</li><li><!--block-->English communication and discussion culture&nbsp;</li></ul>',
#   'title': 'Teamlead / Tech Manager (m/f/x) Cloud Streaming Platform',
#   'created_at': '2020-08-20T13:02:24.050Z',
#   'updated_at': '2021-10-08T00:00:23.435Z',
#   'published_at': '2020-08-21T14:29:46.874Z',
#   'type': 'Full-time',
#   'remote': True,
#   'gross_salary_low': 85000,
#   'gross_salary_high': 110000,
#   'tags': ['Docker',
#    'Kubernetes',
#    'Amazon Web Services',
#    'JavaScript',
#    'Java',
#    'Kotlin',
#    'Python'],
#   'url': 'https://landing.jobs/at/avantgarde-creating-fans/teamlead-tech-manager-m-f-x-cloud-streaming-platform'},
#  {'id': 10743,
#   'city': 'Lisbon',
#   'company_id': 389,
#   'country_code': 'PT',
#   'country_name': 'Portugal',
#   'currency_code': 'EUR',
#   'expires_at': '2022-02-13',
#   'main_requirements': "<ul><li><!--block-->Advanced knowledge of HTML5, knowledge about HTTP, Rest and JSON, alongside CSS3/SASS and Javascript (ES6) to develop new features and modules.</li><li><!--block-->Having extended knowledge of building JS apps using React and Redux.&nbsp;</li><li><!--block-->You're passionate for beautiful, test-driven code and an eye for simplicity and pragmatism</li><li><!--block-->Implementing a CI\\CD environment while working to also create and maintaining pipelines guidelines.</li><li><!--block-->Experience working with monitoring tools;</li><li><!--block-->Experience in SEO&nbsp;</li></ul>",
#   'nice_to_have': '<ul><li><!--block-->Experience with monitoring tools;</li><li><!--block-->Experience working with legacy code and monolith while handling migrations;</li><li><!--block-->Experience with Performance and Scalability</li></ul>',
#   'perks': '<ul><li><!--block-->Unique opportunity to become a part of an international team of top engineers learning from one another and contributing to the global Naspers Classifieds success, based in Lisbon but chipping in on all Classifieds websites in Europe and around the world</li><li><!--block-->Great place to learn and develop within fast-growing, global classifieds leader which opens further career opportunities in a diverse world of OLX and Naspers</li><li><!--block-->Fun and informal environment where getting stuff done and enjoying the ride is far more important than rules and hierarchies</li><li><!--block-->We offer a fixed salary plus other benefits like health insurance, company self-service, food supply, bonus system for good performance, and others</li></ul><div><!--block--><br></div><div><!--block--><br></div><div><!--block--><br></div>',
#   'referral_value': '300.0',
#   'relocation_paid': False,
#   'role_description': "<ul><li><!--block-->Research, suggest and implement new solutions to our problem domain</li><li><!--block-->Contribute to scaling our platform to the next level of modularity &amp; share-ability while working on architecture, tools, standards, and practices for the European engineering organisation</li><li><!--block-->Developing and maintaining a service with billions of page views per month</li><li><!--block-->You'll become an evangelist in assuring the quality practices that bring longevity and success of the product</li><li><!--block-->Along with the teams, you'll lead in building scalable products in a fast release environment</li></ul>",
#   'title': 'Front-end Engineer',
#   'created_at': '2020-08-21T11:14:46.636Z',
#   'updated_at': '2021-10-08T00:00:14.134Z',
#   'published_at': '2021-03-08T10:34:53.353Z',
#   'type': 'Full-time',
#   'remote': True,
#   'tags': ['Redux',
#    'SASS',
#    'JSON',
#    'SEO',
#    'Performance Testing',
#    'React',
#    'JavaScript'],
#   'url': 'https://landing.jobs/at/olx-group/front-end-engineer-in-lisbon-2020-8-21'},
#  {'id': 10744,
#   'city': 'Lisbon',
#   'company_id': 389,
#   'country_code': 'PT',
#   'country_name': 'Portugal',
#   'currency_code': 'EUR',
#   'expires_at': '2022-02-13',
#   'main_requirements': '<ul><li><!--block-->Experience building and scaling High-Traffic Web Applications</li><li><!--block-->Good knowledge of containers and containers orchestration, such as Kubernetes</li><li><!--block-->Proven background on Linux/Unix Systems</li><li><!--block-->Good Knowledge on Amazon Web Services ecosystem</li><li><!--block-->Proficiency on Configuration Management Frameworks such as Ansible, Puppet, Chef or Salt</li><li><!--block-->Expertise with one or more programming languages: Python, Go</li></ul>',
#   'nice_to_have': '',
#   'perks': "<ul><li><!--block-->Unique opportunity to become a part of international teams, learning from one another, and contributing to the global OLX Group success.</li><li><!--block-->An excellent place to learn and develop within fast-growing, global classifieds' leader which opens further career opportunities in a diverse world of OLX and Prosus.</li><li><!--block-->Competitive salary and awesome benefits</li><li><!--block-->Company Mobile phone and any tool you might need a MacBook Pro/ Notebook/ PC</li></ul><div><!--block--><br></div>",
#   'referral_value': '300.0',
#   'relocation_paid': False,
#   'role_description': '<ul><li><!--block-->Support a Global Distributed Classifieds Platform Evolution (scalability, HA, deployment, performance)</li><li><!--block-->Architect, build and implement infrastructure services to enable our distributed platform growth</li><li><!--block-->Advocate sensible, scalable, systems design and share responsibility within the organization in diagnosing, resolving, and preventing production issues through mechanisms like automation</li><li><!--block-->Automate as much as humanly possible and always configure as code</li><li><!--block-->Take operational responsibility for the services that we own, including taking part in an on-call rotation, practice balanced incident response and blameless postmortems</li></ul><div><!--block--><br></div>',
#   'title': 'Site Reliability Engineer',
#   'created_at': '2020-08-21T11:57:59.535Z',
#   'updated_at': '2021-10-08T00:00:32.846Z',
#   'published_at': '2020-08-24T09:05:26.885Z',
#   'type': 'Full-time',
#   'remote': True,
#   'tags': ['Agile',
#    'Ansible',
#    'Amazon Web Services',
#    'Linux',
#    'Go',
#    'Kubernetes',
#    'Python',
#    'CI/CD'],
#   'url': 'https://landing.jobs/at/olx-group/site-reliability-engineer-in-lisbon-2020-8'},
#  {'id': 10759,
#   'city': 'Porto',
#   'company_id': 1885,
#   'country_code': 'PT',
#   'country_name': 'Portugal',
#   'currency_code': 'EUR',
#   'expires_at': '2021-12-19',
#   'main_requirements': '<ul><li><!--block-->Engineer mentality: passion about solving highly complex challenges;&nbsp;</li><li><!--block-->Architecture-oriented engineer;</li><li><!--block-->Unafraid of stepping out of your comfort zone;</li><li><!--block-->Solid experience in the development of native Android applications;</li><li><!--block-->Comfortable with all stages of software development: from Software Architecture design to testing and deployment;</li><li><!--block-->Ability to write clean and optimized code;</li><li><!--block-->Good verbal and written English skills.</li></ul>',
#   'nice_to_have': '<ul><li><!--block-->Experience in C++ is a big plus;</li><li><!--block-->Experience with card present transaction protocols (E.g. EMV/Nexo/ISO8583);</li><li><!--block-->Experience with Python/Django/Javascript;</li><li><!--block-->Experience with Microservices and Docker.</li></ul>',
#   'perks': '<ul><li><!--block-->Work with people passionate about solving high complex tech challenges;&nbsp;</li><li><!--block-->Impact on the product and culture;</li><li><!--block-->Modern technologies and low tech debt;</li><li><!--block-->Progress fast! We promote ownership, doesn’t matter years of experience nor age;&nbsp;</li><li><!--block-->Flexible environment and work life balance - as well as good team environment;&nbsp;</li><li><!--block-->The Switch Kit: Macbook Pro and others;</li><li><!--block-->Health insurance with dental plan;&nbsp;</li><li><!--block-->Spotify and Netflix;</li><li><!--block-->Daily transportation Braga &lt;&gt; Porto Office for someone who lives in Braga.&nbsp;</li></ul>',
#   'referral_value': '300.0',
#   'relocation_paid': False,
#   'role_description': '<p>If you are a talented and passionate Android Software Engineer, not afraid of stepping out of your comfort zone, yearning to learn with the best, and have a giant impact... We have a challenge for you.&nbsp;<br><br>At Switch we have the challenge to build a product that it’s huge and must be scalable to match the most use cases possible. Furthermore, it also needs to be reliable to process millions of transactions for some of the largest merchants/retailers in the world, complying with extremely critical security rules.<br><strong></strong></p><p><br data-mce-bogus="1"></p><p><strong>Your role:&nbsp;</strong></p><ul><li>Develop new features and apps across our Android POS payment platform;</li><li>Manage integrations with different payment stakeholders / terminal manufacturers;</li><li>Improve the quality of our current Android POS payment products while staying true to both Android and Switch’s design principles;</li><li>Ensure the scalability of all current and new features;</li><li>Guarantee as much compatibility as possible with other non-Android POS payment ecosystems.</li></ul>',
#   'title': 'Android Software Engineer',
#   'created_at': '2020-08-25T08:01:20.421Z',
#   'updated_at': '2021-10-08T00:00:31.626Z',
#   'published_at': '2020-08-26T16:29:08.108Z',
#   'type': 'Full-time',
#   'remote': True,
#   'gross_salary_low': 28000,
#   'gross_salary_high': 42000,
#   'tags': ['Web Development',
#    'C++',
#    'C',
#    'Docker',
#    'Django',
#    'Python',
#    'Android'],
#   'url': 'https://landing.jobs/at/switch/android-software-engineer-in-porto-2020'}]

# %%
import requests
from w3lib.html import remove_tags
from datetime import date
from util import save_data_to_json


class LandingJobs():
    def __init__(self):
        self.session = requests.Session()
        self.results = 'break'
        self.company = {'name': ''}
    
    def getJobsList(self, limit=50, offset=0):
        response = self.session.get(f'https://landing.jobs/api/v1/jobs?limit={limit}&offset={offset}')
        if response.status_code == 200:
            self.results = response.json()

    def getCompanyInfo(self, id):
        response = self.session.get(f'https://landing.jobs/api/v1/companies/{id}')
        if response.status_code == 200:
            self.company = response.json()

# %%
def handleResults(results, L):
    """
    This function handles the json output from the API call.
    :parameter: results -> json response
    :parameter: L -> LandingJobs Class
    """
    job_offer = []

    for job in results:
        if job['country_code'] == 'PT':
            job_description = remove_tags(job['main_requirements']+'\n'+job['nice_to_have']+'\n'+job['perks']+'\n'+job['role_description'])
            L.getCompanyInfo(id=job['company_id'])
            company = L.company['name']

            try:
                salary = str(job['gross_salary_low'])+' - '+str(job['gross_salary_high'])
            except KeyError:
                salary = ''

            job_offer.append({
                'job_title': job['title'],
                'job_description': job_description, 
                'post_date': job['published_at'], 
                'scrape_date': date.today().strftime("%d/%m/%Y"),
                'company': company,
                'job_location': job['city'],
                'job_category': 'IT',
                'job_ref': job['url'],
                'salary': salary,
            })

    return job_offer

# %%
L = LandingJobs()
job_offers = []
for i in range(0, 1000, 50):
    L.getJobsList(limit=50, offset=i)
    if L.results == 'break':
        break
    else:
        job_offers += handleResults(results=L.results, L=L)
        print(job_offers)

save_data_to_json("C:/Users/gilnr/OneDrive - NOVASBE/Work Project/Code/Job Vacancies Data/LandingJobsIT_jobs", job_offers)

# %%
job_offers
# Out:
# [{'job_title': 'Java Full-stack Developer',
#   'job_description': 'MSc / BSc in Information Systems and Computer Engineering&nbsp;and/or Computer Science&nbsp;Advanced knowledge on Linux&nbsp;operating systems&nbsp;Large&nbsp;Experience (3+ years)&nbsp;as Java based technology full stack developer/Engineer.&nbsp;Strong Experience&nbsp;while developing with&nbsp;JavaScript&nbsp;and its superset,&nbsp;Typescript&nbsp;Deep understanding of web markup, including&nbsp;HTML&nbsp;and CSS&nbsp;Experience with&nbsp;JavaScript libraries and frameworks such as&nbsp;and&nbsp;/or&nbsp;Angular&nbsp;Experience with&nbsp;Java based technologies&nbsp;(JBoss, Tomcat, Glassfish Spring Boot, Spring MVC, Hibernate)&nbsp;Experience of&nbsp;design patterns&nbsp;while&nbsp;implementing&nbsp;advanced&nbsp;and complex&nbsp;software solutions.&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Experience with&nbsp;relational databases&nbsp;(MS&nbsp;SQL&nbsp;Server, MySQL,&nbsp;PostgreSQL&nbsp;etc.)&nbsp;Experience in design patterns while implementing&nbsp;large scale&nbsp;and complex software solutions.&nbsp;Strong experience in using&nbsp;Eclipse, Maven, Jenkins, GIT, JIRA&nbsp;or equivalent tools&nbsp;Strong communication skills&nbsp;(written and spoken).&nbsp;\nKnowledge or experience with&nbsp;Docker/Kubernetes&nbsp;ecosystemKnowledge or experience with&nbsp;microservices based architecturesTeam player&nbsp;and problem solving skills\nBesides a competitive salary and a variable bonus program according to the performance, we have a number of other benefits:Flexible work hours and partial remote workRelaxed work environmentFruit and coffee availableHealth insuranceTraining plan, adjusted to individual needsSocial and team building eventsAreas for leisure within the facilities\nABOUT US&nbsp;Everything we do is to&nbsp;inspire others&nbsp;to achieve outstanding results. We do this by investing in IT mastery to generate market value. As a global company specializing in&nbsp;Big Data,&nbsp;Business Intelligence &amp; Analytics,&nbsp;Data Science,&nbsp;Middleware,&nbsp;Digital&nbsp;Xperiences, and&nbsp;Collaboration and Development tools, we have top products and services used by Fortune 500 companies.&nbsp;With a posture of honesty and cooperation with more than 180 clients in the service area&nbsp;and more than 3000 that use our products in 76 different countries, Xpand IT is recognized for its technological knowledge and&nbsp;“Passion for Excellence”.At Xpand IT,&nbsp;everyone has a special talent. We value everyone’s talent in all fields. Excellent technical experts, visionary designers,&nbsp;dynamic and communicative Human Resources team, innovative researchers, magical marketers, entrepreneurial managers. These are the people that are part of&nbsp;Xpand IT.&nbsp;ABOUT THE JOBAs a Java Full-stack developer you will build the end-to-end interactions within web and software applications. As part of your mission, you’ll design plans for the user interface, define controls’&nbsp;look &amp; feel and&nbsp;activity. You’ll&nbsp;also structure the backbone&nbsp;part of an application, which manages program middleware&nbsp;logic&nbsp;and database server(s)&nbsp;interactions. Full-stack developers understand what&nbsp;happens&nbsp;between these two (or more) layers and have the set of software skills needed to work on both.&nbsp;At Xpand IT, full-stack developers are&nbsp;also&nbsp;problem-solvers who work in a fast-paced, collaborative environment alongside other experts such as UI/UX and cluster/database gurus.&nbsp;JOB DESCRIPTION/ACTIVITIESUse /&nbsp;suggest a variety of&nbsp;state-of-the-art programming languages in order to create user-friendly web interfaces&nbsp;Design and build&nbsp;high-quality mockups and design different prototypes.&nbsp;Optimize web applications&nbsp;for maximum speed, cross-browser and cross-device&nbsp;Build reusable code and libraries for future use&nbsp;Work in a multidisciplinary\u202fteam with other teammates such as backend developers and web designers&nbsp;Being Responsible for&nbsp;requ ...
#   'post_date': '2020-05-13T09:01:28.506Z',
#   'scrape_date': '08/10/2021',
#   'company': 'Xpand IT',
#   'job_location': 'Lisbon',
#   'job_category': 'IT',
#   'job_ref': 'https://landing.jobs/at/xpand-it/java-full-stack-developer-in-lisbon-2020',
#   'salary': ''},
#  {'job_title': 'JavaScript Full-stack Developer',
#   'job_description': 'MSc / BSc in Information Systems and Computer Engineering&nbsp;and/or Computer ScienceProfessional experience (+ 3 years)&nbsp;as a&nbsp;Developer in JavaScript-based technologies, HTML5 and CSS3Experience with JavaScript libraries and frameworks such as&nbsp;React and /or AngularExperience with backend JavaScript frameworks such as&nbsp;Node.jsExperience in&nbsp;design patterns while implementing advanced&nbsp;and complex software solutions, namely in API Rest services implementationExperience in data base management tools like&nbsp;MS SQL Server, MySQL or PostgreSQLExperience in using&nbsp;Eclipse, Maven, Jenkins, GIT, JIRA&nbsp;or equivalent toolsTeam player&nbsp;and technical problem solving skillsStrong communication skills&nbsp;(written and spoken)English proficiency\n\nBesides a competitive salary and a variable bonus program according to the performance, we have a number of other benefits:Flexible work hours and partial remote workRelaxed work environmentFruit and coffee availableHealth insuranceTraining plan, adjusted to individual needsOpportunity to work on challenging projects in different locationsSocial and team building eventsAreas for leisure within the facilitiesProtocols and other local benefits\nABOUT US…Everything we do is to&nbsp;inspire others to&nbsp;achieve outstanding results.&nbsp;We do this by investing in IT mastery to generate market value. As a global company specializing in&nbsp;Big Data,&nbsp;Business Intelligence &amp; Analytics,&nbsp;Data Science,&nbsp;Middleware,&nbsp;Digital Xperiences, and&nbsp;Collaboration and Development tools, we have top products and services used by Fortune 500 companies.&nbsp;With a posture of honesty and cooperation with more than 180 clients in the service area&nbsp;and more than 3000 that use our products in 76 different countries, Xpand IT is recognized for its technological knowledge and “Passion for Excellence”.At Xpand IT,&nbsp;everyone has a special talent. We value everyone’s talent in all fields. Excellent technical experts, visionary designers,&nbsp;dynamic and communicative Human Resources team, innovative researchers, magical marketers, entrepreneurial managers. These are the people that are part of&nbsp;Xpand IT.ABOUT THE JOBAs a JavaScript Full-stack Developer you will&nbsp;build the end-to-end applications requirements. You will participate in the central structure of an application as well as&nbsp;create design plans for the user interface, define controls’ look, feel and activity.&nbsp;At Xpand IT you will work with JavaScript technologies in a collaborative environment alongside other experts such as UI/UX and cluster/database gurus.JOB DESCRIPTION / ACTIVITIESBeing responsible for requirements definition&nbsp;and translate them into technical servicesUse / suggest a variety of state-of-the-art programming languages in order to&nbsp;create user-friendly web interfacesDesign and build&nbsp;high-quality mockups&nbsp;and design different prototypesOptimize web applications for&nbsp;maximum speed, cross-browser and cross-deviceBuild reusable API libraries&nbsp;for future useWork in multidisciplinary&nbsp;teams&nbsp;with other teammates such as&nbsp;backend developers&nbsp;and&nbsp;web designersDesign and development of&nbsp;applicational backend services&nbsp;using the best design practices and patternsRecommends system solutions by&nbsp;comparing advantages and disadvantages&nbsp;of alternative development strategiesIntegrates applications through the&nbsp;development of APIs / Services&nbsp;with third-party modulesGuarantee the correct&nbsp;performance, security and scalability of backend servicesGuarantee that&nbsp;Unit Test / Test Sets&nbsp;are correctly updated so that Continuous Integration engine remains flawless.&nbsp;',
#   'post_date': '2020-12-28T14:38:00.024Z',
#   'scrape_date': '08/10/2021',
#   'company': 'Xpand IT',
#   'job_location': 'Lisbon',
#   'job_category': 'IT',
#   'job_ref': 'https://landing.jobs/at/xpand-it/javascript-full-stack-developer-in-lisbon-2020',
#   'salary': ''},
#  {'job_title': 'Mobile Developer (Android)',
#   'job_description': "Development in languages such as&nbsp;Java or KotlinSolid Android&nbsp;development experienceUnderstanding of Design Patterns and Object Oriented DesignKnowledge of Android App ArchitectureExperience working with&nbsp;Restful APIsPractical knowledge of network protocols and challenges with latency and reliabilityDemonstrable knowledge of coding involving&nbsp;multithreading, request queueing and cachingContinuous Integration/Deployment tools and processesAbility to work well in a team, self-driven and eager to learnCreative thinking, analytical skills, with attention to detailFluent in EnglishLisbon based\n\n\nIn the UK &amp; Ireland, Sky has been making entertainment better for over 27 years. We’re part of Europe’s leading entertainment company with over 21 million customers across five countries and are now starting our operations in Portugal. Delivering Sky’s mix of TV that people love, pioneering technology, award-winning service and super-fast broadband is a genuine team effort. Across our business, whether in front of the camera or behind the scenes, we’re always looking for new ways to make things better for our customers.We’re always looking to improve by developing pioneering products and services which give every one of our customers experiences they’ll love. Join us as a&nbsp;Senior&nbsp;Mobile Developer (Android)&nbsp;and you'll be part of a dynamic team that makes sure our technology delivers the best experience for our customers.Your Key Responsibilities:Develop excellent quality software using agile techniquesDesign clean and reliable codeDeliver highly scalable and highly reliable products (yes, our customers expect 99.999% availability)Collaborate with other developers, sharing and receiving knowledgePromote best technology and software development practices into the team with passion and enthusiasmContribute to the whole development cycle, analysis, implementation, testing and operation \u202f&nbsp;Operation excellence and support are part of the development teams’ responsibility",
#   'post_date': '2020-10-29T17:21:43.920Z',
#   'scrape_date': '08/10/2021',
#   'company': 'Sky Technology Centre – Portugal',
#   'job_location': 'Lisbon',
#   'job_category': 'IT',
#   'job_ref': 'https://landing.jobs/at/sky-technology-centre-portugal/mobile-developer-android-in-lisbon',
#   'salary': ''},
#  {'job_title': 'Software Engineer - Backend Focus',
#   'job_description': 'You are a great candidate if you have:Passion for what you do;You are a flexible person when it comes to technologies – You choose the best tool for the job;By now, you already know how to adapt to new situations;You are aware of your feelings and other people’s emotions and how you can work together;You know how to communicate verbally and in writing and you always have a positive intent.Nice to Have:Experience working in a&nbsp;Product team&nbsp;(previous experience deploying software into production);Experience with&nbsp;JVM&nbsp;technologies (namely: Java, Scala, or Kotlin);Experience with&nbsp;Streaming&nbsp;technologies, like Kafka, RabbitMQ, or Flink;Experience in&nbsp;RESTful API&nbsp;development;Experience with&nbsp;NoSQL;Deep understanding of Application and&nbsp;Infrastructure&nbsp;Design in a&nbsp;Cloud&nbsp;Environment;Previous experience with&nbsp;Containers&nbsp;(Docker, Kubernetes);Fluent with unit&nbsp;testing, automated integration, and load tests, CI/CD pipelines;Experience in&nbsp;Mentoring&nbsp;/ Coaching others\n\nYou’ll enjoy the perks of a balanced work-lifeYou’ll receive a fair salary that reflects the job market, your experience, and your impact;You and your family will receive health insurance;You’ll have work-life flexibility: we are a remote-first company. This means we trust you with&nbsp;when&nbsp;and&nbsp;where&nbsp;you work from: from our office in the city center, from Alentejo or from your home country. We want to give you the flexibility you need&nbsp;and&nbsp;keep our great office culture, so we do in-person team events in the office every once in a while;Oh, and of course, you’ll get some discounts on Mercedes rentals and acquisition.&lt;center&gt;So… do you have what it takes to become a tb.lxer?&nbsp;Apply now!To know more about us visit our&nbsp;Medium,&nbsp;LinkedIn&nbsp;and&nbsp;Instagram&lt;/center&gt;\nHey there,The world is changing right before our eyes, and we are changing with it. It hasn’t been rainbows and sunshine all the time. We have been challenged, and we have persevered. We stuck together and we kept growing. We reinvented how we work best in collaboration in a remote setup, coming to a healthy remote-first working mode.What do we do?We are trusted to build the best software products in e-mobility, and pave the way for sustainable transportation. Curious to know more? Keep reading!As a corporate startup, we are spearheading innovation within our mother company Daimler Trucks &amp; Buses. Our mission is to develop data-driven solutions for the transportation of&nbsp;tomorrow&nbsp;today: connected, electric and sustainable. Here, your code is more than code. You have an impact on the way goods and people move, on the environment, and on the world we’re creating for future generations.&lt;center&gt;Are you in?&lt;/center&gt;We’re looking for a bold and driven&nbsp;Backend Engineer&nbsp;to&nbsp;help us create a sustainable future of transportation. Keep scrolling to read all the important must-haves and key responsibilities.What your day-to-day work will be like:Develop exciting projects with the latest technologies (Java, Scala, Kotlin, Python is our tech stack);Implement RESTful APIs to serve data and integrate them with API management tools;Align with Data Engineers to define data schemas on the serving layer databases;Align with Frontend developers and data consumers in general for API requirements;Implement CI/CD pipelines;Eventually, you will have to fix some bugs, right? This is not Disneyland 😁Now that you&nbsp;know what we are looking for,&nbsp;here’s what’s in it for you:You’ll learn and grow technicallyYou’ll work in an experienced engineering team, mainly composed of seniors who are humble and ready to help you learn;You’ll be backed up by leadership that walks the talk:You’ll have access to trainings according to your learning and growth needs.',
#   'post_date': '2021-06-07T10:39:10.739Z',
#   'scrape_date': '08/10/2021',
#   'company': 'tb.lx by Daimler Trucks & Buses',
#   'job_location': 'Lisbon',
#   'job_category': 'IT',
#   'job_ref': 'https://landing.jobs/at/tb-lx-by-daimler-trucks-buses/software-engineer-backend-focus-in-lisbon',
#   'salary': ''},
#  {'job_title': 'QA Engineer',
#   'job_description': 'two or more years of professional software testing experiencebachelor’s degree in Computer Science or a related fieldsignificant experience and skills in software-testing tools, including defect-tracking softwarestrong analytical, problem-solving, and judgment skillsfull grasp of client-server architecturegood knowledge of English, both spoken and written\n\nDevexperts employees create the art of FinTech in comfortable working spaces, located in modern business centers around the world. Join our team in Porto and enjoy:Flexible schedulesPossibility to work remotelyPaid vacation 22 daysInsurance coverage (for you and your children)Partial reimbursement for fitness membershipsMeal vouchers providedSnacks and beverages always availableWork spaces with modern equipment\nDevexperts has been working for nearly two decades consulting and developing for the financial industry.&nbsp; We solve complex technological challenges facing the most well-respected financial institutions worldwide.&nbsp;By becoming a part of Devexperts, you’ll become a part of a company that fosters self-improvement and actively seeks out-of-the-box ideas. Our teams work together to create the next generation of financial software solutions. We welcome all candidates who believe, as we do, that innovation is grounded in education.We are looking for a Quality Assurance Engineer to join our team. As a Quality Assurance Engineer, you are part of a Software Development Team, responsible for the full lifecycle of an application.&nbsp; You will perform testing of web and mobile applications&nbsp;in an Agile-driven environment.We expect the QA Engineer to:develop a testing strategy based on the project requirements and scheduledesign, develop, and execute test cases using project specificationspromptly report the defects found in testing diligently, promptly and accurately using standard defect tracking toolsreport test progress against schedulesprovide test summary reports on the quality attributes of the tested softwarecommunicate with development, project management, and customer stakeholders when necessarytest new functionality and perform regression testingperform manual and automated testing as determined by the project guidelines',
#   'post_date': '2020-11-13T17:18:20.536Z',
#   'scrape_date': '08/10/2021',
#   'company': 'Devexperts',
#   'job_location': 'Porto',
#   'job_category': 'IT',
#   'job_ref': 'https://landing.jobs/at/devexperts/qa-engineer-in-porto-2020',
#   'salary': ''},
#  {'job_title': 'Senior Back-end Engineer',
#   'job_description': "&nbsp;4+ years experience with Node.js. The Fidel API is written in Node.jsYou are able to write high-quality code in a programming language (e.g. Javascript, Go, Scala);You have a deep familiarity across cutting-edge technologies, know large scale data, distributed systems, micro-services, messaging/queuing systems, AWS Serverless architecture: Lambda, DynamoDB, API Gateway, SNS.You have worked in multiple cloud environments and understand the problems developers face when working on cloud infrastructure in an enterprise environment: AWSAs an early-stage company, we're most interested in engineering leaders who understand how to craft raw software projects into compelling user-facing products.You have worked on and helped lead a large project to success and understand the day-to-day intricacies of working in an agile collaboration environment.Experience working and communicating with a remote team in an effective asynchronous way.\nComfortable in a dynamic startup environment where change is constant and you will be largely self-guided.Clear, enthusiastic and communicator. Able to lead and inspire teams and our customers.\nWe're committed to making Fidel a fantastic place to work and we go to great lengths to give you what you need to succeed. You’ll receive:Share options - you’re part of Fidel’s success. So why not share (excuse the pun) the rewards!Unlimited leaveFlexible working - work from home or abroad when you need toHealth insuranceA fully stocked kitchen with unlimited snacks &amp; refreshmentsFriday team lunch &amp; drinksDinner if you need to work lateUnlimited budget for any software or books you need\nOur mission at Fidel API is to unlock the full potential of payment cards. We offer a suite of financial infrastructure APIs that enable developers to build programmable experiences connected to purchases made in real-time using a card. Our tools are transforming how merchants and users interact by powering real-time, event-driven engagements, best-in-class loyalty and rewards programs and revolutionizing processes from reimbursements to expense management.Our APIs are used by start-ups through global enterprises including Google, British Airways, TopCashback, Perkbox, Royal Bank of Canada, and Blackhawk Networks, and are supported by the world’s largest card networks, including Visa, Mastercard and American Express.Launched in 2018, Fidel is headquartered in London, with offices in Lisbon, New York, and remote employees globally. Fidel is backed by investors including Nyca Partners, QED Investors, Citi Ventures, RBC Capital and Commerce Ventures.We're in an incredibly exciting period of growth as we continue to scale internationally and are looking for an experienced&nbsp;Back-end Engineer&nbsp;who wants to be part of this journey.What you'll do:Design and build the core of the Fidel APIDesign reliable, fault-tolerant micro-service architectures largely written in Node.jsDesign and build integrations with third parties to add new value-added servicesAutomate safely deploying software, utilizing CI and unit/integration testingKnow how to prevent breaking changes, discovering solutions that are backward compatibleMaintain and nurture a cohesive architecture on a rapidly expanding startupGuide and manage our engineering partnerships with our clients, facilitating collaboration and integration strategiesShare and spread your expertise through contributions to our blog and speaking at conferencesContribute and help guide the open-source community behind Fidel",
#   'post_date': '2021-07-28T08:42:06.369Z',
#   'scrape_date': '08/10/2021',
#   'company': 'Fidel',
#   'job_location': 'Lisbon',
#   'job_category': 'IT',
#   'job_ref': 'https://landing.jobs/at/fidel/senior-back-end-engineer-in-lisbon-2020-5',
#   'salary': ''},
#  {'job_title': 'Back-end Developer',
#   'job_description': "We hope you haveAt least 3 years working with Java 8+ and/or development experience of a high concurrency/high transactional platform;Experience working with Kafka and message queueing systems;Knowledge of Scala, Akka, memcached, Apache Storm, Apache Cassandra, ZooKeeper;Used to work with Client-server protocols such as SOAP, REST;Experience of using established design patterns;Awareness and experience in using agile methodologies\n\nWhat you can expect3 extra days of vacationFlexAppeal – Flexible Hours and possibility to work from homeDoctor, masseuse, nutritionist and ergonomist at the officeHealth insurance for employee+spouse+childrenMobile AllowanceChoose your Operating System (Windows or macOS)Own your laptop and accessories after 3 years in the companyCSR – 2 social days allowanceTraining and CertificationFully provisioned kitchen with free breakfast and coffee breaksCommunity groupsSports TrainingShowers and Locker RoomsPartnerships discountsTeambuilding budget + activitiesInternal International Opportunities (between Porto, London, Dublin, Cluj, Malta, New York, Orlando, Los Angeles, Edinburgh and Glasgow)&nbsp;\nWhat you are going to doAs a Backend Engineer, you are part of a Software Development Team, responsible for the full lifecycle of an application. Reporting to a Delivery Manager in a FanDuel team formed by 5 Developers and 1 QA, you will be using cutting-edge technologies to deliver amazing value to our customers, while scaling our platform to meet the demands of the US market. You will be required to programming well-designed, testable, efficient code to solve business needs, as well as testing and documenting the implemented solutions. You will have a bias for action and can break down complex problems into steps that drive the scalability, performance and stability of our platform.Key responsibilitiesTeam player on an Agile team, working together to keep delivering at pace, scale and with demanded quality to support our productsExecute full software development life cycleDevelop flowcharts, layouts and documentation to support the Product Owner with requirements and the team with solutionsWrite well-designed, testable and efficient codeProduce specifications and determine operational feasibilityIntegrate software components into a fully functional software systemDevelop unit, component and integrated tests, with the guidance of team's QADocument and maintain software functionalityTroubleshoot, debug and upgrade existing systemsDeploy applications in a Continuous Integration platformEnsure software is updated with latest features / versions in a timely manner",
#   'post_date': '2020-03-27T12:53:11.370Z',
#   'scrape_date': '08/10/2021',
#   'company': 'Blip',
#   'job_location': 'Porto',
#   'job_category': 'IT',
#   'job_ref': 'https://landing.jobs/at/blip/back-end-developer-in-porto-2020-3',
#   'salary': ''},
#  {'job_title': 'Senior Back-end Developer',
#   'job_description': "We hope you haveAt least 6 years working with Java 8+ and/or development experience of a high concurrency/high transactional platformExperience working with Kafka and message queueing systemsKnowledge of Scala, Akka, memcached, Apache Storm, Apache Cassandra, ZooKeeperUsed to work with Client-server protocols such as SOAP and RESTExperience of using established design patternsAwareness and experience in using agile methodologies\n\nWhat you can expect3 extra days of vacationFlexAppeal – Flexible Hours and possibility to work from homeDoctor, masseuse, nutritionist and ergonomist at the officeHealth insurance for employee+spouse+childrenMobile AllowanceChoose your Operating System (Windows or macOS)Own your laptop and accessories after 3 years in the companyCSR – 2 social days allowanceTraining and CertificationFully provisioned kitchen with free breakfast and coffee breaksCommunity groupsSports TrainingShowers and Locker RoomsPartnerships discountsTeambuilding budget + activitiesInternal International Opportunities\nWhat you are going to doAs a Backend Engineer, you are part of a Software Development Team, responsible for the full lifecycle of an application. Reporting to a Delivery Manager in a FanDuel team formed by 5 Developers and 1 QA, you will be using cutting-edge technologies to deliver amazing value to our customers, while scaling our platform to meet the demands of the US market. You will be required to programming well-designed, testable, efficient code to solve business needs, as well as testing and documenting the implemented solutions. You will have a bias for action and can break down complex problems into steps that drive the scalability, performance and stability of our platform.&nbsp;Key responsibilitiesTeam player on an Agile team, working together to keep delivering at pace, scale and with demanded quality to support our productsExecute full software development life cycleDevelop flowcharts, layouts and documentation to support the Product Owner with requirements and the team with solutionsWrite well-designed, testable and efficient codeProduce specifications and determine operational feasibilityIntegrate software components into a fully functional software systemDevelop unit, component and integrated tests, with the guidance of team's QADocument and maintain software functionalityTroubleshoot, debug and upgrade existing systemsDeploy applications in a Continuous Integration platformEnsure software is updated with latest features / versions in a timely manner",
#   'post_date': '2020-03-27T12:57:06.817Z',
#   'scrape_date': '08/10/2021',
#   'company': 'Blip',
#   'job_location': 'Porto',
#   'job_category': 'IT',
#   'job_ref': 'https://landing.jobs/at/blip/senior-back-end-developer-in-porto-2020-3',
#   'salary': ''},
#  {'job_title': 'DevOps Manager',
#   'job_description': "We hope you haveAt least 5 years of proven track record of leading and managing teams on complex engineering projects, using agile methodologiesWorking with distributed, redundant and transactional systems and the quality assurance of theseExperience working with Cloud Infrastructures and Cloud Automation solutions/toolsManaging the development of a team by ensuring that project tasks are in line with each team member’s defined career path, as much as possibleUsing defect tracking systemsStrong analytical and diagnostic skills, particularly with regard to technical risks, issues and constraintsStrong leader and energetic motivatorWork well under time and environmental pressuresDemonstrate senior principles, leading by example, showing work ethic and passionate, professional attitudeProven track of project managementExcellent written and verbal communication skills (English and Portuguese)Team player, who strives to maximize team performanceBSc or Masters in Computer Science or equivalent demonstrable knowledge\n\nWhat you can expect3 extra days of vacationFlexAppeal – Flexible Hours and possibility to work from homeDoctor, masseuse, nutritionist and ergonomist at the officeHealth insurance for employee + spouse + childrenMobile AllowanceChoose your Operating System (Windows or macOS)Own your laptop and accessories after 3 years in the companyCSR – 2 social days allowanceTraining and CertificationFully provisioned kitchen with free breakfast and coffee breaksCommunity groupsSports TrainingShowers and Locker RoomsPartnerships discountsTeambuilding budget + activitiesInternal International Opportunities&nbsp;\nWhat you are going to doThe DevOps Manager is accountable for a DevOps Engineering team working on the Cloud Automation tools and Application Deployment processes. You will lead a team of 5 DevOps engineers, using cutting-edge cloud automation technologies to support the development, maintenance and monitoring of our platforms, while scaling our cloud platform to meet the demands of the US market. Using lean and agile methodologies, you will be responsible for the pace, scale and performance of your team. You will also be accountable for hiring, performance appraisal and reward of your team, focusing in helping your people define their career path and goals for short and long term.&nbsp;Key responsibilitiesLeadership &amp; PeopleLead, inspire, motivate and line manage a DevOps teamCoach, hold 1 to 1s, set and review objectives, appraise performance, and assist with career development, ensuring effective performance managementLead a ‘build and support with high quality’ cultureResponsible for achieving and sustaining people's engagementMeet ambitious timelines while balancing business risks and trade-offsDrive the team to continuously improve processesMaximize employee retentionSoftware DeliveryUnderstand the dependencies between components and how they combine&nbsp;Apply knowledge of Agile/Lean within the team to continuously improve the team pace, efficiency and qualityServe as liaison between your team and key stakeholder(s)Execute, plan and manage changesManage the review of infrastructure requirements within the team and provide feedback to other Managers and other change originatorsProvide technical direction for design, development, testing and deployment from definition phase through planning, implementation and maintenanceUnderstand and balance commercial needs against technical requirements and capabilitiesRecognize system deficiencies and lead to solutionsContinuous improvement of processes through automation of common procedures and implementation of standards, processes and checklistsPrioritize tasks throughout the project lifecycleLead a culture of technical approach documentation and preparation of software development and QA estimatesActively measure and review the Productivity, Velocity, Quality and Duration of delivery taking corrective action where necessaryOwnershipOwn the Cloud Solu ...
#   'post_date': '2020-03-27T12:57:33.564Z',
#   'scrape_date': '08/10/2021',
#   'company': 'Blip',
#   'job_location': 'Porto',
#   'job_category': 'IT',
#   'job_ref': 'https://landing.jobs/at/blip/devops-manager',
#   'salary': ''},
#  {'job_title': 'DevOps Engineer',
#   'job_description': 'We hope you haveLinux systems administration, including bash, python or ruby scripting experience;Configuration management experience, preferably ansible or chef;Experience working with Kafka and message queueing systems;Knowledge of Scala, Kafka, memcached, Apache Storm, Apache Cassandra, ZooKeeper;Continuous Integration and Continuous Delivery experience, preferably in Jenkins and GoCD;Experience of using established design patterns;Awareness and experience in using agile methodologies.\nWe´d love to seeTechnical experience in managing a highly available and highly scalable cloud environment;Hands-on knowledge of container orchestration;Strong desire to automate and simplify your way out of technical challenges;Ability to interact effectively with other functional teams;Excellent communicator, common sense and a passion for the art of problem-solving.\nWhat you can expect3 extra days of vacationFlexAppeal – Flexible Hours and possibility to work from homeDoctor, masseuse, nutritionist and ergonomist at the officeHealth insurance for employee+spouse+childrenMobile AllowanceChoose your Operating System (Windows or macOS)Own your laptop and accessories after 3 years in the companyCSR – 2 social days allowanceTraining and CertificationFully provisioned kitchen with free breakfast and coffee breaksCommunity groupsSports TrainingShowers and Locker RoomsPartnerships discountsTeambuilding budget + activitiesInternal International Opportunities (between Porto, London, Dublin, Cluj, Malta, New York, Orlando, Los Angeles, Edinburgh and Glasgow)\nWhat are you going to doAs a&nbsp;DevOps Engineer, you are part of a DevOps team, responsible for the Cloud Automation tools and Application Deployment processes for FanDuel Sportsbook Platforms. Reporting to a Delivery Manager in a team formed by 5 DevOps Engineers, you will be using cutting-edge cloud automation technologies to support our Sportsbook Platform development, maintenance and monitoring, while scaling our cloud platform to meet the demands of the US market. You will be required to create well-designed, testable, efficient tools to solve deployment and delivery needs, as well as testing and documenting the implemented solutions. You will have a bias for action and can break down complex problems into steps that drive the scalability, performance and stability of our platform.Key responsibilitiesTeam player on an Agile team, working together to keep delivering at pace, scale and with demanded quality to support our productsExecute full software development life cycleDevelop flowcharts, layouts and documentation to support the software teams with requirements and the team with solutionsWrite well-designed, testable and efficient codeProduce specifications and determine operational feasibilityIntegrate software components into a fully functional software systemDocument and maintain software functionalityTroubleshoot, debug and upgrade existing systemsDeploy applications in a Continuous Integration platformEnsure software is updated with latest features/versions in a timely manner',
#   'post_date': '2020-03-27T12:58:43.094Z',
#   'scrape_date': '08/10/2021',
#   'company': 'Blip',
#   'job_location': 'Porto',
#   'job_category': 'IT',
#   'job_ref': 'https://landing.jobs/at/blip/devops-engineer-in-porto-2020-3',
#   'salary': ''},
#  {'job_title': 'QA Engineer',
#   'job_description': 'We hope you haveAt least 3 years working as a Quality Assurance Engineer (or similar) roleExcellent analytical and problem-solving skillsExperience with API testing using frameworks like PostmanExcellent written and verbal communication skills (Portuguese and English)BSc or Masters in Computer Science or equivalent demonstrable knowledge&nbsp;\n\nWhat you can expect3 extra days of vacationFlexAppeal – Flexible Hours and possibility to work from homeDoctor, masseuse, nutritionist and ergonomist at the officeHealth insurance for employee + spouse + childrenMobile AllowanceChoose your Operating System (Windows or macOS)Own your laptop and accessories after 3 years in the companyCSR – 2 social days allowanceTraining and CertificationFully provisioned kitchen with free breakfast and coffee breaksCommunity groupsSports TrainingShowers and Locker RoomsPartnerships discountsTeambuilding budget + activitiesInternal International Opportunities\nWhat you are going to doAs a Quality Assurance Engineer, you are part of a Software Development Team, responsible for the full lifecycle of an application. Reporting to a Delivery Manager in a FanDuel team formed by 5 Developers and 1 QA, you will be collaborating with the Product Owner and your team Developers to deliver quality products at pace. You will be required to focus on the quality of the team delivery by using test-driven techniques, such as BDD. You understand and embrace the philosophy of CI/CD and have no interest in throwing work “over the wall” to anybody inside or outside of the team. You believe that preventing bugs through collaborative techniques, such as Specification by Example, brings better results and is more conducive to delivering at pace than bug detection. Passion to work in a cross-functional team that collaboratively build, test, release and operate applications describes you, as a QA Engineer.Key responsibilitiesTeam player on an Agile team, working together to keep delivering at pace, scale and with demanded quality to support our productsAnalyze requirements/user stories with a critical mindset, identifying possible gaps and being ready to challenge the Product OwnerSpecification of test plans for new features or architectural changesSpecification of test cases for user stories, in order to assure a good coverage of automated testsSupport/Help the developers on test case implementation and integration on existing componentsExploratory Testing of user storiesSupport the release management in a CI/CD environment, with a quality focus mindsetAnalyze incidents assigned to the team and create a bug story for the team to fix it, agreeing with the Product Owner the right priority and serverity&nbsp;',
#   'post_date': '2020-03-27T12:54:45.948Z',
#   'scrape_date': '08/10/2021',
#   'company': 'Blip',
#   'job_location': 'Porto',
#   'job_category': 'IT',
#   'job_ref': 'https://landing.jobs/at/blip/qa-engineer-in-porto-2020-3-27',
#   'salary': ''},
#  {'job_title': 'Senior QA Engineer',
#   'job_description': 'We hope you haveAt least 6 years working as a Quality Assurance Engineer (or similar) roleExcellent analytical and problem-solving skillsExperience with API testing using frameworks like PostmanExcellent written and verbal communication skills (Portuguese and English)BSc or Masters in Computer Science or equivalent demonstrable knowledge&nbsp;\n\nWhat you can expect3 extra days of vacationFlexAppeal – Flexible Hours and possibility to work from homeDoctor, masseuse, nutritionist and ergonomist at the officeHealth insurance for employee + spouse + childrenMobile AllowanceChoose your Operating System (Windows or macOS)Own your laptop and accessories after 3 years in the companyCSR – 2 social days allowanceTraining and CertificationFully provisioned kitchen with free breakfast and coffee breaksCommunity groupsSports TrainingShowers and Locker RoomsPartnerships discountsTeambuilding budget + activitiesInternal International Opportunities&nbsp;\nWhat you are going to doAs a Quality Assurance Engineer, you are part of a Software Development Team, responsible for the full lifecycle of an application. Reporting to a Delivery Manager in a FanDuel team formed by 5 Developers and 1 QA, you will be collaborating with the Product Owner and your team Developers to deliver quality products at pace. You will be required to focus on the quality of the team delivery by using test-driven techniques, such as BDD. You understand and embrace the philosophy of CI/CD and have no interest in throwing work “over the wall” to anybody inside or outside of the team. You believe that preventing bugs through collaborative techniques, such as Specification by Example, brings better results and is more conducive to delivering at pace than bug detection. Passion to work in a cross-functional team that collaboratively build, test, release and operate applications describes you, as a QA Engineer.Key responsibilitiesTeam player on an Agile team, working together to keep delivering at pace, scale and with demanded quality to support our productsAnalyze requirements/user stories with a critical mindset, identifying possible gaps and being ready to challenge the Product OwnerSpecification of test plans for new features or architectural changesSpecification of test cases for user stories, in order to assure a good coverage of automated testsSupport/Help the developers on test case implementation and integration on existing componentsExploratory Testing of user storiesSupport the release management in a CI/CD environment, with a quality focus mindsetAnalyze incidents assigned to the team and create a bug story for the team to fix it, agreeing with the Product Owner the right priority and serverity&nbsp;',
#   'post_date': '2020-03-27T12:55:47.525Z',
#   'scrape_date': '08/10/2021',
#   'company': 'Blip',
#   'job_location': 'Porto',
#   'job_category': 'IT',
#   'job_ref': 'https://landing.jobs/at/blip/senior-qa-engineer-in-porto-2020',
#   'salary': ''},
#  {'job_title': 'Delivery Manager | Front-end',
#   'job_description': "We hope you haveAt least 5 years of proven track record of leading and managing multi-disciplinary teams on complex software projectsUsing agile methods for software deliveryWorking with distributed, redundant and transactional systems and the quality assurance of theseManaging the development of a team by ensuring that project tasks are in line with each team member’s defined career path, as much as possibleUsing defect tracking systemsStrong analytical and diagnostic skills, particularly with regard to technical risks, issues and constraintsStrong leader and energetic motivatorWork well under time and environmental pressuresDemonstrate senior principles, leading by example, showing work ethic and passionate, professional attitudeProven track of project managementExcellent written and verbal communication skills (English and Portuguese)Team player, who strives to maximize team performanceBSc or Masters in Computer Science or equivalent demonstrable knowledge\n\nWhat you can expect&nbsp;3 extra days of vacationFlexAppeal – Flexible Hours and possibility to work from homeDoctor, masseuse, nutritionist and ergonomist at the officeHealth insurance for employee + spouse + childrenMobile AllowanceChoose your Operating System (Windows or macOS)Own your laptop and accessories after 3 years in the companyCSR – 2 social days allowanceTraining and CertificationFully provisioned kitchen with free breakfast and coffee breaksCommunity groupsSports TrainingShowers and Locker RoomsPartnerships discountsTeambuilding budget + activitiesInternal International Opportunities\nWhat you are going to doYou will lead a team of 5 software engineers and 1 QA engineer to deliver amazing value to our customers. Using lean and agile methodologies, you will be responsible for the pace, scale and performance of your team delivery. Having experience in all aspects of software delivery processes, from inception to release, will set you up for success.You will also be accountable for hiring, performance appraisal and reward of your team, focusing in helping your people define their career path and goals for short and long term.Key responsibilitiesLeadership &amp; PeopleLead, inspire and line manage a multi-disciplinary teamCoach, hold 1 to 1s, set and review objectives, appraise performance and assist with career developmentLead a ‘delivery with high quality’ cultureResponsible for achieving and sustaining people's engagementMeet ambitious timelines while balancing business risks and trade-offsDrive the team to continuously improve in a changing environmentMaximize employee retentionSoftware DeliveryUnderstand the dependencies between components and how they combine to deliver service to the end consumer and to the businessApply knowledge of Agile/Lean within the team, namely Scrum methodology to continuously improveServe as liaison between delivery team and stakeholder(s)Execute, plan and manage changes as appropriate to meet changing needs and requirementsManage the review of product requirements within the team and provide feedback to product owners and other change originatorsProvide technical direction for design, development, testing and deployment from definition phase through planning, implementation and maintenanceUnderstand and balance commercial needs against technical requirements and capabilitiesRecognize system deficiencies and lead to effective solutionsContinuous improvement of processes through automation of common procedures and implementation of standards, processes and checklistsPrioritize tasks throughout the project lifecycleLead a culture of technical approach documentation and preparation of software development and QA estimatesMeasure and review the Productivity, Velocity, Quality and Duration of delivery, taking prompt corrective action where necessaryOwnershipOwn products and/or components in terms of being fully accountable for the efficient, quality, and effective implementation of the relevant roadmap, as wel ...
#   'post_date': '2020-03-30T13:24:59.911Z',
#   'scrape_date': '08/10/2021',
#   'company': 'Blip',
#   'job_location': 'Porto',
#   'job_category': 'IT',
#   'job_ref': 'https://landing.jobs/at/blip/delivery-manager-front-end',
#   'salary': ''},
#  {'job_title': 'Product Manager @ SDC:LX',
# ...
#   'post_date': '2021-03-12T14:18:08.420Z',
#   'scrape_date': '08/10/2021',
#   'company': 'Oramix',
#   'job_location': 'Lisbon',
#   'job_category': 'IT',
#   'job_ref': 'https://landing.jobs/at/clarity-ai/senior-data-engineer-in-madrid',
#   'salary': ''},
#  {'job_title': 'IT Operations Engineer',
#   'job_description': 'Excellent written and oral communication skills&nbsp;6+ months of IT experience, with a strong technical foundationBasic knowledge of Mac, Linux, and Windows workstation setup and maintenanceB.S. Degree in Information Technology or a related discipline is a plus\n\n\nAs SingleStore’s IT Operations Engineer, you have the opportunity to help shape our IT organization. You will be part of the Global Infrastructure Team, a talented group of individuals that support several key technical areas at SingleStore including IT, security, and engineering infrastructure. This is an incredible opportunity for someone to build upon their technical foundation and gain broad exposure in IT at a growing startup.Roles and Responsibilities:&nbsp;Provide IT Help Desk support, including staff computer hardware, operating systems, software applications, networking, videoconferencing, printers, and phones&nbsp;Perform hardware repairs, upgrades and migrations&nbsp;Resolve problems in a timely manner or escalate on behalf of customers to senior technical staff&nbsp;Support endpoint security standards (antivirus/firewall/patching/two-factor authentication)&nbsp;Handle system access and maintain user accounts, passwords, data integrity &amp; security&nbsp;Help to evaluate hardware and software solutions and participate in IT projects&nbsp;Help to maintain inventory management, the asset lifecycle, and an organized help desk&nbsp;Document issues while providing updates to management, the team, and end users',
#   'post_date': '2021-03-16T09:33:38.510Z',
#   'scrape_date': '08/10/2021',
#   'company': 'Oramix',
#   'job_location': 'Lisbon',
#   'job_category': 'IT',
#   'job_ref': 'https://landing.jobs/at/singlestore/it-operations-engineer',
#   'salary': ''},
#  {'job_title': 'Senior Software Engineer',
#   'job_description': "3+ years of experience working on a cloud-native product (Go experience preferred)Deep interest and experience working on distributed systems, databases, networking, storage, and multi-tenant servicesExperience developing software which runs on KubernetesPassionate about building highly reliable customer facing servicesB.S. degree in Computer Science or a similar field\nAmazon EKS, Azure AKS, or Google GKE experience a bonus\n\nSenior Software Engineer, Serverless BackendAt SingleStore we're not just building a database company, we are defining the future of data management. We believe we can build a serverless solution designed for operational workloads and the SingleStore Managed Service Team is responsible for this initiative. We are looking for people to join us in building a hybrid cloud control plane which autonomously manages thousands of high-performance SingleStore databases on behalf of our customers. We fundamentally believe that customers should not have to compromise between always-online performance and serverless convenience.Joining us as a Senior Software Engineer, you will have the opportunity to develop continuously deployed software with a collaborative team. As our team operates in parallel on multiple features, you will manage the entire lifecycle of feature development at varying levels of complexity. This includes working directly with other teams as well as customers to ensure we always exceed expectations.Role and ResponsibilitiesDevelop a world-class cloud service responsible for providing an innovative serverless operational databaseWork closely with Kubernetes allowing the same technology powering SingleStore Managed Service to be delivered to select customers on-premiseBe part of the team that ships the world's first serverless operational databaseAutomate workflows and test your own code to improve overall software qualityManage individual project priorities, deadlines, and deliverablesPerform high-quality code reviews for your team members",
#   'post_date': '2021-03-16T09:33:36.942Z',
#   'scrape_date': '08/10/2021',
#   'company': 'Oramix',
#   'job_location': 'Lisbon',
#   'job_category': 'IT',
#   'job_ref': 'https://landing.jobs/at/singlestore/senior-software-engineer-in-lisbon-2021-3',
#   'salary': ''},
#  {'job_title': 'Junior Software Engineer',
#   'job_description': 'B.S. Degree in Computer Science, Electrical Engineering, Computer Engineering, or related disciplineDeep understanding of C.S. fundamentalsStrong programming skills with Python, Go, C, C++, or JavaScriptPassionate about building highly reliable softwareFirm grasp of algorithms and data structures\n\n\nSingleStore Software Engineers are at the forefront of real-time technology that’s revolutionizing how companies run their businesses everyday. With release cycles throughout the year, our engineers are accustomed to moving quickly in a rapid production environment. To do this successfully, we work collaboratively and creatively across teams to maximize our opportunity for impact. We also believe it’s important to celebrate our wins together whether it be at local spot or getting out of the city for some exploring.As a Software Engineer, you will be empowered to own your projects end-to-end and be an active contributor throughout the product life cycle. To expedite your growth path, you will partner with engineers who deeply care about your success and will lend their expertise to your professional development. Our engineers are not just technical partners, but are also business partners who are exposed to all areas of the business, working with teams such as product, marketing, and sales.Role and ResponsibilitiesOur Software Engineers work on small, collaborative teams to help drive our company forward.&nbsp;&nbsp;Whether you’re building new features in Javascript and React.js, increasing the runtime and performance of a SingleStore cluster, or writing new C++ code for the query optimizer, our University Graduates are responsible for brand new and existing projects that are deployed into production with each release.&nbsp;Your work will include everything from writing to testing software, and you’ll gain a significant understanding of both the product and the business.',
#   'post_date': '2021-03-12T16:38:12.527Z',
#   'scrape_date': '08/10/2021',
#   'company': 'Oramix',
#   'job_location': 'Lisbon',
#   'job_category': 'IT',
#   'job_ref': 'https://landing.jobs/at/singlestore/junior-software-engineer-in-lisbon-2021',
#   'salary': ''},
#  {'job_title': 'Site Reliability Engineer',
#   'job_description': 'Infrastructure automation experience.&nbsp; Python and GoLang a plus.&nbsp;&nbsp;Knowledge of Kubernetes and the container ecosystemStrong cross group collaboration and communication skillsFamiliar with at least one of AWS, Azure, or Google CloudExperience debugging, diagnosing and troubleshooting complex, production softwareB.S. Degree in Computer Science or related field\n\n\nSite Reliability Engineer, Managed ServiceSingleStore is seeking a Site Reliability Engineer to help optimize and scale our managed service offering across all three major cloud providers. In this role, you will be at the intersection of leading technology trends -&nbsp; A highly performant distributed database, managed by Kubernetes, running in the cloud.&nbsp; This is a great opportunity to push the boundaries with a cloud focused SRE role.&nbsp;&nbsp;This is a development role, requiring an engineering mindset to solve operational challenges.&nbsp; You will be part of a globally distributed team of engineers, helping to drive SRE practices across the company.&nbsp; Through infrastructure automation, you will help us grow our service across multiple cloud platforms.&nbsp; This requires a relentless focus on eliminating manual processes.&nbsp; You will also leverage our monitoring platform to improve overall customer experience by systematically identifying and fixing any issues impacting our customers.&nbsp; As an SRE you will also&nbsp; help diagnose issues on the platform, leveraging a deep understanding of the SingleStore query engine along with the backend infrastructure.&nbsp;&nbsp;Roles and ResponsibilitiesDevelop automation platform to manage infrastructure rollouts across cloud providersOptimize telemetry platform to identify customer impacting events while providing relevant data to drive debuggingPartner with engineering team to optimize performance of services for cloud architectureDebug Live Site events and conduct follow up post mortem and RCA analysisParticipate in a SLA-driven on-call rotation, which will include after-hours, weekend, and rotating holiday participation.',
#   'post_date': '2021-03-12T16:40:35.683Z',
#   'scrape_date': '08/10/2021',
#   'company': 'Oramix',
#   'job_location': 'Lisbon',
#   'job_category': 'IT',
#   'job_ref': 'https://landing.jobs/at/singlestore/site-reliability-engineer-in-lisbon-2021',
#   'salary': '40000 - 80000'},
#  {'job_title': 'Remote | Engineering Manager',
#   'job_description': "Who we’re looking forExperience in Software Engineering or in a similar field in Computer Science.Proven people management experience focused on developing and growing teams and its people. Not just on putting people on the path, but dealing with all sorts of situations.Demonstrated skills in leadership, adaptability, problem solving, and critical thinkingAbility to lead by example not being afraid to take risks and to go beyond what’s expectedSolution oriented, and when issues arise, be able to roll up sleeves and tackle them with a ‘get it done’ attitudePassion and experience designing, building and scaling services, cloud-based systems serving millions of users. Experience in high-scale migrations is highly welcome for this role.Evaluates and creates new product features in collaboration with the product team, while guaranteeing its success.\n\nWhat we’ll give youFull Remote Position based in Portugal. You'll need to be able to work in a full remote setup.Unique opportunity to become a part of an international team of top engineers learning from one another and contributing to the global OLX Group success.Working with and impacting all Classifieds websites in Europe collaborating with European and other International Hubs.A phenomenal place to learn and develop within fast-growing, global classifieds leader which opens further career opportunities in a diverse world of OLX and ProsusWork in a multicultural and international environment. We currently have&nbsp;over 20 nationalities in Portugal!Great Perks as a baseline, including, opportunity to go for conferences and open selection of training e-courses including MyAcademy, Udemy and specialist AWS trainings\nAs an&nbsp;Engineering Manager&nbsp;in our Motors hub in Portugal, you'll get the chance to work with various people from a completely international environment and have the autonomy to implement your ideas and processes in your very own team with us. You'll work with similar peers to deliver various features but also solidify the current platform, updating it to modern trends.You will contribute to build experiences in one of the fastest and key marketplaces: Motors. The European Motors Team is developing the Vertical Motors Platforms for many valuable markets figuring many millions in revenue.&nbsp; Among our brands you can find&nbsp;&nbsp;Otomoto.pl&nbsp;in Poland,&nbsp;Autovit.ro&nbsp;in Romania and in Portugal,&nbsp;Standvirtual.pt.&nbsp;Isn't this awesome or what? Great! But do you know what is even most exciting?&nbsp;You can be a key contributor of the platform where a friend of yours can find a dream car at a fair price. Yes, your work will impact people's lives!What you will be doingYour work with us is to lead and shape an effective multi-functional team of 6-10 people of which 3-6 engineers are under your direct management. As such you'll be responsible for:Contribute to scaling our platform to the next level of modularity &amp; shareability while working on architecture, tools, standards, and practices for the engineering European organization.Hiring, onboarding, mentoring, coaching, feedback, and career development of the engineering team.Technical leadership by putting in place and continuously improving development and quality practices (design, code reviews, code quality, testing, release management)Supporting the team with as much or little process as they require, e.g. implementing the best methodology that brings efficiency to your team.Work with recruiting team to find and interview engineersBe responsible for the planning, execution, and success of our product features.Working together with the team’s product responsible to align technology solutions with the product vision.",
#   'post_date': '2021-03-15T16:49:06.898Z',
#   'scrape_date': '08/10/2021',
#   'company': 'Oramix',
#   'job_location': 'Lisbon',
#   'job_category': 'IT',
#   'job_ref': 'https://landing.jobs/at/olx-group/remote-engineering-manager-in-lisbon',
#   'salary': ''}]
